# %% [markdown]
# # 20-sentence-embedding for review, description and overview

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from sentence_transformers import SentenceTransformer
import umap

# %% [markdown]
# ## Read in main.csv

# %%
main = pd.read_csv('Data/main_211112.csv', dtype=str)

# %%
main
# Out:
#               id                                             review  \
# 0      tt0018515  This is a very strange film that was long thou...
# 1      tt0018515  William Boyd and Louis Wolheim are the "Two Ar...
# 2      tt0018515  Not very many movies come to my mind that cove...
# 3      tt0018515  The third movie produced by Howard Hughes, thi...
# 4      tt0018515  Turner Classic Movies showed this silent, B&W ...
# ...          ...                                                ...
# 28623  tt0492486  This was the surprise film at the Dublin Horro...
# 28624  tt0492486  I've seen hundreds of horror movies in my life...
# 28625  tt0492486  I cannot remember the last time a horror movie...
# 28626  tt0492486  I saw this movie tonight. Never have left comm...
# 28627  tt0492486  Shrooms basically is a Slasher Movie. 3 couple...
#
#        review_1st review_2nd       original_title  year date_published  \
# 0       2.6453724   5.547905  Two Arabian Knights  1927     1927-09-23
# 1      -0.4441953  2.2827504  Two Arabian Knights  1927     1927-09-23
# 2       0.8150438  3.9238899  Two Arabian Knights  1927     1927-09-23
# 3        2.477075   5.466526  Two Arabian Knights  1927     1927-09-23
# 4       1.1922804  2.5448508  Two Arabian Knights  1927     1927-09-23
# ...           ...        ...                  ...   ...            ...
# 28623   1.0869972   6.843044              Shrooms  2007     2008-08-22
# 28624  0.17316706    6.62107              Shrooms  2007     2008-08-22
# 28625   1.0682999   6.835441              Shrooms  2007     2008-08-22
# 28626   1.0295599  3.5069268              Shrooms  2007     2008-08-22
# 28627   1.0787203   6.848455              Shrooms  2007     2008-08-22
#
#       duration               country language  ...   recommendation3  \
# 0           92                   USA  English  ...  The Last Command
# 1           92                   USA  English  ...  The Last Command
# 2           92                   USA  English  ...  The Last Command
# 3           92                   USA  English  ...  The Last Command
# 4           92                   USA  English  ...  The Last Command
# ...        ...                   ...      ...  ...               ...
# 28623       84  Ireland, UK, Denmark  English  ...   YellowBrickRoad
# 28624       84  Ireland, UK, Denmark  English  ...   YellowBrickRoad
# 28625       84  Ireland, UK, Denmark  English  ...   YellowBrickRoad
# 28626       84  Ireland, UK, Denmark  English  ...   YellowBrickRoad
# 28627       84  Ireland, UK, Denmark  English  ...   YellowBrickRoad
#
#       recommendation4 recommendation5       recommendation6 recommendation7  \
# 0        Street Angel  Sadie Thompson            Underworld         Tempest
# 1        Street Angel  Sadie Thompson            Underworld         Tempest
# 2        Street Angel  Sadie Thompson            Underworld         Tempest
# 3        Street Angel  Sadie Thompson            Underworld         Tempest
# 4        Street Angel  Sadie Thompson            Underworld         Tempest
# ...               ...             ...                   ...             ...
# 28623      Shrooms 3D           Creep  Wicked Little Things       Catacombs
# 28624      Shrooms 3D           Creep  Wicked Little Things       Catacombs
# 28625      Shrooms 3D           Creep  Wicked Little Things       Catacombs
# 28626      Shrooms 3D           Creep  Wicked Little Things       Catacombs
# 28627      Shrooms 3D           Creep  Wicked Little Things       Catacombs
#
#             recommendation8 recommendation9   recommendation10  \
# 0      The Way of All Flesh  The Front Page    The Divine Lady
# 1      The Way of All Flesh  The Front Page    The Divine Lady
# 2      The Way of All Flesh  The Front Page    The Divine Lady
# 3      The Way of All Flesh  The Front Page    The Divine Lady
# 4      The Way of All Flesh  The Front Page    The Divine Lady
# ...                     ...             ...                ...
# 28623             Dark Ride        100 Feet  La bête à l'affût
# 28624             Dark Ride        100 Feet  La bête à l'affût
# 28625             Dark Ride        100 Feet  La bête à l'affût
# 28626             Dark Ride        100 Feet  La bête à l'affût
# 28627             Dark Ride        100 Feet  La bête à l'affût
#
#              recommendation11  recommendation12
# 0      The Patent Leather Kid   The Love Parade
# 1      The Patent Leather Kid   The Love Parade
# 2      The Patent Leather Kid   The Love Parade
# 3      The Patent Leather Kid   The Love Parade
# 4      The Patent Leather Kid   The Love Parade
# ...                       ...               ...
# 28623         Finders Keepers  Shin Tange Sazen
# 28624         Finders Keepers  Shin Tange Sazen
# 28625         Finders Keepers  Shin Tange Sazen
# 28626         Finders Keepers  Shin Tange Sazen
# 28627         Finders Keepers  Shin Tange Sazen
#
# [28628 rows x 46 columns]

# %% [markdown]
# ## How many unique movies do we have in main dataset

# %%
len(set(main['id'].tolist()))
# Out:
# 3037

# %% [markdown]
# ## Convert review and description into list for models

# %%
reviews = main["review"].tolist()
reviews[:2]

descriptions = main["description"].tolist()
descriptions[:2]

overviews = main["overview"].tolist()
overviews[:2]
# Out:
# ["Director Lewis Milestone's 1927 comedy follows the exploits of two American soldiers during WWI. Starring William Boyd, Mary Astor and Louis Wolheim.",
#  "Director Lewis Milestone's 1927 comedy follows the exploits of two American soldiers during WWI. Starring William Boyd, Mary Astor and Louis Wolheim."]

# %% [markdown]
# ## Download and import model we need

# %%
model = SentenceTransformer('sentence-transformers/distiluse-base-multilingual-cased-v1')

# %% [markdown]
# ## Create review embedding by above model

# %% [markdown]
# ### Combine reviews from the same movie into one

# %%
df = main.groupby(by='id').sum()[['review']]
df['id'] = df.index
reviews = df['review'].tolist()
df
# Out:
#                                                       review         id
# id
# tt0000574  The Story of the Kelly Gang (1906) symbolizes ...  tt0000574
# tt0002461  Credited as the earliest complete feature-leng...  tt0002461
# tt0005078  In this short, under an hour feature, all we h...  tt0005078
# tt0005339  Watching this today is akin to taking a trip i...  tt0005339
# tt0006206  Serials are a low point in film history and th...  tt0006206
# ...                                                      ...        ...
# tt0988047  It sure took a long time for this film to debu...  tt0988047
# tt0988849  Definition of a donkey punch: a blow administe...  tt0988849
# tt0990361  I've had the chance to see this movie yesterda...  tt0990361
# tt0995740  Do not, I repeat DO NOT watch this movie if yo...  tt0995740
# tt0995827  saw a sneak preview of this film yesterday in ...  tt0995827
#
# [3037 rows x 2 columns]

# %%
review_embeddings = model.encode(reviews)
print("Shape:", review_embeddings.shape)
print(review_embeddings)
# Out:
# Shape: (3037, 512)
# [[-0.05172382 -0.01318167 -0.02941219 ... -0.08277107 -0.04488661
#   -0.0467704 ]
#  [ 0.02845402 -0.00476698 -0.0085305  ... -0.07068139  0.00186067
#    0.03523669]
#  [-0.02477219 -0.04172837 -0.04370242 ... -0.0950805   0.06399228
#    0.01111828]
#  ...
#  [-0.04749458 -0.02303065 -0.02309803 ... -0.04840309 -0.01880701
#   -0.00211786]
#  [-0.01954935  0.03467304 -0.0288606  ... -0.03560465  0.00657937
#    0.05115532]
#  [-0.03478554 -0.03051612 -0.01558649 ... -0.07321873 -0.01056405
#   -0.00945658]]

# %% [markdown]
# ## Create description embedding

# %%
df_des = main[['id', 'description']].drop_duplicates()
descriptions = df_des['description'].tolist()
df_des
# Out:
#               id                                        description
# 0      tt0018515  Two American soldiers are captured by the Germ...
# 10     tt0118866  The relationship between four female temps all...
# 40     tt0050652  Aging gunslinger Jacob Wade hopes to settle do...
# 46     tt0051885  A doctor's daughter is kidnapped and buried al...
# 49     tt0248123  Julietta returns to Berlin with a dilemma on h...
# ...          ...                                                ...
# 28580  tt0238948  A man on the run takes another man's passport,...
# 28593  tt0406375  Two young brothers are drawn into an intergala...
# 28597  tt0063591  A pardoned stagecoach robber, becomes governme...
# 28598  tt0119791  A law student, who takes a job as a night watc...
# 28603  tt0492486  A group of friends are stalked and murdered wh...
#
# [3037 rows x 2 columns]

# %%
description_embeddings = model.encode(descriptions)
print("Shape:", description_embeddings.shape)
print(description_embeddings)
# Out:
# Shape: (3037, 512)
# [[ 0.00010171  0.00142653  0.0030459  ...  0.04980651  0.02470978
#   -0.01856348]
#  [ 0.08609562 -0.02957341  0.08522253 ... -0.04514211 -0.07731085
#   -0.01606046]
#  [-0.00051633 -0.04036959 -0.01269487 ...  0.04954691 -0.03707771
#   -0.00208472]
#  ...
#  [ 0.0303678   0.02007469 -0.01344747 ... -0.03773912  0.0312012
#   -0.0448827 ]
#  [ 0.04699449  0.01423166  0.00188398 ...  0.02691923  0.02676632
#   -0.03699284]
#  [-0.03081206  0.00739098  0.06345712 ...  0.01487389  0.00680741
#    0.06922294]]

# %% [markdown]
# ## Create overview embeddings

# %%
df_over = main[['id', 'overview']].drop_duplicates()
overviews = df_over['overview'].tolist()
df_over
# Out:
#               id                                           overview
# 0      tt0018515  Director Lewis Milestone's 1927 comedy follows...
# 10     tt0118866  Iris can best be described as a wallflower. Sh...
# 40     tt0050652  Aging gunslinger Jacob Wade hopes to settle do...
# 46     tt0051885  A doctor's daughter is kidnapped and buried al...
# 49     tt0248123  A dramatic teenage love story set against the ...
# ...          ...                                                ...
# 28580  tt0238948  The governor of a Mexican state is assassinate...
# 28593  tt0406375  After their father is called into work, two yo...
# 28597  tt0063591  Jesse W. Haywood (Don Knotts) graduates from d...
# 28598  tt0119791  A law student, who takes a job as a night watc...
# 28603  tt0492486  A group of American teens comes Ireland to vis...
#
# [3037 rows x 2 columns]

# %%
overview_embeddings = model.encode(overviews)
print("Shape:", overview_embeddings.shape)
print(overview_embeddings)
# Out:
# Shape: (3037, 512)
# [[-0.00078443 -0.06351549 -0.13784662 ... -0.04011483 -0.0479288
#   -0.05433805]
#  [ 0.06199616 -0.00951628 -0.05670635 ...  0.0027988  -0.00995845
#    0.02490294]
#  [ 0.08615995 -0.03223411 -0.03190124 ... -0.03967644  0.02711902
#   -0.02216075]
#  ...
#  [ 0.00195637  0.06153557  0.01064557 ... -0.00223976  0.05434822
#    0.00480348]
#  [ 0.04699449  0.01423166  0.00188398 ...  0.02691923  0.02676632
#   -0.03699284]
#  [-0.00325433 -0.00610787  0.00798221 ... -0.0211592   0.04874625
#    0.05028084]]

# %% [markdown]
# ## Reduce 512 dimension to 2 by using umap technique and plot

# %%
reducer = umap.UMAP()
review2D = reducer.fit_transform(review_embeddings)
describe2D = reducer.fit_transform(description_embeddings)
overview2D = reducer.fit_transform(overview_embeddings)
print(review2D.shape)
print(describe2D.shape)
print(overview2D.shape)
# Out:
# (3037, 2)
# (3037, 2)
# (3037, 2)

# %% [markdown]
# ### Drop all previous embedding columns

# %%
main.columns
# Out:
# Index(['id', 'review', 'review_1st', 'review_2nd', 'original_title', 'year',
#        'date_published', 'duration', 'country', 'language', 'director',
#        'writer', 'production_company', 'actors', 'description',
#        'description_1st', 'description_2nd', 'votes', 'reviews_from_users',
#        'reviews_from_critics', 'adult', 'genres', 'original_language',
#        'overview', 'popularity', 'poster_path', 'revenue', 'runtime', 'status',
#        'video', 'vote_count', 'genre_1', 'genre_2', 'genre_3',
#        'recommendation1', 'recommendation2', 'recommendation3',
#        'recommendation4', 'recommendation5', 'recommendation6',
#        'recommendation7', 'recommendation8', 'recommendation9',
#        'recommendation10', 'recommendation11', 'recommendation12'],
#       dtype='object')

# %%
main_drop = main.drop(columns=['review', 'review_1st', 'review_2nd', 'description', 'description_1st', 'description_2nd'])

# %% [markdown]
# ## Add review 2d embeddings to main dataset

# %%
df['review_1st']=review2D[:,0]
df['review_2nd']=review2D[:,1]
df_re = df.drop(columns='review')
df_re.reset_index(drop=True, inplace=True)
df_re
# Out:
#              id  review_1st  review_2nd
# 0     tt0000574    2.970235   10.711953
# 1     tt0002461    2.900796   11.341978
# 2     tt0005078    0.627618   12.805361
# 3     tt0005339    0.984023   11.585050
# 4     tt0006206    6.032124    9.722160
# ...         ...         ...         ...
# 3032  tt0988047    2.914837   13.828070
# 3033  tt0988849    5.236000   12.443265
# 3034  tt0990361    2.541798   12.849465
# 3035  tt0995740    3.031713   14.914072
# 3036  tt0995827    2.928864   12.301660
#
# [3037 rows x 3 columns]

# %%
main_rev = main_drop.merge(df_re, how='left', on = 'id')

# %% [markdown]
# ## Add description 2d embeddings to main dataset

# %%
df_des['description_1st'] = describe2D[:, 0]
df_des['description_2nd'] = describe2D[:, 1]
df_des = df_des.drop(columns='description')
df_des.reset_index(drop=True, inplace=True)
df_des
# Out:
#              id  description_1st  description_2nd
# 0     tt0018515        17.669596        -0.738235
# 1     tt0118866        20.341370        -4.583504
# 2     tt0050652        20.424614        -2.285807
# 3     tt0051885        21.787266        -3.158614
# 4     tt0248123        19.101181        -5.684755
# ...         ...              ...              ...
# 3032  tt0238948        20.537291        -1.603543
# 3033  tt0406375        20.091591        -2.168772
# 3034  tt0063591        21.206562        -0.786693
# 3035  tt0119791        22.496815        -2.224130
# 3036  tt0492486        20.324760        -0.633298
#
# [3037 rows x 3 columns]

# %%
main_rev_des = main_rev.merge(df_des, how='left', on = 'id')
main_rev_des
# Out:
#               id       original_title  year date_published duration  \
# 0      tt0018515  Two Arabian Knights  1927     1927-09-23       92
# 1      tt0018515  Two Arabian Knights  1927     1927-09-23       92
# 2      tt0018515  Two Arabian Knights  1927     1927-09-23       92
# 3      tt0018515  Two Arabian Knights  1927     1927-09-23       92
# 4      tt0018515  Two Arabian Knights  1927     1927-09-23       92
# ...          ...                  ...   ...            ...      ...
# 28623  tt0492486              Shrooms  2007     2008-08-22       84
# 28624  tt0492486              Shrooms  2007     2008-08-22       84
# 28625  tt0492486              Shrooms  2007     2008-08-22       84
# 28626  tt0492486              Shrooms  2007     2008-08-22       84
# 28627  tt0492486              Shrooms  2007     2008-08-22       84
#
#                     country language          director  \
# 0                       USA  English   Lewis Milestone
# 1                       USA  English   Lewis Milestone
# 2                       USA  English   Lewis Milestone
# 3                       USA  English   Lewis Milestone
# 4                       USA  English   Lewis Milestone
# ...                     ...      ...               ...
# 28623  Ireland, UK, Denmark  English  Paddy Breathnach
# 28624  Ireland, UK, Denmark  English  Paddy Breathnach
# 28625  Ireland, UK, Denmark  English  Paddy Breathnach
# 28626  Ireland, UK, Denmark  English  Paddy Breathnach
# 28627  Ireland, UK, Denmark  English  Paddy Breathnach
#
#                              writer production_company  ... recommendation7  \
# 0      Wallace Smith, Cyril Gardner  The Caddo Company  ...         Tempest
# 1      Wallace Smith, Cyril Gardner  The Caddo Company  ...         Tempest
# 2      Wallace Smith, Cyril Gardner  The Caddo Company  ...         Tempest
# 3      Wallace Smith, Cyril Gardner  The Caddo Company  ...         Tempest
# 4      Wallace Smith, Cyril Gardner  The Caddo Company  ...         Tempest
# ...                             ...                ...  ...             ...
# 28623                Pearse Elliott      Capitol Films  ...       Catacombs
# 28624                Pearse Elliott      Capitol Films  ...       Catacombs
# 28625                Pearse Elliott      Capitol Films  ...       Catacombs
# 28626                Pearse Elliott      Capitol Films  ...       Catacombs
# 28627                Pearse Elliott      Capitol Films  ...       Catacombs
#
#             recommendation8 recommendation9   recommendation10  \
# 0      The Way of All Flesh  The Front Page    The Divine Lady
# 1      The Way of All Flesh  The Front Page    The Divine Lady
# 2      The Way of All Flesh  The Front Page    The Divine Lady
# 3      The Way of All Flesh  The Front Page    The Divine Lady
# 4      The Way of All Flesh  The Front Page    The Divine Lady
# ...                     ...             ...                ...
# 28623             Dark Ride        100 Feet  La bête à l'affût
# 28624             Dark Ride        100 Feet  La bête à l'affût
# 28625             Dark Ride        100 Feet  La bête à l'affût
# 28626             Dark Ride        100 Feet  La bête à l'affût
# 28627             Dark Ride        100 Feet  La bête à l'affût
#
#              recommendation11  recommendation12 review_1st review_2nd  \
# 0      The Patent Leather Kid   The Love Parade   4.942679  13.482060
# 1      The Patent Leather Kid   The Love Parade   4.942679  13.482060
# 2      The Patent Leather Kid   The Love Parade   4.942679  13.482060
# 3      The Patent Leather Kid   The Love Parade   4.942679  13.482060
# 4      The Patent Leather Kid   The Love Parade   4.942679  13.482060
# ...                       ...               ...        ...        ...
# 28623         Finders Keepers  Shin Tange Sazen   2.569802  12.533641
# 28624         Finders Keepers  Shin Tange Sazen   2.569802  12.533641
# 28625         Finders Keepers  Shin Tange Sazen   2.569802  12.533641
# 28626         Finders Keepers  Shin Tange Sazen   2.569802  12.533641
# 28627         Finders Keepers  Shin Tange Sazen   2.569802  12.533641
#
#       description_1st description_2nd
# 0           17.669596       -0.738235
# 1           17.669596       -0.738235
# 2           17.669596       -0.738235
# 3           17.669596       -0.738235
# 4           17.669596       -0.738235
# ...               ...             ...
# 28623       20.324760       -0.633298
# 28624       20.324760       -0.633298
# 28625       20.324760       -0.633298
# 28626       20.324760       -0.633298
# 28627       20.324760       -0.633298
#
# [28628 rows x 44 columns]

# %% [markdown]
# ## Add overview 2D embeddings to main dataset

# %%
df_over['overview_1st'] = overview2D[:, 0]
df_over['overview_2nd'] = overview2D[:, 1]
df_over = df_over.drop(columns='overview')
df_over.reset_index(drop=True, inplace=True)
df_over
# Out:
#              id  overview_1st  overview_2nd
# 0     tt0018515      8.649476      3.307126
# 1     tt0118866     12.137049      4.244494
# 2     tt0050652      9.784697      2.606914
# 3     tt0051885     11.626658      0.298345
# 4     tt0248123     10.454543      5.274888
# ...         ...           ...           ...
# 3032  tt0238948     10.153371      1.411950
# 3033  tt0406375      8.163801      0.694519
# 3034  tt0063591     11.498743      3.363511
# 3035  tt0119791     11.200775     -0.287683
# 3036  tt0492486      9.588804      0.534126
#
# [3037 rows x 3 columns]

# %%
main_rev_des_over = main_rev_des.merge(df_over, how='left', on = 'id')
main_rev_des_over
# Out:
#               id       original_title  year date_published duration  \
# 0      tt0018515  Two Arabian Knights  1927     1927-09-23       92
# 1      tt0018515  Two Arabian Knights  1927     1927-09-23       92
# 2      tt0018515  Two Arabian Knights  1927     1927-09-23       92
# 3      tt0018515  Two Arabian Knights  1927     1927-09-23       92
# 4      tt0018515  Two Arabian Knights  1927     1927-09-23       92
# ...          ...                  ...   ...            ...      ...
# 28623  tt0492486              Shrooms  2007     2008-08-22       84
# 28624  tt0492486              Shrooms  2007     2008-08-22       84
# 28625  tt0492486              Shrooms  2007     2008-08-22       84
# 28626  tt0492486              Shrooms  2007     2008-08-22       84
# 28627  tt0492486              Shrooms  2007     2008-08-22       84
#
#                     country language          director  \
# 0                       USA  English   Lewis Milestone
# 1                       USA  English   Lewis Milestone
# 2                       USA  English   Lewis Milestone
# 3                       USA  English   Lewis Milestone
# 4                       USA  English   Lewis Milestone
# ...                     ...      ...               ...
# 28623  Ireland, UK, Denmark  English  Paddy Breathnach
# 28624  Ireland, UK, Denmark  English  Paddy Breathnach
# 28625  Ireland, UK, Denmark  English  Paddy Breathnach
# 28626  Ireland, UK, Denmark  English  Paddy Breathnach
# 28627  Ireland, UK, Denmark  English  Paddy Breathnach
#
#                              writer production_company  ... recommendation9  \
# 0      Wallace Smith, Cyril Gardner  The Caddo Company  ...  The Front Page
# 1      Wallace Smith, Cyril Gardner  The Caddo Company  ...  The Front Page
# 2      Wallace Smith, Cyril Gardner  The Caddo Company  ...  The Front Page
# 3      Wallace Smith, Cyril Gardner  The Caddo Company  ...  The Front Page
# 4      Wallace Smith, Cyril Gardner  The Caddo Company  ...  The Front Page
# ...                             ...                ...  ...             ...
# 28623                Pearse Elliott      Capitol Films  ...        100 Feet
# 28624                Pearse Elliott      Capitol Films  ...        100 Feet
# 28625                Pearse Elliott      Capitol Films  ...        100 Feet
# 28626                Pearse Elliott      Capitol Films  ...        100 Feet
# 28627                Pearse Elliott      Capitol Films  ...        100 Feet
#
#         recommendation10        recommendation11  recommendation12 review_1st  \
# 0        The Divine Lady  The Patent Leather Kid   The Love Parade   4.942679
# 1        The Divine Lady  The Patent Leather Kid   The Love Parade   4.942679
# 2        The Divine Lady  The Patent Leather Kid   The Love Parade   4.942679
# 3        The Divine Lady  The Patent Leather Kid   The Love Parade   4.942679
# 4        The Divine Lady  The Patent Leather Kid   The Love Parade   4.942679
# ...                  ...                     ...               ...        ...
# 28623  La bête à l'affût         Finders Keepers  Shin Tange Sazen   2.569802
# 28624  La bête à l'affût         Finders Keepers  Shin Tange Sazen   2.569802
# 28625  La bête à l'affût         Finders Keepers  Shin Tange Sazen   2.569802
# 28626  La bête à l'affût         Finders Keepers  Shin Tange Sazen   2.569802
# 28627  La bête à l'affût         Finders Keepers  Shin Tange Sazen   2.569802
#
#       review_2nd description_1st description_2nd overview_1st overview_2nd
# 0      13.482060       17.669596       -0.738235     8.649476     3.307126
# 1      13.482060       17.669596       -0.738235     8.649476     3.307126
# 2      13.482060       17.669596       -0.738235     8.649476     3.307126
# 3      13.482060       17.669596       -0.738235     8.649476     3.307126
# 4      13.482060       17.669596       -0.738235     8.649476     3.307126
# ...          ...             ...             ...          ...          ...
# 28623  12.533641       20.324760       -0.633298     9.588804     0.534126
# 28624  12.533641       20.324760       -0.633298     9.588804     0.534126
# 28625  12.533641       20.324760       -0.633298     9.588804     0.534126
# 28626  12.533641       20.324760       -0.633298     9.588804     0.534126
# 28627  12.533641       20.324760       -0.633298     9.588804     0.534126
#
# [28628 rows x 46 columns]

# %% [markdown]
# ## Select needed columns

# %%
main_rev_des_over.columns
# Out:
# Index(['id', 'original_title', 'year', 'date_published', 'duration', 'country',
#        'language', 'director', 'writer', 'production_company', 'actors',
#        'votes', 'reviews_from_users', 'reviews_from_critics', 'adult',
#        'genres', 'original_language', 'overview', 'popularity', 'poster_path',
#        'revenue', 'runtime', 'status', 'video', 'vote_count', 'genre_1',
#        'genre_2', 'genre_3', 'recommendation1', 'recommendation2',
#        'recommendation3', 'recommendation4', 'recommendation5',
#        'recommendation6', 'recommendation7', 'recommendation8',
#        'recommendation9', 'recommendation10', 'recommendation11',
#        'recommendation12', 'review_1st', 'review_2nd', 'description_1st',
#        'description_2nd', 'overview_1st', 'overview_2nd'],
#       dtype='object')

# %%
final_main = main_rev_des_over[['id', 'review_1st', 'review_2nd', 
                         'description_1st', 'description_2nd', 
                         'overview_1st', 'overview_2nd', 
                         'country', 'language', 'director', 'votes', 
                         'reviews_from_critics', 'popularity', 
                         'genre_1', 'genre_2', 'genre_3']]

# %%
movie_only = final_main.drop_duplicates()
movie_only.to_csv("Data/final_main.csv", index=False)
movie_only
# Out:
#               id  review_1st  review_2nd  description_1st  description_2nd  \
# 0      tt0018515    4.942679   13.482060        17.669596        -0.738235
# 10     tt0118866    1.672779   11.368067        20.341370        -4.583504
# 40     tt0050652    3.586681   10.927030        20.424614        -2.285807
# 46     tt0051885    5.692213   10.103884        21.787266        -3.158614
# 49     tt0248123    5.052363   14.008677        19.101181        -5.684755
# ...          ...         ...         ...              ...              ...
# 28580  tt0238948    3.672903   13.673236        20.537291        -1.603543
# 28593  tt0406375    2.739948   14.026184        20.091591        -2.168772
# 28597  tt0063591    3.020100    9.555977        21.206562        -0.786693
# 28598  tt0119791    4.831090    9.789382        22.496815        -2.224130
# 28603  tt0492486    2.569802   12.533641        20.324760        -0.633298
#
#        overview_1st  overview_2nd               country          language  \
# 0          8.649476      3.307126                   USA           English
# 10        12.137049      4.244494               UK, USA           English
# 40         9.784697      2.606914                   USA           English
# 46        11.626658      0.298345                   USA           English
# 49        10.454543      5.274888               Germany            German
# ...             ...           ...                   ...               ...
# 28580     10.153371      1.411950                   USA  English, Spanish
# 28593      8.163801      0.694519                   USA           English
# 28597     11.498743      3.363511                   USA           English
# 28598     11.200775     -0.287683                   USA           English
# 28603      9.588804      0.534126  Ireland, UK, Denmark           English
#
#                director              votes reviews_from_critics popularity  \
# 0       Lewis Milestone               3.35                  6.0    0.38981
# 10        Jill Sprecher               6.05                 43.0   1.885671
# 40          Henry Levin               6.25                  8.0   0.127452
# 46       William Castle  5.949999999999999                 22.0   0.837849
# 49      Christoph Stark                6.6                  7.0   0.041677
# ...                 ...                ...                  ...        ...
# 28580      George Gallo                5.5                 46.0   3.067916
# 28593       Jon Favreau               6.15                132.0  10.695639
# 28597       Alan Rafkin  6.300000000000001                  8.0   1.053244
# 28598      Ole Bornedal                6.2                 52.0   6.122067
# 28603  Paddy Breathnach               4.75                 96.0   9.128571
#
#          genre_1     genre_2    genre_3
# 0      Adventure      Comedy    Romance
# 10        Comedy       Drama        NaN
# 40         Drama     Western        NaN
# 46        Horror    Thriller        NaN
# 49         Drama     Romance        NaN
# ...          ...         ...        ...
# 28580     Action      Comedy      Crime
# 28593     Action   Adventure     Comedy
# 28597     Action   Adventure     Comedy
# 28598      Drama      Horror   Thriller
# 28603     Comedy      Horror    Mystery
#
# [3037 rows x 16 columns]

# %% [markdown]
# ## Merge with imdb_recommendation_tid.csv file

# %%
imdb = pd.read_csv('Data/imdb_recommendations_tid.csv', dtype=str)
imdb
# Out:
#              id recommendation1 recommendation2 recommendation3  \
# 0     tt0018515       tt0019304       tt0019071       tt0018379
# 1     tt0118866       tt0116041       tt0114095       tt0119324
# 2     tt0050652       tt0052877       tt0044683       tt0048707
# 3     tt0051885       tt0047348       tt0054988       tt0060228
# 4     tt0248123       tt4326444      tt13279528       tt0072852
# ...         ...             ...             ...             ...
# 3032  tt0238948       tt0166195       tt4191580       tt0199290
# 3033  tt0406375       tt0398808       tt0416236       tt0113497
# 3034  tt0063591       tt0067219       tt0064606       tt0081376
# 3035  tt0119791       tt0110631       tt0119535       tt0120662
# 3036  tt0492486       tt0454224       tt2050633       tt0377749
#
#      recommendation4 recommendation5 recommendation6 recommendation7  \
# 0          tt0019429       tt0018526       tt0019451       tt0019344
# 1          tt3314958       tt1512240       tt0268690       tt0443698
# 2          tt0058286       tt0043079       tt0051046       tt0051849
# 3          tt0059821       tt0053931       tt0055200       tt0052602
# 4          tt0433770       tt0045942       tt0402022       tt4048272
# ...              ...             ...             ...             ...
# 3032       tt0119664       tt0101252       tt0241760       tt0297181
# 3033       tt0405325       tt1155076       tt0373051       tt0963966
# 3034       tt0077698       tt0052005       tt0079754       tt0045589
# 3035       tt4287464       tt0111149       tt0108473       tt0403358
# 3036       tt1398428       tt1718895       tt0381966       tt0470000
#
#      recommendation8 recommendation9 recommendation10 recommendation11  \
# 0          tt0019553       tt0021890        tt0019824        tt0018054
# 1          tt0067350       tt0090037        tt5791216        tt0082220
# 2          tt0043276       tt0051496        tt0042426        tt0051848
# 3          tt0053363       tt0048190        tt0062909        tt0023790
# 4          tt9271164       tt0185125       tt15392100       tt11242218
# ...              ...             ...              ...              ...
# 3032       tt0472126       tt5304664        tt0410097        tt0421045
# 3033       tt1078912       tt0477347        tt0338348        tt0494238
# 3034       tt0091846       tt0047197        tt0067809        tt0043767
# 3035       tt0145531       tt0119675        tt0070444        tt0115744
# 3036       tt1204883       tt1601475        tt0227488        tt0449471
#
#      recommendation12
# 0           tt0018253
# 1           tt0068718
# 2           tt0051400
# 3           tt0053719
# 4           tt9203694
# ...               ...
# 3032        tt0119807
# 3033        tt0396752
# 3034        tt0065051
# 3035        tt0104549
# 3036        tt0899128
#
# [3037 rows x 13 columns]

# %%
model_data = movie_only.merge(imdb, how='left', on = 'id').drop(columns=['recommendation6','recommendation7',
                                                           'recommendation8', 'recommendation9',
                                                           'recommendation10', 'recommendation11',
                                                           'recommendation12'])
model_data.to_csv("Data/model_data.csv", index=False)

# %%
pd.read_csv('Data/model_data.csv')
# Out:
#              id  review_1st  review_2nd  description_1st  description_2nd  \
# 0     tt0018515    4.942679   13.482060        17.669596        -0.738235
# 1     tt0118866    1.672779   11.368067        20.341370        -4.583504
# 2     tt0050652    3.586681   10.927030        20.424614        -2.285807
# 3     tt0051885    5.692213   10.103884        21.787266        -3.158614
# 4     tt0248123    5.052363   14.008677        19.101181        -5.684755
# ...         ...         ...         ...              ...              ...
# 3032  tt0238948    3.672903   13.673236        20.537290        -1.603543
# 3033  tt0406375    2.739948   14.026184        20.091590        -2.168772
# 3034  tt0063591    3.020100    9.555977        21.206562        -0.786693
# 3035  tt0119791    4.831091    9.789382        22.496815        -2.224130
# 3036  tt0492486    2.569802   12.533641        20.324760        -0.633298
#
#       overview_1st  overview_2nd               country          language  \
# 0         8.649476      3.307126                   USA           English
# 1        12.137049      4.244494               UK, USA           English
# 2         9.784697      2.606914                   USA           English
# 3        11.626658      0.298345                   USA           English
# 4        10.454543      5.274888               Germany            German
# ...            ...           ...                   ...               ...
# 3032     10.153371      1.411950                   USA  English, Spanish
# 3033      8.163801      0.694519                   USA           English
# 3034     11.498743      3.363511                   USA           English
# 3035     11.200775     -0.287683                   USA           English
# 3036      9.588804      0.534126  Ireland, UK, Denmark           English
#
#               director  ...  reviews_from_critics  popularity    genre_1  \
# 0      Lewis Milestone  ...                   6.0    0.389810  Adventure
# 1        Jill Sprecher  ...                  43.0    1.885671     Comedy
# 2          Henry Levin  ...                   8.0    0.127452      Drama
# 3       William Castle  ...                  22.0    0.837849     Horror
# 4      Christoph Stark  ...                   7.0    0.041677      Drama
# ...                ...  ...                   ...         ...        ...
# 3032      George Gallo  ...                  46.0    3.067916     Action
# 3033       Jon Favreau  ...                 132.0   10.695639     Action
# 3034       Alan Rafkin  ...                   8.0    1.053244     Action
# 3035      Ole Bornedal  ...                  52.0    6.122067      Drama
# 3036  Paddy Breathnach  ...                  96.0    9.128571     Comedy
#
#          genre_2    genre_3 recommendation1 recommendation2 recommendation3  \
# 0         Comedy    Romance       tt0019304       tt0019071       tt0018379
# 1          Drama        NaN       tt0116041       tt0114095       tt0119324
# 2        Western        NaN       tt0052877       tt0044683       tt0048707
# 3       Thriller        NaN       tt0047348       tt0054988       tt0060228
# 4        Romance        NaN       tt4326444      tt13279528       tt0072852
# ...          ...        ...             ...             ...             ...
# 3032      Comedy      Crime       tt0166195       tt4191580       tt0199290
# 3033   Adventure     Comedy       tt0398808       tt0416236       tt0113497
# 3034   Adventure     Comedy       tt0067219       tt0064606       tt0081376
# 3035      Horror   Thriller       tt0110631       tt0119535       tt0120662
# 3036      Horror    Mystery       tt0454224       tt2050633       tt0377749
#
#      recommendation4 recommendation5
# 0          tt0019429       tt0018526
# 1          tt3314958       tt1512240
# 2          tt0058286       tt0043079
# 3          tt0059821       tt0053931
# 4          tt0433770       tt0045942
# ...              ...             ...
# 3032       tt0119664       tt0101252
# 3033       tt0405325       tt1155076
# 3034       tt0077698       tt0052005
# 3035       tt4287464       tt0111149
# 3036       tt1398428       tt1718895
#
# [3037 rows x 21 columns]

# %% [markdown]
# ## Check movie id

# %%
ori_tid = model_data['id'].tolist()
imdb_tid = model_data[['recommendation1', 'recommendation2', 'recommendation3', 'recommendation4', 'recommendation5']].values.tolist()

# %%
np.squeeze(imdb_tid)
# Out:
# array([['tt0019304', 'tt0019071', 'tt0018379', 'tt0019429', 'tt0018526'],
#        ['tt0116041', 'tt0114095', 'tt0119324', 'tt3314958', 'tt1512240'],
#        ['tt0052877', 'tt0044683', 'tt0048707', 'tt0058286', 'tt0043079'],
#        ...,
#        ['tt0067219', 'tt0064606', 'tt0081376', 'tt0077698', 'tt0052005'],
#        ['tt0110631', 'tt0119535', 'tt0120662', 'tt4287464', 'tt0111149'],
#        ['tt0454224', 'tt2050633', 'tt0377749', 'tt1398428', 'tt1718895']],
#       dtype='<U32')

# %%
len(list(set([i for l in imdb_tid for i in l])))
# Out:
# 11341

# %%
imdb_id = list(set([i for l in imdb_tid for i in l]))

# %% [markdown]
# ## IMDB list exceeds training list ids

# %% [markdown]
# ## Only keep tid in ori_tid

# %%
imdb
# Out:
#              id recommendation1 recommendation2 recommendation3  \
# 0     tt0018515       tt0019304       tt0019071       tt0018379
# 1     tt0118866       tt0116041       tt0114095       tt0119324
# 2     tt0050652       tt0052877       tt0044683       tt0048707
# 3     tt0051885       tt0047348       tt0054988       tt0060228
# 4     tt0248123       tt4326444      tt13279528       tt0072852
# ...         ...             ...             ...             ...
# 3032  tt0238948       tt0166195       tt4191580       tt0199290
# 3033  tt0406375       tt0398808       tt0416236       tt0113497
# 3034  tt0063591       tt0067219       tt0064606       tt0081376
# 3035  tt0119791       tt0110631       tt0119535       tt0120662
# 3036  tt0492486       tt0454224       tt2050633       tt0377749
#
#      recommendation4 recommendation5 recommendation6 recommendation7  \
# 0          tt0019429       tt0018526       tt0019451       tt0019344
# 1          tt3314958       tt1512240       tt0268690       tt0443698
# 2          tt0058286       tt0043079       tt0051046       tt0051849
# 3          tt0059821       tt0053931       tt0055200       tt0052602
# 4          tt0433770       tt0045942       tt0402022       tt4048272
# ...              ...             ...             ...             ...
# 3032       tt0119664       tt0101252       tt0241760       tt0297181
# 3033       tt0405325       tt1155076       tt0373051       tt0963966
# 3034       tt0077698       tt0052005       tt0079754       tt0045589
# 3035       tt4287464       tt0111149       tt0108473       tt0403358
# 3036       tt1398428       tt1718895       tt0381966       tt0470000
#
#      recommendation8 recommendation9 recommendation10 recommendation11  \
# 0          tt0019553       tt0021890        tt0019824        tt0018054
# 1          tt0067350       tt0090037        tt5791216        tt0082220
# 2          tt0043276       tt0051496        tt0042426        tt0051848
# 3          tt0053363       tt0048190        tt0062909        tt0023790
# 4          tt9271164       tt0185125       tt15392100       tt11242218
# ...              ...             ...              ...              ...
# 3032       tt0472126       tt5304664        tt0410097        tt0421045
# 3033       tt1078912       tt0477347        tt0338348        tt0494238
# 3034       tt0091846       tt0047197        tt0067809        tt0043767
# 3035       tt0145531       tt0119675        tt0070444        tt0115744
# 3036       tt1204883       tt1601475        tt0227488        tt0449471
#
#      recommendation12
# 0           tt0018253
# 1           tt0068718
# 2           tt0051400
# 3           tt0053719
# 4           tt9203694
# ...               ...
# 3032        tt0119807
# 3033        tt0396752
# 3034        tt0065051
# 3035        tt0104549
# 3036        tt0899128
#
# [3037 rows x 13 columns]

# %%
for i in range(imdb.shape[0]):
    for j in range(1,13):
        if imdb.at[i, "recommendation"+str(j)] not in ori_tid:
            imdb.at[i, "recommendation"+str(j)] = "Missing"

# %%
imdb
# Out:
#              id recommendation1 recommendation2 recommendation3  \
# 0     tt0018515       tt0019304         Missing         Missing
# 1     tt0118866         Missing         Missing       tt0119324
# 2     tt0050652         Missing         Missing         Missing
# 3     tt0051885         Missing         Missing         Missing
# 4     tt0248123         Missing         Missing         Missing
# ...         ...             ...             ...             ...
# 3032  tt0238948         Missing         Missing         Missing
# 3033  tt0406375         Missing         Missing         Missing
# 3034  tt0063591         Missing         Missing       tt0081376
# 3035  tt0119791       tt0110631         Missing         Missing
# 3036  tt0492486         Missing         Missing         Missing
#
#      recommendation4 recommendation5 recommendation6 recommendation7  \
# 0            Missing         Missing         Missing         Missing
# 1            Missing         Missing         Missing         Missing
# 2            Missing         Missing         Missing         Missing
# 3            Missing         Missing         Missing       tt0052602
# 4            Missing         Missing         Missing         Missing
# ...              ...             ...             ...             ...
# 3032         Missing         Missing         Missing         Missing
# 3033         Missing         Missing         Missing         Missing
# 3034         Missing         Missing         Missing         Missing
# 3035         Missing         Missing         Missing       tt0403358
# 3036         Missing         Missing         Missing         Missing
#
#      recommendation8 recommendation9 recommendation10 recommendation11  \
# 0            Missing       tt0021890          Missing          Missing
# 1            Missing       tt0090037          Missing        tt0082220
# 2            Missing         Missing          Missing          Missing
# 3            Missing         Missing          Missing          Missing
# 4            Missing         Missing          Missing          Missing
# ...              ...             ...              ...              ...
# 3032         Missing         Missing          Missing        tt0421045
# 3033         Missing         Missing          Missing        tt0494238
# 3034         Missing         Missing          Missing          Missing
# 3035         Missing         Missing          Missing        tt0115744
# 3036         Missing         Missing          Missing          Missing
#
#      recommendation12
# 0             Missing
# 1           tt0068718
# 2             Missing
# 3             Missing
# 4             Missing
# ...               ...
# 3032          Missing
# 3033        tt0396752
# 3034          Missing
# 3035          Missing
# 3036          Missing
#
# [3037 rows x 13 columns]

# %%
count_miss = []
for i in range(imdb.shape[0]):
    count_miss.append(list(imdb.loc[i].values).count("Missing"))
count_miss
# Out:
# [10,
#  8,
#  12,
#  11,
#  12,
#  12,
#  11,
#  7,
#  10,
#  10,
#  12,
#  11,
#  11,
#  11,
#  11,
#  11,
#  9,
#  10,
#  10,
#  11,
#  12,
#  10,
#  11,
#  12,
#  10,
#  12,
#  11,
#  11,
#  12,
#  12,
#  10,
#  11,
#  10,
#  12,
#  12,
#  9,
#  11,
#  10,
#  11,
#  10,
#  10,
#  11,
#  10,
#  12,
#  12,
#  12,
#  11,
#  10,
#  11,
#  11,
#  9,
#  9,
#  11,
#  11,
#  11,
#  12,
#  12,
#  11,
#  11,
#  12,
#  12,
#  12,
#  9,
#  11,
#  12,
#  9,
#  10,
#  12,
#  12,
#  10,
#  11,
#  12,
#  11,
#  9,
#  10,
#  10,
#  9,
#  10,
#  10,
#  12,
#  12,
#  12,
#  10,
#  11,
#  11,
#  11,
#  11,
#  11,
#  10,
#  12,
#  10,
#  11,
#  10,
#  11,
#  12,
#  12,
#  12,
#  11,
#  11,
#  10,
#  9,
#  10,
#  12,
#  10,
#  9,
#  12,
#  12,
#  8,
#  12,
#  10,
#  8,
#  12,
#  10,
#  12,
#  11,
#  12,
#  12,
#  11,
#  10,
#  11,
#  11,
#  11,
#  11,
#  11,
#  10,
#  10,
#  8,
#  9,
#  12,
#  11,
#  11,
#  12,
#  12,
#  8,
#  9,
#  12,
#  11,
#  12,
#  12,
#  10,
#  12,
#  12,
#  9,
#  12,
#  12,
#  11,
#  11,
#  10,
#  11,
#  12,
#  11,
#  12,
#  10,
#  11,
#  12,
#  12,
#  12,
#  12,
#  12,
#  11,
#  10,
#  11,
#  12,
#  11,
#  11,
#  12,
#  11,
#  12,
#  10,
#  11,
#  9,
#  12,
#  11,
#  11,
#  11,
#  11,
#  11,
#  12,
#  12,
#  12,
#  11,
#  10,
#  9,
#  7,
#  10,
#  11,
#  12,
#  10,
#  11,
#  10,
#  9,
#  11,
#  9,
#  10,
#  11,
#  8,
#  11,
#  10,
#  12,
#  11,
#  10,
#  12,
#  12,
#  11,
#  12,
#  12,
#  11,
#  12,
#  9,
#  11,
#  12,
#  11,
#  11,
#  11,
#  12,
#  11,
#  12,
#  11,
#  11,
#  11,
#  11,
#  11,
#  10,
#  11,
#  12,
#  12,
#  12,
#  12,
#  10,
#  12,
#  9,
#  11,
#  10,
#  12,
#  9,
#  11,
#  12,
#  9,
#  12,
#  11,
#  12,
#  10,
#  10,
#  11,
#  12,
#  10,
#  12,
#  11,
#  11,
#  11,
#  11,
#  11,
#  12,
#  12,
#  12,
#  10,
#  12,
#  9,
#  11,
#  9,
#  10,
#  12,
#  10,
#  9,
#  10,
#  12,
#  12,
#  11,
#  12,
#  11,
#  10,
#  12,
#  11,
#  12,
#  11,
#  12,
#  10,
#  11,
#  11,
#  12,
#  10,
#  10,
#  11,
#  10,
#  11,
#  12,
#  10,
#  9,
#  10,
#  11,
#  12,
#  12,
#  10,
#  11,
#  10,
#  11,
#  12,
#  12,
#  12,
#  7,
#  10,
#  12,
#  11,
#  11,
#  12,
#  12,
#  11,
#  9,
#  11,
#  12,
#  10,
#  12,
#  12,
#  7,
#  10,
#  10,
#  9,
#  12,
#  11,
#  12,
#  12,
#  12,
#  9,
#  12,
#  9,
#  10,
#  11,
#  11,
#  12,
#  12,
#  12,
#  12,
#  12,
#  12,
#  11,
#  11,
#  12,
#  12,
#  10,
#  11,
#  9,
#  12,
#  11,
#  12,
#  11,
#  11,
#  11,
#  10,
#  12,
#  10,
#  11,
#  10,
#  11,
#  12,
#  11,
#  9,
#  10,
#  12,
#  12,
#  10,
#  11,
#  11,
#  10,
#  11,
#  8,
#  10,
#  10,
#  12,
#  11,
#  6,
#  12,
#  11,
#  10,
#  10,
#  10,
#  12,
#  12,
#  10,
#  12,
#  11,
#  12,
#  12,
#  10,
#  11,
#  11,
#  10,
#  12,
#  11,
#  11,
#  11,
#  10,
#  11,
#  12,
#  11,
#  12,
#  9,
#  10,
#  12,
#  11,
#  12,
#  12,
#  11,
#  12,
#  12,
#  12,
#  11,
#  12,
#  11,
#  12,
#  12,
#  11,
#  8,
#  11,
#  11,
#  12,
#  12,
#  12,
#  12,
#  10,
#  11,
#  11,
#  11,
#  7,
#  11,
#  11,
#  11,
#  11,
#  12,
#  12,
#  11,
#  11,
#  12,
#  12,
#  10,
#  12,
#  11,
#  12,
#  11,
#  9,
#  12,
#  9,
#  10,
#  10,
#  10,
#  12,
#  11,
#  11,
#  12,
#  11,
#  12,
#  11,
#  12,
#  12,
#  12,
#  11,
#  12,
#  11,
#  10,
#  9,
#  11,
#  11,
#  9,
#  12,
#  10,
#  12,
#  11,
#  12,
#  12,
#  11,
#  12,
#  11,
#  11,
#  12,
#  12,
#  11,
#  12,
#  11,
#  11,
#  8,
#  9,
#  12,
#  9,
#  10,
#  12,
#  12,
#  11,
#  11,
#  12,
#  12,
#  10,
#  11,
#  12,
#  11,
#  12,
#  11,
#  12,
#  12,
#  11,
#  10,
#  11,
#  12,
#  12,
#  11,
#  11,
#  9,
#  11,
#  11,
#  10,
#  11,
#  12,
#  11,
#  12,
#  8,
#  10,
#  12,
#  10,
#  10,
#  12,
#  11,
#  10,
#  9,
#  10,
#  10,
#  11,
#  12,
#  12,
#  12,
#  10,
#  12,
#  12,
#  11,
#  12,
#  11,
#  10,
#  12,
#  11,
#  12,
#  9,
#  10,
#  12,
#  12,
#  9,
#  12,
#  12,
#  12,
#  8,
#  12,
#  9,
#  11,
#  9,
#  12,
#  11,
#  10,
#  12,
#  12,
#  12,
#  9,
#  10,
#  10,
#  11,
#  10,
#  12,
#  12,
#  10,
#  11,
#  12,
#  10,
#  11,
#  12,
#  11,
#  11,
#  10,
#  12,
#  11,
#  11,
#  11,
#  12,
#  10,
#  12,
#  8,
#  9,
#  10,
#  12,
#  11,
#  11,
#  10,
#  12,
#  12,
#  12,
#  9,
#  10,
#  12,
#  12,
#  10,
#  9,
#  10,
#  12,
#  12,
#  12,
#  8,
#  8,
#  12,
#  12,
#  11,
#  10,
#  12,
#  12,
#  9,
#  10,
#  11,
#  11,
#  12,
#  10,
#  9,
#  12,
#  12,
#  11,
#  10,
#  11,
#  12,
#  12,
#  10,
#  11,
#  11,
#  10,
#  12,
#  11,
#  10,
#  9,
#  11,
#  11,
#  11,
#  8,
#  12,
#  12,
#  9,
#  12,
#  11,
#  11,
#  11,
#  12,
#  11,
#  8,
#  11,
#  10,
#  9,
#  11,
#  11,
#  10,
#  9,
#  9,
#  12,
#  11,
#  12,
#  12,
#  11,
#  10,
#  6,
#  11,
#  12,
#  11,
#  8,
#  12,
#  11,
#  10,
#  12,
#  9,
#  10,
#  11,
#  10,
#  9,
#  11,
#  11,
#  10,
#  10,
#  11,
#  11,
#  9,
#  11,
#  12,
#  12,
#  12,
#  12,
#  10,
#  12,
#  11,
#  12,
#  12,
#  11,
#  12,
#  12,
#  12,
#  12,
#  11,
#  12,
#  12,
#  10,
#  12,
#  11,
#  12,
#  12,
#  12,
#  11,
#  12,
#  8,
#  10,
#  11,
#  10,
#  10,
#  11,
#  12,
#  12,
#  12,
#  10,
#  12,
#  8,
#  11,
#  11,
#  12,
#  11,
#  11,
#  11,
#  11,
#  12,
#  12,
#  11,
#  11,
#  12,
#  10,
#  9,
#  10,
#  11,
#  11,
#  10,
#  12,
#  10,
#  10,
#  11,
#  10,
#  12,
#  11,
#  10,
#  11,
#  12,
#  11,
#  12,
#  12,
#  11,
#  10,
#  12,
#  10,
#  12,
#  10,
#  9,
#  11,
#  10,
#  12,
#  12,
#  10,
#  8,
#  11,
#  12,
#  12,
#  12,
#  11,
#  9,
#  11,
#  9,
#  10,
#  12,
#  11,
#  11,
#  12,
#  11,
#  10,
#  10,
#  11,
#  11,
#  12,
#  12,
#  12,
#  11,
#  11,
#  11,
#  12,
#  12,
#  10,
#  9,
#  12,
#  11,
#  12,
#  10,
#  10,
#  10,
#  10,
#  11,
#  12,
#  10,
#  11,
#  11,
#  11,
#  12,
#  12,
#  11,
#  8,
#  11,
#  11,
#  9,
#  12,
#  10,
#  12,
#  11,
#  10,
#  11,
#  11,
#  9,
#  11,
#  11,
#  12,
#  11,
#  11,
#  12,
#  11,
#  11,
#  12,
#  12,
#  12,
#  10,
#  9,
#  12,
#  12,
#  12,
#  11,
#  10,
#  11,
#  10,
#  10,
#  8,
#  11,
#  11,
#  12,
#  8,
#  12,
#  12,
#  12,
#  10,
#  11,
#  11,
#  12,
#  12,
#  12,
#  12,
#  11,
#  10,
#  11,
#  12,
#  11,
#  12,
#  9,
#  12,
#  9,
#  9,
#  12,
#  12,
#  9,
#  9,
#  12,
#  12,
#  12,
#  11,
#  12,
#  10,
#  11,
#  11,
#  11,
#  12,
#  12,
#  11,
#  12,
#  9,
#  12,
#  12,
#  11,
#  11,
#  11,
#  11,
#  11,
#  10,
#  12,
#  12,
#  12,
#  12,
#  11,
#  12,
#  9,
#  11,
#  11,
#  12,
#  9,
#  12,
#  11,
#  10,
#  12,
#  8,
#  11,
#  10,
#  11,
#  10,
#  12,
#  11,
#  9,
#  11,
#  11,
#  12,
#  9,
#  12,
#  9,
#  11,
#  11,
#  10,
#  11,
#  12,
#  10,
#  12,
#  12,
#  12,
#  12,
#  10,
#  11,
#  11,
#  12,
#  11,
#  12,
#  10,
#  11,
#  10,
#  11,
#  12,
#  9,
#  12,
#  10,
#  11,
#  10,
#  10,
#  10,
#  12,
#  12,
#  9,
#  12,
#  11,
#  11,
#  9,
#  9,
#  10,
#  9,
#  9,
#  11,
#  11,
#  11,
#  12,
#  10,
#  10,
#  12,
#  12,
#  7,
#  12,
#  11,
#  9,
#  12,
#  10,
#  11,
#  12,
#  11,
#  11,
#  12,
#  11,
#  12,
#  12,
#  10,
#  12,
#  11,
#  12,
#  10,
#  11,
#  10,
#  12,
#  9,
#  11,
#  9,
#  12,
#  12,
#  10,
#  11,
#  10,
#  10,
#  9,
#  12,
#  12,
#  8,
#  11,
#  ...]

# %%
np.max(count_miss)
# Out:
# 12

# %%
np.min(count_miss)
# Out:
# 6

# %%
imdb_sid = {}
for i in range(imdb.shape[0]):
    imdb_sid[imdb.at[i, 'id']] = [j for j in list(imdb.iloc[i, 1:13].values) if j != "Missing"]

# %%
imdb_sid
# Out:
# {'tt0018515': ['tt0019304', 'tt0021890'],
#  'tt0118866': ['tt0119324', 'tt0090037', 'tt0082220', 'tt0068718'],
#  'tt0050652': [],
#  'tt0051885': ['tt0052602'],
#  'tt0248123': [],
#  'tt0065755': [],
#  'tt0100263': ['tt0151137'],
#  'tt0045992': ['tt0043469',
#   'tt0046719',
#   'tt0039737',
#   'tt0043408',
#   'tt0043959'],
#  'tt0112443': ['tt0117193', 'tt0454839'],
#  'tt0235712': ['tt0218553', 'tt0367913'],
#  'tt0115685': [],
#  'tt0029952': ['tt0035659'],
#  'tt0114367': ['tt0106950'],
#  'tt0353489': ['tt0115610'],
#  'tt0044811': ['tt0038675'],
#  'tt0443584': ['tt0082054'],
#  'tt0115006': ['tt0100975', 'tt0080379', 'tt0108339'],
#  'tt0094375': ['tt0111800', 'tt0106937'],
#  'tt0118747': ['tt0109254', 'tt0090056'],
#  'tt0242527': ['tt0366627'],
#  'tt0466766': [],
#  'tt0374180': ['tt0100369', 'tt0115610'],
#  'tt0100369': ['tt0106950'],
#  'tt0122933': [],
#  'tt0089087': ['tt0082348', 'tt0093209'],
#  'tt0442781': [],
#  'tt0428856': ['tt0415932'],
#  'tt0914797': ['tt0212380'],
#  'tt0099316': [],
#  'tt0229480': [],
#  'tt0082677': ['tt0083336', 'tt0079240'],
#  'tt0067345': ['tt0073835'],
#  'tt0037386': ['tt0041247', 'tt0038107'],
#  'tt0073233': [],
#  'tt0111003': [],
#  'tt0105399': ['tt0103950', 'tt0108656', 'tt0098019'],
#  'tt0399327': ['tt0264472'],
#  'tt0168043': ['tt0220644', 'tt0374184'],
#  'tt0384177': ['tt0081182'],
#  'tt0084732': ['tt0119594', 'tt0166943'],
#  'tt0034182': ['tt0035369', 'tt0035244'],
#  'tt0113278': ['tt0102202'],
#  'tt0831888': ['tt0452039', 'tt0293416'],
#  'tt0211718': [],
#  'tt0119086': [],
#  'tt0120408': [],
#  'tt0029120': ['tt0048527'],
#  'tt0024894': ['tt0034398', 'tt0021814'],
#  'tt0119434': ['tt0127276'],
#  'tt0072933': ['tt0071464'],
#  'tt0221218': ['tt0118744', 'tt0880578', 'tt0486822'],
#  'tt0083798': ['tt0082894', 'tt0100212', 'tt0089628'],
#  'tt0369295': ['tt0367631'],
#  'tt0035244': ['tt0035369'],
#  'tt0091818': ['tt0097138'],
#  'tt0030287': [],
#  'tt0046878': [],
#  'tt0161292': ['tt0396184'],
#  'tt0002461': ['tt0006206'],
#  'tt0026942': [],
#  'tt0435286': [],
#  'tt0337876': [],
#  'tt0092644': ['tt0109254', 'tt0099044', 'tt0104714'],
#  'tt0052600': ['tt0053106'],
#  'tt0158714': [],
#  'tt0097498': ['tt0090837', 'tt0090094', 'tt0090627'],
#  'tt0089715': ['tt0078481', 'tt0116745'],
#  'tt0085750': [],
#  'tt0227277': [],
#  'tt0043469': ['tt0046719', 'tt0039737'],
#  'tt0036376': ['tt0034902'],
#  'tt0082892': [],
#  'tt0031742': ['tt0032728'],
#  'tt0120794': ['tt0138749', 'tt0118617', 'tt0114148'],
#  'tt0072342': ['tt0064106', 'tt0164368'],
#  'tt0048682': ['tt0049370', 'tt0052969'],
#  'tt0098157': ['tt0117609', 'tt0087998', 'tt0234748'],
#  'tt0104418': ['tt0096426', 'tt0110667'],
#  'tt0047542': ['tt0044789', 'tt0047370'],
#  'tt0101879': [],
#  'tt0254455': [],
#  'tt0073496': [],
#  'tt0076725': ['tt0077318', 'tt0079596'],
#  'tt0138703': ['tt0079714'],
#  'tt0072006': ['tt0072349'],
#  'tt0450232': ['tt0300556'],
#  'tt0438488': ['tt0093773'],
#  'tt0067367': ['tt0065851'],
#  'tt0029606': ['tt0047522', 'tt0030287'],
#  'tt0419677': [],
#  'tt0442933': ['tt0253556', 'tt0120657'],
#  'tt0075824': ['tt0071487'],
#  'tt0090037': ['tt0118866', 'tt0068718'],
#  'tt0097373': ['tt0097880'],
#  'tt0382295': [],
#  'tt0114369': [],
#  'tt0116729': [],
#  'tt0071746': ['tt0068327'],
#  'tt0044030': ['tt0043880'],
#  'tt0362270': ['tt0838221', 'tt0115734'],
#  'tt0028676': ['tt0036203', 'tt0035431', 'tt0030418'],
#  'tt0104573': ['tt0255819', 'tt0113118'],
#  'tt0435696': [],
#  'tt0087363': ['tt0084516', 'tt0091064'],
#  'tt0090357': ['tt0093260', 'tt0218182', 'tt0110197'],
#  'tt0126651': [],
#  'tt0970462': [],
#  'tt0768212': ['tt0760329', 'tt0457419', 'tt0970411', 'tt0494238'],
#  'tt0783532': [],
#  'tt0120723': ['tt0098645', 'tt0387514'],
#  'tt0253556': ['tt0120657', 'tt0296572', 'tt0119665', 'tt0298408'],
#  'tt0069404': [],
#  'tt0168501': ['tt0110186', 'tt0114885'],
#  'tt0101578': [],
#  'tt0048535': ['tt0048289'],
#  'tt0453467': [],
#  'tt0093502': [],
#  'tt0474642': ['tt0254455'],
#  'tt0072271': ['tt0083907', 'tt0092991'],
#  'tt0053183': ['tt0047376'],
#  'tt0018066': ['tt0021571'],
#  'tt0096163': ['tt0286751'],
#  'tt0035749': ['tt0036349'],
#  'tt0068327': ['tt0071746'],
#  'tt0095145': ['tt0097366', 'tt0092214'],
#  'tt0098165': ['tt0076868', 'tt0095488'],
#  'tt0119809': ['tt0112887', 'tt0127296', 'tt0370986', 'tt0780608'],
#  'tt0095662': ['tt0082121', 'tt0076106', 'tt0081562'],
#  'tt0423176': [],
#  'tt0330843': ['tt0986213'],
#  'tt0089565': ['tt0071464'],
#  'tt0095016': [],
#  'tt0210302': [],
#  'tt0079822': ['tt0012190', 'tt0082511', 'tt0088207', 'tt0047191'],
#  'tt0048954': ['tt0047688', 'tt0038116', 'tt0120321'],
#  'tt0411117': [],
#  'tt0031235': ['tt0040076'],
#  'tt0772200': [],
#  'tt0325596': [],
#  'tt0292490': ['tt0374887', 'tt0347304'],
#  'tt0104431': [],
#  'tt0209368': [],
#  'tt0079714': ['tt0138703', 'tt0095583', 'tt0083624'],
#  'tt0090186': [],
#  'tt0205461': [],
#  'tt0039204': ['tt0043625'],
#  'tt0244094': ['tt0120813'],
#  'tt0044209': ['tt0043643', 'tt0050271'],
#  'tt0053106': ['tt0052600'],
#  'tt0190798': [],
#  'tt0380066': ['tt0367153'],
#  'tt0063050': [],
#  'tt0032477': ['tt0047860', 'tt0039659'],
#  'tt0089853': ['tt0093818'],
#  'tt0084412': [],
#  'tt0103105': [],
#  'tt0022792': [],
#  'tt0210065': [],
#  'tt0037179': [],
#  'tt0064100': ['tt0065775'],
#  'tt0118819': ['tt0095675', 'tt0287467'],
#  'tt0052847': ['tt0051196'],
#  'tt0075669': [],
#  'tt0045631': ['tt0047370'],
#  'tt0246134': ['tt0489225'],
#  'tt0391728': [],
#  'tt0142242': ['tt0142236'],
#  'tt0101694': [],
#  'tt0106827': ['tt0092974', 'tt0129908'],
#  'tt0167132': ['tt0405743'],
#  'tt0131646': ['tt0101366', 'tt0119630', 'tt0185183'],
#  'tt0044170': [],
#  'tt0093201': ['tt0097910'],
#  'tt0049843': ['tt0051055'],
#  'tt0461769': ['tt0210302'],
#  'tt0044110': ['tt0043408'],
#  'tt0286261': ['tt0118818'],
#  'tt0119586': [],
#  'tt0080012': [],
#  'tt0404552': [],
#  'tt0112922': ['tt0168080'],
#  'tt0039029': ['tt0035659', 'tt0039896'],
#  'tt0283952': ['tt0107079', 'tt0110186', 'tt0255819'],
#  'tt0098347': ['tt0084412',
#   'tt0134619',
#   'tt0120835',
#   'tt0069226',
#   'tt0080945'],
#  'tt0050709': ['tt0050669', 'tt0044907'],
#  'tt0064363': ['tt0067112'],
#  'tt0960741': [],
#  'tt0077235': ['tt0065775', 'tt0079271'],
#  'tt0068168': ['tt0082220'],
#  'tt0498120': ['tt0119828', 'tt0072204'],
#  'tt0031387': ['tt0044406', 'tt0052602', 'tt0033787'],
#  'tt0870090': ['tt0293007'],
#  'tt0099044': ['tt0092644', 'tt0109254', 'tt0104114'],
#  'tt0035980': ['tt0034622', 'tt0028829'],
#  'tt0118632': ['tt0283897'],
#  'tt0076106': ['tt0082121', 'tt0072351', 'tt0074281', 'tt0095662'],
#  'tt0018836': ['tt0020589'],
#  'tt0022689': ['tt0064041', 'tt0023369'],
#  'tt0452694': [],
#  'tt0108071': ['tt0110367'],
#  'tt0120804': ['tt0318627', 'tt0320691'],
#  'tt0238119': [],
#  'tt0033174': [],
#  'tt0019304': ['tt0018515'],
#  'tt0362120': [],
#  'tt0450336': [],
#  'tt0104779': ['tt0070913'],
#  'tt0044391': [],
#  'tt0052782': ['tt0050381', 'tt0052604', 'tt0051951'],
#  'tt0087589': ['tt0083619'],
#  'tt0064310': [],
#  'tt0337909': ['tt0434124'],
#  'tt0098219': ['tt0089424'],
#  'tt0109195': ['tt0119013'],
#  'tt0065777': [],
#  'tt0066826': ['tt0044811'],
#  'tt0101545': [],
#  'tt0051629': ['tt0041253'],
#  'tt0067017': ['tt0065852'],
#  'tt0066921': ['tt0266697'],
#  'tt0478134': ['tt0419294'],
#  'tt0108188': ['tt0098360'],
#  'tt0126765': ['tt0408777', 'tt0326429'],
#  'tt0048750': ['tt0048728'],
#  'tt0046330': [],
#  'tt0497316': [],
#  'tt0387055': [],
#  'tt0069442': [],
#  'tt0389790': ['tt0358082', 'tt0351283'],
#  'tt0981072': [],
#  'tt0083960': ['tt0082350', 'tt0088936', 'tt0099399'],
#  'tt0026564': ['tt0029706'],
#  'tt0076068': ['tt0064787', 'tt0072349'],
#  'tt0120112': [],
#  'tt0036203': ['tt0040499', 'tt0033174', 'tt0031377'],
#  'tt0101700': ['tt0211915'],
#  'tt0078474': [],
#  'tt0097967': ['tt0087985', 'tt0084408', 'tt0094082'],
#  'tt0303970': [],
#  'tt0290329': ['tt0492784'],
#  'tt0455537': [],
#  'tt0129908': ['tt0106827', 'tt0092974'],
#  'tt0104952': ['tt0103241', 'tt0090685'],
#  'tt0033676': ['tt0030824'],
#  'tt0792966': [],
#  'tt0844286': ['tt0427470', 'tt0838221'],
#  'tt0100347': [],
#  'tt0884335': ['tt0300556'],
#  'tt0357668': ['tt0454824'],
#  'tt0103003': ['tt0119639'],
#  'tt0818165': ['tt0472259'],
#  'tt0099762': ['tt0069718'],
#  'tt0483812': [],
#  'tt0070679': [],
#  'tt0086189': [],
#  'tt0023940': ['tt0022074', 'tt0025464'],
#  'tt0071949': [],
#  'tt0080379': ['tt0080503', 'tt0082479', 'tt0081248'],
#  'tt0075334': ['tt0065851'],
#  'tt0046791': ['tt0042039', 'tt0038965', 'tt0047679'],
#  'tt0092240': ['tt0096426', 'tt0093560'],
#  'tt0836683': [],
#  'tt0095728': ['tt0086636', 'tt0085385'],
#  'tt0338094': ['tt0317303', 'tt0240462', 'tt0112642'],
#  'tt0181618': ['tt0018455', 'tt0063462'],
#  'tt0337585': [],
#  'tt0067732': [],
#  'tt0109445': ['tt0113749'],
#  'tt0484113': [],
#  'tt0065566': ['tt0064603'],
#  'tt0120747': ['tt0208196', 'tt0409681'],
#  'tt0084036': [],
#  'tt0261652': ['tt0159696'],
#  'tt0486822': [],
#  'tt0113749': ['tt0109445'],
#  'tt0816556': [],
#  'tt0063636': ['tt0068718', 'tt0039029'],
#  'tt0023369': ['tt0048527'],
#  'tt0062089': ['tt0063570'],
#  'tt0065700': [],
#  'tt0036349': ['tt0038008', 'tt0031022'],
#  'tt0081376': ['tt0063591', 'tt0035679'],
#  'tt0097008': ['tt0080100'],
#  'tt0075909': ['tt0073835', 'tt0079285'],
#  'tt0102057': ['tt0104431'],
#  'tt0106364': [],
#  'tt0988047': ['tt0443274', 'tt0963178'],
#  'tt0887883': ['tt0101410', 'tt0100150', 'tt0116282'],
#  'tt0086312': ['tt0084707', 'tt0089560'],
#  'tt0050737': ['tt0042428'],
#  'tt0120802': [],
#  'tt0299045': [],
#  'tt0085513': ['tt0062765', 'tt0085878'],
#  'tt0897347': ['tt0435528'],
#  'tt0036104': ['tt0037820', 'tt0038343'],
#  'tt0473514': ['tt0922642'],
#  'tt0119986': [],
#  'tt0044662': [],
#  'tt0250081': [],
#  'tt0970411': ['tt0760329',
#   'tt0457419',
#   'tt0494238',
#   'tt0406375',
#   'tt0449010'],
#  'tt0258967': ['tt0160620', 'tt0984200'],
#  'tt0808357': [],
#  'tt0086263': ['tt0108339'],
#  'tt0101414': ['tt0114148'],
#  'tt0094347': [],
#  'tt0284850': [],
#  'tt0074952': ['tt0073633'],
#  'tt0127311': ['tt0499262', 'tt0902955', 'tt0263438'],
#  'tt0043880': ['tt0044030'],
#  'tt0032186': [],
#  'tt0017416': ['tt0012675', 'tt0012190'],
#  'tt0047365': [],
#  'tt0040884': [],
#  'tt0091064': ['tt0084516',
#   'tt0097368',
#   'tt0087363',
#   'tt0083907',
#   'tt0092991'],
#  'tt0037820': ['tt0038343', 'tt0036104'],
#  'tt0292610': ['tt0218378', 'tt0367479'],
#  'tt0025464': ['tt0032617', 'tt0028505', 'tt0023305'],
#  'tt0093543': [],
#  'tt0307213': ['tt0497986'],
#  'tt0325005': [],
#  'tt0430651': [],
#  'tt0021730': [],
#  'tt0211915': ['tt0118799', 'tt0066921', 'tt0097165'],
#  'tt0042700': [],
#  'tt0101702': ['tt0099399', 'tt0092534', 'tt0087727'],
#  'tt0029761': ['tt0029675', 'tt0039169'],
#  'tt0020589': ['tt0020488'],
#  'tt0479965': ['tt0914797'],
#  'tt0069515': [],
#  'tt0323572': [],
#  'tt0425321': [],
#  'tt0034734': [],
#  'tt0116692': [],
#  'tt0357585': [],
#  'tt0118744': ['tt0221218'],
#  'tt0109936': ['tt0101745'],
#  'tt0145529': [],
#  'tt0048317': [],
#  'tt0104070': ['tt0161081', 'tt0120791'],
#  'tt0314121': ['tt0168080'],
#  'tt0040720': ['tt0037508', 'tt0047603', 'tt0043643'],
#  'tt0101465': [],
#  'tt0262246': ['tt0475783'],
#  'tt0209280': [],
#  'tt0088133': ['tt0089715'],
#  'tt0089283': ['tt0099606'],
#  'tt0022208': ['tt0023590'],
#  'tt0240913': ['tt0354356', 'tt0324133'],
#  'tt0077868': [],
#  'tt0086036': ['tt0094642', 'tt0097557'],
#  'tt0093773': ['tt0370263'],
#  'tt0117958': ['tt0119256', 'tt0162346'],
#  'tt0092972': ['tt0115751'],
#  'tt0159421': [],
#  'tt0120070': ['tt0169145'],
#  'tt0099108': ['tt0103773', 'tt0083624', 'tt0094057'],
#  'tt0119626': ['tt0190798', 'tt0320042'],
#  'tt0041550': [],
#  'tt0090251': [],
#  'tt0043910': ['tt0040971', 'tt0040499'],
#  'tt0084445': ['tt0096316'],
#  'tt0119773': ['tt0354356'],
#  'tt0026908': ['tt0024516', 'tt0025969'],
#  'tt0342167': ['tt0477078'],
#  'tt0081480': ['tt0095188', 'tt0097366', 'tt0080094', 'tt0090056'],
#  'tt0295427': ['tt0118539', 'tt0317303'],
#  'tt0488962': ['tt0115610', 'tt0353489'],
#  'tt0077588': [],
#  'tt0072785': ['tt0074740'],
#  'tt0087277': ['tt0077631',
#   'tt0099653',
#   'tt0076666',
#   'tt0091790',
#   'tt0103855',
#   'tt0086200'],
#  'tt0239986': [],
#  'tt0162973': ['tt0334754'],
#  'tt0101591': ['tt0212879', 'tt0090190'],
#  'tt0076513': ['tt0039819', 'tt0051724'],
#  'tt0160620': ['tt0152176', 'tt0258967'],
#  'tt0399901': [],
#  'tt0191636': [],
#  'tt0249371': ['tt0222024', 'tt0119861'],
#  'tt0490166': [],
#  'tt0211934': ['tt0119861'],
#  'tt0037746': [],
#  'tt0479773': [],
#  'tt0084786': ['tt0084945', 'tt0085470'],
#  'tt0486219': ['tt0370919'],
#  'tt0067315': ['tt0053106'],
#  'tt0088272': ['tt0074483', 'tt0100928'],
#  'tt0082509': [],
#  'tt0033436': ['tt0037027'],
#  'tt0088207': ['tt0090200'],
#  'tt0077413': ['tt0081163'],
#  'tt0095631': ['tt0113161', 'tt0104952'],
#  'tt0089798': ['tt0076666'],
#  'tt0113057': [],
#  'tt0116405': ['tt0090056'],
#  'tt0983909': [],
#  'tt0028597': ['tt0029284', 'tt0032599', 'tt0039169'],
#  'tt0062218': ['tt0048340', 'tt0049933'],
#  'tt0339230': [],
#  'tt0106375': ['tt0106701'],
#  'tt0236019': [],
#  'tt0443274': [],
#  'tt0072149': ['tt0095488'],
#  'tt0872022': [],
#  'tt0076716': [],
#  'tt0381716': [],
#  'tt0049271': ['tt0051525'],
#  'tt0126838': [],
#  'tt0373074': ['tt0116426'],
#  'tt0952682': [],
#  'tt0454435': [],
#  'tt0077272': ['tt0062863'],
#  'tt0317648': ['tt0253556', 'tt0800308', 'tt0399146', 'tt0120657'],
#  'tt0046161': ['tt0035429'],
#  'tt0041182': ['tt0034922'],
#  'tt0082783': [],
#  'tt0408777': [],
#  'tt0277027': [],
#  'tt0027700': [],
#  'tt0008879': ['tt0009652', 'tt0006206'],
#  'tt0099397': ['tt0119594'],
#  'tt0089686': ['tt0087298'],
#  'tt0080736': ['tt0087910'],
#  'tt0082121': ['tt0076106',
#   'tt0081562',
#   'tt0095662',
#   'tt0074281',
#   'tt0072351'],
#  'tt0037034': ['tt0037820'],
#  'tt0067893': ['tt0071424'],
#  'tt0117924': ['tt0160916'],
#  'tt0929261': ['tt0417976'],
#  'tt0239395': [],
#  'tt0081182': [],
#  'tt0040076': ['tt0041955'],
#  'tt0064019': ['tt0066413'],
#  'tt0454864': [],
#  'tt0029442': [],
#  'tt0118772': ['tt0119272', 'tt0105159'],
#  'tt0076162': [],
#  'tt0082136': ['tt0074279'],
#  'tt0379270': [],
#  'tt0074798': ['tt0070509'],
#  'tt0034303': ['tt0023369', 'tt0034012', 'tt0032617'],
#  'tt0459605': [],
#  'tt0103919': ['tt0112625', 'tt0072271', 'tt0083907'],
#  'tt0067525': ['tt0070909', 'tt0065462'],
#  'tt0431461': ['tt0391728', 'tt0453453'],
#  'tt0041955': ['tt0040076', 'tt0031235'],
#  'tt0418647': [],
#  'tt0099606': ['tt0089283'],
#  'tt0074279': ['tt0082136'],
#  'tt0067770': [],
#  'tt0092794': ['tt0096163'],
#  'tt0075815': [],
#  'tt0080002': ['tt0077868'],
#  'tt0090636': [],
#  'tt0040737': [],
#  'tt0250371': [],
#  'tt0088161': ['tt0086927'],
#  'tt0071282': [],
#  'tt0100681': ['tt0494271'],
#  'tt0162830': ['tt0322659', 'tt0118818'],
#  'tt0182789': ['tt0120716', 'tt0113986', 'tt0426931'],
#  'tt0066612': ['tt0074740'],
#  'tt0022905': ['tt0022208'],
#  'tt0048130': ['tt0049843', 'tt0038455', 'tt0047542'],
#  'tt0050669': [],
#  'tt0084707': ['tt0086312', 'tt0074119'],
#  'tt0036677': [],
#  'tt0119361': ['tt0256276'],
#  'tt0419663': [],
#  'tt0097244': [],
#  'tt0109785': ['tt0102469'],
#  'tt0076319': [],
#  'tt0081150': ['tt0082894'],
#  'tt0044941': ['tt0044896'],
#  'tt0053001': [],
#  'tt0098649': [],
#  'tt0438052': ['tt0265104'],
#  'tt0048990': [],
#  'tt0403692': ['tt0313550'],
#  'tt0158011': ['tt0096246'],
#  'tt0042279': ['tt0043469', 'tt0046198', 'tt0049933', 'tt0048340'],
#  'tt0022286': ['tt0021079', 'tt0023042', 'tt0020836'],
#  'tt0448400': [],
#  'tt0046446': ['tt0048527', 'tt0042544', 'tt0039357'],
#  'tt0063098': ['tt0035659', 'tt0044075'],
#  'tt0064177': [],
#  'tt0100258': [],
#  'tt0046998': ['tt0087144'],
#  'tt0374298': ['tt0403358'],
#  'tt0105271': [],
#  'tt0042229': [],
#  'tt0042039': ['tt0038492', 'tt0046791'],
#  'tt0121297': ['tt0068448'],
#  'tt0036709': [],
#  'tt0130623': ['tt0138749'],
#  'tt0028096': [],
#  'tt0074749': ['tt0090727'],
#  'tt0220806': [],
#  'tt0069289': [],
#  'tt0103790': ['tt0083260'],
#  'tt0052106': ['tt0046921', 'tt0044110'],
#  'tt0439662': ['tt0292490'],
#  'tt0386862': [],
#  'tt0074706': [],
#  'tt0020556': ['tt0049843'],
#  'tt0986213': ['tt0330843'],
#  'tt0067454': ['tt0064683', 'tt0365125', 'tt0111127'],
#  'tt0110516': ['tt0120683'],
#  'tt0347304': ['tt0248126'],
#  'tt0443072': ['tt0425236', 'tt0119773'],
#  'tt0294357': ['tt0218922'],
#  'tt0118929': [],
#  'tt0118571': ['tt0109444'],
#  'tt0330247': [],
#  'tt0050622': ['tt0049516', 'tt0035124', 'tt0047960', 'tt0047559'],
#  'tt0064603': ['tt0062737', 'tt0065566'],
#  'tt0463385': [],
#  'tt0037017': ['tt0042994', 'tt0048750'],
#  'tt0081070': ['tt0070077', 'tt0082220'],
#  'tt0119415': [],
#  'tt0795376': ['tt0372884'],
#  'tt0140352': ['tt0070666', 'tt0430357'],
#  'tt0902955': ['tt0499262', 'tt0263438', 'tt0127311'],
#  'tt0030302': ['tt0025410', 'tt0036677'],
#  'tt0087968': ['tt0090769', 'tt0104438'],
#  'tt0166110': ['tt0105128'],
#  'tt0286482': [],
#  'tt0040550': [],
#  'tt0364745': [],
#  'tt0095286': ['tt0097557', 'tt0089679'],
#  'tt0064265': [],
#  'tt0089385': [],
#  'tt0094226': ['tt0217505'],
#  'tt0072200': [],
#  'tt0032636': ['tt0032285'],
#  'tt0032617': ['tt0025464', 'tt0023305'],
#  'tt0364093': [],
#  'tt0038387': ['tt0033787'],
#  'tt0087837': [],
#  'tt0092690': ['tt0084788', 'tt0100608', 'tt0103671'],
#  'tt0300015': ['tt0450336', 'tt0337909'],
#  'tt0064860': [],
#  'tt0203343': [],
#  'tt0097557': ['tt0081515', 'tt0083959', 'tt0096426'],
#  'tt0050298': [],
#  'tt0192949': [],
#  'tt0069761': [],
#  'tt0030418': ['tt0028203', 'tt0024865', 'tt0030287', 'tt0033405'],
#  'tt0071402': [],
#  'tt0088680': ['tt0119485', 'tt0063803', 'tt0106226'],
#  'tt0069795': ['tt0074430'],
#  'tt0076301': ['tt0082220', 'tt0068245', 'tt0070509'],
#  'tt0299203': [],
#  'tt0079240': ['tt0066767'],
#  'tt0101455': ['tt0106701', 'tt0092638'],
#  'tt0375735': [],
#  'tt0039357': [],
#  'tt0039819': [],
#  'tt0162346': ['tt0335266', 'tt0305206', 'tt0364955'],
#  'tt0252480': ['tt0116261', 'tt0243609'],
#  'tt0188757': ['tt0073705', 'tt0119256'],
#  'tt0103923': ['tt0076009'],
#  'tt0017925': ['tt0018455', 'tt0041959'],
#  'tt0048517': [],
#  'tt0756618': [],
#  'tt0089114': ['tt0088979', 'tt0087065'],
#  'tt0367153': ['tt0074455'],
#  'tt0032007': [],
#  'tt0114496': ['tt0117002', 'tt0096037'],
#  'tt0796307': ['tt0318292'],
#  'tt0414426': [],
#  'tt0098257': ['tt0089539'],
#  'tt0100212': ['tt0083798'],
#  'tt0069097': ['tt0068555', 'tt0093818'],
#  'tt0028505': [],
#  'tt0063655': ['tt0077629'],
#  'tt0087130': ['tt0074226'],
#  'tt0031505': ['tt0039694'],
#  'tt0049026': [],
#  'tt0041959': ['tt0043014', 'tt0033870'],
#  'tt0120787': [],
#  'tt0214878': ['tt0094082', 'tt0067770', 'tt0324133', 'tt0110638'],
#  'tt0077617': ['tt0070653', 'tt0064397', 'tt0044110'],
#  'tt0152176': ['tt0160620', 'tt0212826'],
#  'tt0115759': [],
#  'tt0177749': ['tt0378906'],
#  'tt0943326': ['tt0089562'],
#  'tt0032599': ['tt0028597', 'tt0029284'],
#  'tt0031828': [],
#  'tt0132910': [],
#  'tt0325675': [],
#  'tt0069704': ['tt0074119', 'tt0075860', 'tt0084805'],
#  'tt0810868': ['tt0408777', 'tt0126765'],
#  'tt0120510': [],
#  'tt0218864': [],
#  'tt0035429': ['tt0046436', 'tt0045808'],
#  'tt0420294': ['tt0099994', 'tt0072271', 'tt0758746'],
#  'tt0098273': ['tt0067549', 'tt0070666'],
#  'tt0318292': [],
#  'tt0286751': [],
#  'tt0079191': [],
#  'tt0048729': ['tt0043961', 'tt0049933', 'tt0044573', 'tt0044110'],
#  'tt0080539': ['tt0087188', 'tt0093267', 'tt0064940', 'tt0044000'],
#  'tt0892255': [],
#  'tt0074174': [],
#  'tt0029578': ['tt0025725'],
#  'tt0044789': ['tt0047878', 'tt0041503'],
#  'tt0032414': [],
#  'tt0031406': [],
#  'tt0105435': ['tt0113161', 'tt0089118', 'tt0101745'],
#  'tt0067004': ['tt0072435', 'tt0063636'],
#  'tt0263438': ['tt0384116'],
#  'tt0029440': ['tt0042644'],
#  'tt0086148': [],
#  'tt0309698': ['tt0230600', 'tt0363988'],
#  'tt0028829': ['tt0035980', 'tt0034622', 'tt0029120'],
#  'tt0238883': [],
#  'tt0050091': [],
#  'tt0106701': ['tt0109813'],
#  'tt0023327': ['tt0023335', 'tt0023305'],
#  'tt0046198': ['tt0049933'],
#  'tt0145048': [],
#  'tt0127045': [],
#  'tt0109686': ['tt0109040', 'tt0116483'],
#  'tt0478829': ['tt0069404'],
#  'tt0117193': ['tt0112443'],
#  'tt0499262': ['tt0127311', 'tt0902955'],
#  'tt0084874': [],
#  'tt0065669': ['tt0072869'],
#  'tt0376196': ['tt0763840', 'tt0963965'],
#  'tt0080754': ['tt0064728', 'tt0049830', 'tt0340376'],
#  'tt0078111': ['tt0082054'],
#  'tt0082054': ['tt0078122'],
#  'tt0038965': ['tt0041487'],
#  'tt0426931': ['tt0182789', 'tt0762114', 'tt0120716', 'tt0473308'],
#  'tt0120680': [],
#  'tt0255665': [],
#  'tt0075845': ['tt0080442', 'tt0066471', 'tt0069761'],
#  'tt0346336': [],
#  'tt0064787': ['tt0067602'],
#  'tt0368658': ['tt0245046'],
#  'tt0084935': ['tt0092860'],
#  'tt0420251': [],
#  'tt0074483': ['tt0088272'],
#  'tt0029284': ['tt0039169', 'tt0028597', 'tt0034012', 'tt0044916'],
#  'tt0251736': ['tt0072271'],
#  'tt0984200': ['tt0967945', 'tt0119791'],
#  'tt0083959': ['tt0082431', 'tt0088379', 'tt0096246'],
#  'tt0027893': ['tt0036022'],
#  'tt0488174': ['tt0475783'],
#  'tt0052811': ['tt0062037', 'tt0069715'],
#  'tt0111127': ['tt0365125', 'tt0067454', 'tt0064683'],
#  'tt0402158': ['tt0337103', 'tt0237534', 'tt0108500'],
#  'tt0068912': [],
#  'tt0040087': ['tt0041487'],
#  'tt0026966': [],
#  'tt0293191': [],
#  'tt0089444': ['tt0086998'],
#  'tt0097165': ['tt0264464', 'tt0211915'],
#  'tt0043503': ['tt0044533',
#   'tt0047985',
#   'tt0044040',
#   'tt0037611',
#   'tt0039302',
#   'tt0037166'],
#  'tt0269217': ['tt0098360'],
#  'tt0050097': [],
#  'tt0064727': ['tt0062870'],
#  'tt0010060': ['tt0018455', 'tt0017416', 'tt0012190', 'tt0012675'],
#  'tt0144106': [],
#  'tt0045737': ['tt0067989'],
#  'tt0018773': ['tt0039631', 'tt0017925'],
#  'tt0488120': [],
#  'tt0080907': ['tt0064886', 'tt0062765', 'tt0068638'],
#  'tt0102569': ['tt0100369', 'tt0101591'],
#  'tt0088895': ['tt0089679'],
#  'tt0076933': ['tt0084049', 'tt0081562'],
#  'tt0118798': ['tt0077663', 'tt0071970', 'tt0113161'],
#  'tt0025935': ['tt0044075'],
#  'tt0367479': ['tt0137494'],
#  'tt0115886': ['tt0120013', 'tt0084728'],
#  'tt0050839': ['tt0044391', 'tt0051196'],
#  'tt0103617': ['tt0095382'],
#  'tt0217505': ['tt0407887'],
#  'tt0117609': ['tt0212879', 'tt0090190', 'tt0101591'],
#  'tt0111001': ['tt0119668'],
#  'tt0122111': [],
#  'tt0448154': [],
#  'tt0837803': [],
#  'tt0470765': [],
#  'tt0032152': ['tt0032828', 'tt0025590'],
#  'tt0238627': [],
#  'tt0116240': ['tt0109951'],
#  'tt0120856': [],
#  'tt0079648': [],
#  'tt0101902': ['tt0079826'],
#  'tt0088153': [],
#  'tt0034998': [],
#  'tt0482629': [],
#  'tt0036533': [],
#  'tt0410730': ['tt0212132'],
#  'tt0014945': [],
#  'tt0033388': [],
#  'tt0022979': ['tt0023629', 'tt0032285'],
#  'tt0901476': [],
#  'tt0094015': ['tt0095812'],
#  'tt0082886': [],
#  'tt0473360': [],
#  'tt0181602': [],
#  'tt0101745': ['tt0109936'],
#  'tt0316732': [],
#  'tt0074569': ['tt0104418', 'tt0111361', 'tt0066735', 'tt0081248'],
#  'tt0181689': ['tt0325710', 'tt0117060'],
#  'tt0047679': ['tt0034798'],
#  'tt0039725': ['tt0048527', 'tt0042544'],
#  'tt0107613': ['tt0102741', 'tt0098678'],
#  'tt0033606': ['tt0035369'],
#  'tt0246425': [],
#  'tt0160916': [],
#  'tt0071782': [],
#  'tt0811138': ['tt0799949', 'tt0105793'],
#  'tt0424273': [],
#  'tt0305224': ['tt0389860', 'tt0120484', 'tt0116483', 'tt0120888'],
#  'tt0109040': ['tt0109686'],
#  'tt0050168': ['tt0046436'],
#  'tt0022981': [],
#  'tt0243609': ['tt0252480'],
#  'tt0144117': ['tt0465602'],
#  'tt0094056': ['tt0104693'],
#  'tt0111216': ['tt0114367'],
#  'tt0068183': [],
#  'tt0867295': [],
#  'tt0052168': ['tt0067602'],
#  'tt0085375': ['tt0077235'],
#  'tt0115847': [],
#  'tt0048527': ['tt0042544', 'tt0039725'],
#  'tt0026139': ['tt0023305', 'tt0025028', 'tt0034622'],
#  'tt0109444': ['tt0164184', 'tt0118571'],
#  'tt0097991': ['tt0094374'],
#  'tt0112368': ['tt0127723'],
#  'tt0218553': ['tt0235712', 'tt0367913'],
#  'tt0790799': [],
#  'tt0042544': ['tt0048527', 'tt0039725'],
#  'tt0116378': ['tt0133122', 'tt0425236'],
#  'tt0093260': ['tt0089370'],
#  'tt0243222': ['tt0127296', 'tt0112887'],
#  'tt0439504': [],
#  'tt0061927': ['tt0062373'],
#  'tt0047189': ['tt0041550', 'tt0033787'],
#  'tt0073036': ['tt0064860'],
#  'tt0032728': [],
#  'tt0024625': ['tt0036349'],
#  'tt0094374': [],
#  'tt0181317': [],
#  'tt0865297': ['tt0258967'],
#  'tt0838221': ['tt0362270', 'tt0115734'],
#  'tt0027552': [],
#  'tt0092904': ['tt0094597', 'tt0094347'],
#  'tt0242508': [],
#  'tt0067377': ['tt0064886', 'tt0032599'],
#  'tt0080678': ['tt0100935', 'tt0116282', 'tt0460829'],
#  'tt0067921': ['tt0046719'],
#  'tt0186151': ['tt0366627', 'tt0453467'],
#  'tt0068687': [],
#  'tt0829297': [],
#  'tt0023305': ['tt0025464', 'tt0032617'],
#  'tt0064940': ['tt0087188', 'tt0080539', 'tt0093267', 'tt0044000'],
#  'tt0421715': ['tt0454921'],
#  'tt0260695': [],
#  'tt0104684': [],
#  'tt0016630': [],
#  'tt0080094': ['tt0081480'],
#  'tt0063803': ['tt0068309', 'tt0119485', 'tt0088680'],
#  'tt0106505': ['tt0134619'],
#  'tt0039737': ['tt0041253', 'tt0043469', 'tt0040720'],
#  'tt0462465': ['tt0120657', 'tt0253556'],
#  'tt0101529': [],
#  'tt0087144': ['tt0046998'],
#  'tt0081677': ['tt0074845'],
#  'tt0064451': [],
#  'tt0349079': ['tt0115751'],
#  'tt0111361': ['tt0393956', 'tt0084408'],
#  'tt0039871': ['tt0042958', 'tt0041699'],
#  'tt0422370': ['tt0378428'],
#  'tt0120716': ['tt0182789'],
#  'tt0284478': [],
#  'tt0030824': [],
#  'tt0078780': [],
#  'tt0064160': ['tt0073768'],
#  'tt0070928': ['tt0065566'],
#  'tt0094288': ['tt0091051'],
#  'tt0203940': [],
#  'tt0359564': [],
#  'tt0076661': ['tt0075439', 'tt0079484'],
#  'tt0041555': ['tt0037611', 'tt0082220', 'tt0039926'],
#  'tt0102855': [],
#  'tt0395424': ['tt0763840'],
#  'tt0117131': [],
#  'tt0092214': ['tt0080094', 'tt0101745'],
#  'tt0496350': ['tt0897347', 'tt0119791'],
#  'tt0027684': ['tt0032828', 'tt0024548'],
#  'tt0025590': ['tt0032152', 'tt0032828'],
#  'tt0027395': ['tt0026073'],
#  'tt0425326': [],
#  'tt0114465': ['tt0102940', 'tt0106315'],
#  'tt0283897': ['tt0118632'],
#  'tt0181530': ['tt0104507'],
#  'tt0363282': ['tt0361467'],
#  'tt0026656': [],
#  'tt0475783': [],
#  'tt0274155': ['tt0096386'],
#  'tt0080945': ['tt0086992', 'tt0069226', 'tt0098347', 'tt0120835'],
#  'tt0443456': ['tt0107613'],
#  'tt0162348': ['tt0363780'],
#  'tt0780567': ['tt0317303', 'tt0240462', 'tt0338094'],
#  'tt0356159': [],
#  'tt0901488': ['tt0168043', 'tt0414931'],
#  'tt0365183': [],
#  'tt0016039': ['tt0014945'],
#  'tt0100685': ['tt0085210', 'tt0120399'],
#  'tt0040092': ['tt0042477'],
#  'tt0033368': ['tt0049964'],
#  'tt0102741': ['tt0107613', 'tt0090886', 'tt0091653'],
#  'tt0018528': ['tt0018839'],
#  'tt0031831': ['tt0041487'],
#  'tt0312297': [],
#  'tt0062037': ['tt0052811'],
#  'tt0300957': ['tt0245910'],
#  'tt0855975': [],
#  'tt0839880': ['tt0922642'],
#  'tt0317887': ['tt0291003'],
#  'tt0064106': [],
#  'tt0303758': [],
#  'tt0062078': [],
#  'tt0020836': ['tt0021079', 'tt0022236'],
#  'tt0093818': ['tt0089853', 'tt0109348', 'tt0093940'],
#  'tt0367602': [],
#  'tt0116147': [],
#  'tt0382365': [],
#  'tt0208988': ['tt0111255'],
#  'tt0027189': ['tt0042428', 'tt0040321'],
#  'tt0017075': ['tt0017843'],
#  'tt0108187': ['tt0085384', 'tt0084814'],
#  'tt0062776': ['tt0064728', 'tt0098165'],
#  'tt0760329': ['tt0457419', 'tt0396752', 'tt0494238', 'tt0970411'],
#  'tt0026249': ['tt0029442'],
#  'tt0478303': ['tt0092240'],
#  'tt0115012': [],
#  'tt0120888': ['tt0120484', 'tt0116483', 'tt0389860', 'tt0305224'],
#  'tt0317950': [],
#  'tt0036929': [],
#  'tt0088885': [],
#  'tt0068231': ['tt0077904', 'tt0025037'],
#  'tt0102469': ['tt0101523'],
#  'tt0036367': ['tt0023973'],
#  'tt0100586': [],
#  'tt0075902': [],
#  'tt0845448': [],
#  'tt0487273': [],
#  'tt0357283': ['tt0104321'],
#  'tt0465602': ['tt0144117', 'tt0963178'],
#  'tt0074845': ['tt0081677'],
#  'tt0293007': [],
#  'tt0363303': ['tt0246266'],
#  'tt0841044': [],
#  'tt0370986': ['tt0112887', 'tt0119809', 'tt0127296'],
#  'tt0277663': [],
#  'tt0030265': ['tt0030418', 'tt0029442', 'tt0044533'],
#  'tt0035679': ['tt0033787', 'tt0023583', 'tt0052602'],
#  'tt0083885': [],
#  'tt0372478': [],
#  'tt0079596': ['tt0077318', 'tt0076725', 'tt0073540'],
#  'tt0108174': ['tt0103241', 'tt0105793', 'tt0104952'],
#  'tt0044202': [],
#  'tt0067656': [],
#  'tt0113617': [],
#  'tt0022958': ['tt0039416'],
#  'tt0083097': [],
#  'tt0107254': ['tt0087298', 'tt0758746'],
#  'tt0079484': ['tt0075439'],
#  'tt0016654': ['tt0017416'],
#  'tt0042702': ['tt0045737'],
#  'tt0050681': [],
#  'tt0293116': [],
#  'tt0215135': ['tt0093036'],
#  'tt0081541': [],
#  'tt0049516': ['tt0049370', 'tt0050622', 'tt0050545'],
#  'tt0386651': [],
#  'tt0097100': [],
#  'tt0178988': ['tt0187512'],
#  'tt0114266': ['tt0080728'],
#  'tt0039926': ['tt0037611'],
#  'tt0112302': ['tt0113755'],
#  'tt0377744': ['tt0091400'],
#  'tt0106598': ['tt0120484', 'tt0120888'],
#  'tt0206608': [],
#  'tt0414713': [],
#  'tt0018451': [],
#  'tt0275468': [],
#  'tt0051507': ['tt0049169'],
#  'tt0097889': [],
#  'tt0070511': ['tt0062765', 'tt0068638', 'tt0074119'],
#  'tt0367089': ['tt0119291'],
#  'tt0066195': ['tt0064418'],
#  'tt0071147': [],
#  'tt0043408': ['tt0044573', 'tt0046906', 'tt0049933'],
#  'tt0339071': [],
#  'tt0176016': ['tt0120787'],
#  'tt0095647': ['tt0096969', 'tt0094226'],
#  'tt0444849': [],
#  'tt0080895': ['tt0090886', 'tt0066195', 'tt0067112', 'tt0072362'],
#  'tt0065206': ['tt0065398'],
#  'tt0324133': ['tt0240913', 'tt0354356'],
#  'tt0046374': ['tt0033774'],
#  'tt0233699': ['tt0171356', 'tt0118002'],
#  'tt0063634': [],
#  'tt0128170': ['tt0285531'],
#  'tt0037027': ['tt0033436', 'tt0041098', 'tt0044320'],
#  'tt0472043': ['tt0898367'],
#  'tt0062385': ['tt0095900'],
#  'tt0062310': [],
#  'tt0384929': ['tt0398963', 'tt0361498', 'tt0487273'],
#  'tt0119994': [],
#  'tt0106950': ['tt0100369', 'tt0114367', 'tt0102034'],
#  'tt0015400': ['tt0018051'],
#  'tt0117826': ['tt0100740'],
#  'tt0089560': ['tt0086312', 'tt0094608'],
#  'tt0102536': ['tt0379217'],
#  'tt0131636': [],
#  'tt0082479': ['tt0081248', 'tt0080503'],
#  'tt0115678': [],
#  'tt0047956': [],
#  'tt0847050': [],
#  'tt0147192': [],
#  'tt0418689': ['tt0120863', 'tt0215750'],
#  'tt0271027': ['tt0865556'],
#  'tt0023973': ['tt0023028'],
#  'tt0168504': [],
#  'tt0047377': ['tt0047370'],
#  'tt0471011': [],
#  'tt0089572': ['tt0092783', 'tt0086356'],
#  'tt0086856': ['tt0084591'],
#  'tt0073911': ['tt0070077', 'tt0384177'],
#  'tt0100975': ['tt0115006'],
#  'tt0032254': [],
#  'tt0022236': ['tt0022208', 'tt0020836', 'tt0023590'],
#  'tt0265010': [],
#  'tt0047376': ['tt0053183', 'tt0062975'],
#  'tt0096316': ['tt0084445'],
#  'tt0093855': ['tt0094059', 'tt0093286'],
#  'tt0107711': ['tt0099385', 'tt0097138'],
#  'tt0072239': ['tt0076888', 'tt0075334'],
#  'tt0495040': [],
#  'tt0437857': [],
#  'tt0168794': ['tt0219333', 'tt0119598', 'tt0187995'],
#  'tt0031397': [],
#  'tt0084357': ['tt0065744'],
#  'tt0079826': ['tt0101902'],
#  'tt0042509': ['tt0052837', 'tt0039737', 'tt0038455'],
#  'tt0072362': ['tt0125128', 'tt0067112', 'tt0100049'],
#  'tt0231402': ['tt0099018', 'tt0089370'],
#  'tt0081562': ['tt0082121', 'tt0084049', 'tt0095662'],
#  'tt0068615': ['tt0075261', 'tt0075989', 'tt0074540'],
#  'tt0104142': ['tt0128278'],
#  'tt0101523': ['tt0102469'],
#  'tt0052611': ['tt0049169'],
#  'tt0072195': [],
#  'tt0034965': ['tt0032285', 'tt0023629'],
#  'tt0082340': ['tt0085333', 'tt0093777'],
#  'tt0120394': [],
#  'tt0167137': [],
#  'tt0116483': ['tt0120484',
#   'tt0120888',
#   'tt0389860',
#   'tt0838283',
#   'tt0364725'],
#  'tt0349333': [],
#  'tt0112619': ['tt0318292'],
#  'tt0329767': ['tt0339806', 'tt0161292', 'tt0855975'],
#  'tt0000574': [],
#  'tt0133197': ['tt0340376', 'tt0091164'],
#  'tt0092783': ['tt0089572'],
#  'tt0830558': [],
#  'tt0158983': ['tt0105793'],
#  'tt0064074': ['tt0063426'],
#  'tt0375568': [],
#  'tt0807054': ['tt0212826'],
#  'tt0365262': [],
#  'tt0451038': [],
#  'tt0101998': ['tt0074281', 'tt0074875'],
#  'tt0029322': [],
#  'tt0073705': ['tt0115964'],
#  'tt0041983': [],
#  'tt0041699': ['tt0042958', 'tt0039871'],
#  'tt0100633': ['tt0099250'],
#  'tt0076584': ['tt0074740', 'tt0076877'],
#  'tt0102489': [],
#  'tt0021931': ['tt0021890', 'tt0022074', 'tt0043625'],
#  'tt0038107': ['tt0044789'],
#  'tt0048512': ['tt0037075', 'tt0040087', 'tt0043503'],
#  'tt0361399': [],
#  'tt0443526': [],
#  'tt0119822': ['tt0337741', 'tt0099653'],
#  'tt0363771': ['tt0417741'],
#  'tt0084945': ['tt0086352', 'tt0085868'],
#  'tt0117373': ['tt0105175', 'tt0105108'],
#  'tt0039169': ['tt0029284', 'tt0028597', 'tt0044916'],
#  'tt0043045': [],
#  'tt0411270': [],
#  'tt0034012': ['tt0029284', 'tt0039169', 'tt0028597', 'tt0044916'],
#  'tt0086197': ['tt0074119'],
#  ...}

# %%
name = ["recommendation" + str(i) for i in range(1,7)]
df = pd.DataFrame.from_dict(imdb_sid, orient='index', columns= name)
df.reset_index(level=0, inplace=True)
df.rename(columns={'index':'id'}, inplace=True)

# %%
df
# Out:
#              id recommendation1 recommendation2 recommendation3  \
# 0     tt0018515       tt0019304       tt0021890            None
# 1     tt0118866       tt0119324       tt0090037       tt0082220
# 2     tt0050652            None            None            None
# 3     tt0051885       tt0052602            None            None
# 4     tt0248123            None            None            None
# ...         ...             ...             ...             ...
# 3032  tt0238948       tt0421045            None            None
# 3033  tt0406375       tt0494238       tt0396752            None
# 3034  tt0063591       tt0081376            None            None
# 3035  tt0119791       tt0110631       tt0403358       tt0115744
# 3036  tt0492486            None            None            None
#
#      recommendation4 recommendation5 recommendation6
# 0               None            None            None
# 1          tt0068718            None            None
# 2               None            None            None
# 3               None            None            None
# 4               None            None            None
# ...              ...             ...             ...
# 3032            None            None            None
# 3033            None            None            None
# 3034            None            None            None
# 3035            None            None            None
# 3036            None            None            None
#
# [3037 rows x 7 columns]

# %% [markdown]
# ## Merge again

# %%
model_data = movie_only.merge(df, how='left', on = 'id')
model_data.to_csv("Data/model_data.csv", index=False)

# %%
model_data
# Out:
#              id  review_1st  review_2nd  description_1st  description_2nd  \
# 0     tt0018515    4.942679   13.482060        17.669596        -0.738235
# 1     tt0118866    1.672779   11.368067        20.341370        -4.583504
# 2     tt0050652    3.586681   10.927030        20.424614        -2.285807
# 3     tt0051885    5.692213   10.103884        21.787266        -3.158614
# 4     tt0248123    5.052363   14.008677        19.101181        -5.684755
# ...         ...         ...         ...              ...              ...
# 3032  tt0238948    3.672903   13.673236        20.537291        -1.603543
# 3033  tt0406375    2.739948   14.026184        20.091591        -2.168772
# 3034  tt0063591    3.020100    9.555977        21.206562        -0.786693
# 3035  tt0119791    4.831090    9.789382        22.496815        -2.224130
# 3036  tt0492486    2.569802   12.533641        20.324760        -0.633298
#
#       overview_1st  overview_2nd               country          language  \
# 0         8.649476      3.307126                   USA           English
# 1        12.137049      4.244494               UK, USA           English
# 2         9.784697      2.606914                   USA           English
# 3        11.626658      0.298345                   USA           English
# 4        10.454543      5.274888               Germany            German
# ...            ...           ...                   ...               ...
# 3032     10.153371      1.411950                   USA  English, Spanish
# 3033      8.163801      0.694519                   USA           English
# 3034     11.498743      3.363511                   USA           English
# 3035     11.200775     -0.287683                   USA           English
# 3036      9.588804      0.534126  Ireland, UK, Denmark           English
#
#               director  ... popularity    genre_1     genre_2    genre_3  \
# 0      Lewis Milestone  ...    0.38981  Adventure      Comedy    Romance
# 1        Jill Sprecher  ...   1.885671     Comedy       Drama        NaN
# 2          Henry Levin  ...   0.127452      Drama     Western        NaN
# 3       William Castle  ...   0.837849     Horror    Thriller        NaN
# 4      Christoph Stark  ...   0.041677      Drama     Romance        NaN
# ...                ...  ...        ...        ...         ...        ...
# 3032      George Gallo  ...   3.067916     Action      Comedy      Crime
# 3033       Jon Favreau  ...  10.695639     Action   Adventure     Comedy
# 3034       Alan Rafkin  ...   1.053244     Action   Adventure     Comedy
# 3035      Ole Bornedal  ...   6.122067      Drama      Horror   Thriller
# 3036  Paddy Breathnach  ...   9.128571     Comedy      Horror    Mystery
#
#      recommendation1 recommendation2 recommendation3 recommendation4  \
# 0          tt0019304       tt0021890            None            None
# 1          tt0119324       tt0090037       tt0082220       tt0068718
# 2               None            None            None            None
# 3          tt0052602            None            None            None
# 4               None            None            None            None
# ...              ...             ...             ...             ...
# 3032       tt0421045            None            None            None
# 3033       tt0494238       tt0396752            None            None
# 3034       tt0081376            None            None            None
# 3035       tt0110631       tt0403358       tt0115744            None
# 3036            None            None            None            None
#
#      recommendation5 recommendation6
# 0               None            None
# 1               None            None
# 2               None            None
# 3               None            None
# 4               None            None
# ...              ...             ...
# 3032            None            None
# 3033            None            None
# 3034            None            None
# 3035            None            None
# 3036            None            None
#
# [3037 rows x 22 columns]

# %%
pd.set_option('display.max_columns', None)
pd.read_csv('Data/model_data.csv')
# Out:
#              id  review_1st  review_2nd  description_1st  description_2nd  \
# 0     tt0018515    4.942679   13.482060        17.669596        -0.738235
# 1     tt0118866    1.672779   11.368067        20.341370        -4.583504
# 2     tt0050652    3.586681   10.927030        20.424614        -2.285807
# 3     tt0051885    5.692213   10.103884        21.787266        -3.158614
# 4     tt0248123    5.052363   14.008677        19.101181        -5.684755
# ...         ...         ...         ...              ...              ...
# 3032  tt0238948    3.672903   13.673236        20.537290        -1.603543
# 3033  tt0406375    2.739948   14.026184        20.091590        -2.168772
# 3034  tt0063591    3.020100    9.555977        21.206562        -0.786693
# 3035  tt0119791    4.831091    9.789382        22.496815        -2.224130
# 3036  tt0492486    2.569802   12.533641        20.324760        -0.633298
#
#       overview_1st  overview_2nd               country          language  \
# 0         8.649476      3.307126                   USA           English
# 1        12.137049      4.244494               UK, USA           English
# 2         9.784697      2.606914                   USA           English
# 3        11.626658      0.298345                   USA           English
# 4        10.454543      5.274888               Germany            German
# ...            ...           ...                   ...               ...
# 3032     10.153371      1.411950                   USA  English, Spanish
# 3033      8.163801      0.694519                   USA           English
# 3034     11.498743      3.363511                   USA           English
# 3035     11.200775     -0.287683                   USA           English
# 3036      9.588804      0.534126  Ireland, UK, Denmark           English
#
#               director  votes  reviews_from_critics  popularity    genre_1  \
# 0      Lewis Milestone   3.35                   6.0    0.389810  Adventure
# 1        Jill Sprecher   6.05                  43.0    1.885671     Comedy
# 2          Henry Levin   6.25                   8.0    0.127452      Drama
# 3       William Castle   5.95                  22.0    0.837849     Horror
# 4      Christoph Stark   6.60                   7.0    0.041677      Drama
# ...                ...    ...                   ...         ...        ...
# 3032      George Gallo   5.50                  46.0    3.067916     Action
# 3033       Jon Favreau   6.15                 132.0   10.695639     Action
# 3034       Alan Rafkin   6.30                   8.0    1.053244     Action
# 3035      Ole Bornedal   6.20                  52.0    6.122067      Drama
# 3036  Paddy Breathnach   4.75                  96.0    9.128571     Comedy
#
#          genre_2    genre_3 recommendation1 recommendation2 recommendation3  \
# 0         Comedy    Romance       tt0019304       tt0021890             NaN
# 1          Drama        NaN       tt0119324       tt0090037       tt0082220
# 2        Western        NaN             NaN             NaN             NaN
# 3       Thriller        NaN       tt0052602             NaN             NaN
# 4        Romance        NaN             NaN             NaN             NaN
# ...          ...        ...             ...             ...             ...
# 3032      Comedy      Crime       tt0421045             NaN             NaN
# 3033   Adventure     Comedy       tt0494238       tt0396752             NaN
# 3034   Adventure     Comedy       tt0081376             NaN             NaN
# 3035      Horror   Thriller       tt0110631       tt0403358       tt0115744
# 3036      Horror    Mystery             NaN             NaN             NaN
#
#      recommendation4 recommendation5 recommendation6
# 0                NaN             NaN             NaN
# 1          tt0068718             NaN             NaN
# 2                NaN             NaN             NaN
# 3                NaN             NaN             NaN
# 4                NaN             NaN             NaN
# ...              ...             ...             ...
# 3032             NaN             NaN             NaN
# 3033             NaN             NaN             NaN
# 3034             NaN             NaN             NaN
# 3035             NaN             NaN             NaN
# 3036             NaN             NaN             NaN
#
# [3037 rows x 22 columns]
