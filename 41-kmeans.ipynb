# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt


from kneed import KneeLocator
from sklearn.datasets import make_blobs
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score
from sklearn.preprocessing import StandardScaler

# %%
cluster_1 = pd.read_csv("/Users/jaykim/Documents/Yeartwo/Case_studies/case2/Data/cluster16_kmode/Australia_English_Alex Proyas_Comedy.csv")
cluster_2 = pd.read_csv("/Users/jaykim/Documents/Yeartwo/Case_studies/case2/Data/cluster16_kmode/Japan_Japanese_Akira Kurosawa_Animation.csv")
cluster_3 = pd.read_csv("/Users/jaykim/Documents/Yeartwo/Case_studies/case2/Data/cluster16_kmode/UK, USA_English_James Ivory_Drama.csv")
cluster_4 = pd.read_csv("/Users/jaykim/Documents/Yeartwo/Case_studies/case2/Data/cluster16_kmode/USA_English, French_Alan Bunce_Horror.csv")
cluster_5 = pd.read_csv("/Users/jaykim/Documents/Yeartwo/Case_studies/case2/Data/cluster16_kmode/USA_English, German_Leslie Fenton_Drama.csv")
cluster_6 = pd.read_csv("/Users/jaykim/Documents/Yeartwo/Case_studies/case2/Data/cluster16_kmode/USA_English, German_Tim Blake Nelson_Drama.csv")
cluster_7 = pd.read_csv("/Users/jaykim/Documents/Yeartwo/Case_studies/case2/Data/cluster16_kmode/USA_English_Albert Pyun_Action.csv")
cluster_8 = pd.read_csv("/Users/jaykim/Documents/Yeartwo/Case_studies/case2/Data/cluster16_kmode/USA_English_Blake Edwards_Comedy.csv")
                    
cluster_9 = pd.read_csv("/Users/jaykim/Documents/Yeartwo/Case_studies/case2/Data/cluster16_kmode/USA_English_Charles Jarrott_Biography.csv")
cluster_10 = pd.read_csv("/Users/jaykim/Documents/Yeartwo/Case_studies/case2/Data/cluster16_kmode/USA_English_Fritz Lang_Crime.csv")
cluster_11 = pd.read_csv("/Users/jaykim/Documents/Yeartwo/Case_studies/case2/Data/cluster16_kmode/USA_English_Harry Basil_Comedy.csv")
cluster_12 = pd.read_csv("/Users/jaykim/Documents/Yeartwo/Case_studies/case2/Data/cluster16_kmode/USA_English_Joel Silberg_Comedy.csv")
cluster_13 = pd.read_csv("/Users/jaykim/Documents/Yeartwo/Case_studies/case2/Data/cluster16_kmode/USA_English_Joseph L. Mankiewicz_Crime.csv")
cluster_14 = pd.read_csv("/Users/jaykim/Documents/Yeartwo/Case_studies/case2/Data/cluster16_kmode/USA_English_Mark Robson_Drama.csv")
cluster_15 = pd.read_csv("/Users/jaykim/Documents/Yeartwo/Case_studies/case2/Data/cluster16_kmode/USA_English_Mikhail Kalatozov_Adventure.csv")
cluster_16 = pd.read_csv("/Users/jaykim/Documents/Yeartwo/Case_studies/case2/Data/cluster16_kmode/USA_English_Tobe Hooper_Horror.csv")

# %% [markdown]
# ### Cluster 1

# %%
#CLUSTER 1
X = cluster_1.iloc[: , 1:9]
wcss = [] 
for i in range(1, 9): 
    kmeans = KMeans(n_clusters = i, init = 'k-means++', random_state = 42)
    kmeans.fit(X) 
    wcss.append(kmeans.inertia_)
    
plt.plot(range(1, 9), wcss)
plt.xlabel('Number of clusters')
plt.ylabel('WCSS') 
plt.show()

kmeans = KMeans(n_clusters = 3, init = "k-means++", random_state = 42)
one_kmeans = kmeans.fit_predict(X)
one_kmeans

cluster_1['class'] = one_kmeans

# %% [markdown]
# # Cluster 2

# %%
#cluster_2.isnull().sum()
#np.where(cluster_2['reviews_from_critics'].isnull())
cluster_2= cluster_2.drop([ 5, 21])

#cluster_1.iloc[96: , 1:9]

# %%
X = cluster_2.iloc[: , 1:9]
wcss = [] 
for i in range(1, 9): 
    kmeans = KMeans(n_clusters = i, init = 'k-means++', random_state = 42)
    kmeans.fit(X) 
    wcss.append(kmeans.inertia_)
    
plt.plot(range(1, 9), wcss)
plt.xlabel('Number of clusters')
plt.ylabel('WCSS') 
plt.show()

kmeans = KMeans(n_clusters = 4, init = "k-means++", random_state = 42)
two_kmeans = kmeans.fit_predict(X)

cluster_2['class'] = two_kmeans

# %% [markdown]
# ### Cluster 3

# %%
cluster_3= cluster_3.drop(95)
#np.where(cluster_3['reviews_from_critics'].isnull())

# %%
#CLUSTER 3
X = cluster_3.iloc[: , 1:9]
wcss = [] 
for i in range(1, 9): 
    kmeans = KMeans(n_clusters = i, init = 'k-means++', random_state = 42)
    kmeans.fit(X) 
    wcss.append(kmeans.inertia_)
    
plt.plot(range(1, 9), wcss)
plt.xlabel('Number of clusters')
plt.ylabel('WCSS') 
plt.show()

kmeans = KMeans(n_clusters = 4, init = "k-means++", random_state = 42)
three_kmeans = kmeans.fit_predict(X)

cluster_3['class'] = three_kmeans

# %% [markdown]
# ### Cluster 4

# %%
#CLUSTER 4
X = cluster_4.iloc[: , 1:9]
wcss = [] 
for i in range(1, 9): 
    kmeans = KMeans(n_clusters = i, init = 'k-means++', random_state = 42)
    kmeans.fit(X) 
    wcss.append(kmeans.inertia_)
    
plt.plot(range(1, 9), wcss)
plt.xlabel('Number of clusters')
plt.ylabel('WCSS') 
plt.show()

kmeans = KMeans(n_clusters = 2, init = "k-means++", random_state = 42)
four_kmeans = kmeans.fit_predict(X)

cluster_4['class'] = four_kmeans

# %% [markdown]
# # Cluster 5

# %%
cluster_5
# Out:
#           id  review_1st  review_2nd  description_1st  description_2nd  \
# 0  tt0037386    5.223167   14.189524         17.36336        -1.299123
#
#    overview_1st  overview_2nd  votes  reviews_from_critics  popularity  \
# 0      8.347475       2.56148    6.5                  12.0    0.469587
#
#   recommendation1 recommendation2  recommendation3  recommendation4  \
# 0       tt0041247       tt0038107              NaN              NaN
#
#    recommendation5  recommendation6
# 0              NaN              NaN

# %% [markdown]
# # Cluster 6

# %%
X = cluster_6.iloc[: , 1:9]
wcss = [] 
for i in range(1, 9): 
    kmeans = KMeans(n_clusters = i, init = 'k-means++', random_state = 42)
    kmeans.fit(X) 
    wcss.append(kmeans.inertia_)
    
plt.plot(range(1, 9), wcss)
plt.xlabel('Number of clusters')
plt.ylabel('WCSS') 
plt.show()


kmeans = KMeans(n_clusters = 3, init = "k-means++", random_state = 42)
six_kmeans = kmeans.fit_predict(X)

cluster_6['class'] = six_kmeans

# %% [markdown]
# # Cluster 7

# %%
#cluster_7.isnull().sum()
#np.where(cluster_7['reviews_from_critics'].isnull())
#cluster_7 = cluster_7.iloc[5]
cluster_7 = cluster_7.drop(5)

# %%
X = cluster_7.iloc[: , 1:9]
wcss = [] 
for i in range(1, 9): 
    kmeans = KMeans(n_clusters = i, init = 'k-means++', random_state = 42)
    kmeans.fit(X) 
    wcss.append(kmeans.inertia_)
plt.plot(range(1, 9), wcss)
plt.xlabel('Number of clusters')
plt.ylabel('WCSS') 
plt.show()


kmeans = KMeans(n_clusters = 2, init = "k-means++", random_state = 42)
seven_kmeans = kmeans.fit_predict(X)

cluster_7['class'] = seven_kmeans

# %% [markdown]
# # 8

# %%
#np.where(cluster_8['reviews_from_critics'].isnull())
cluster_8= cluster_8.drop([ 41, 215, 281, 768, 830])

# %%
X = cluster_8.iloc[: , 1:9]
wcss = [] 
for i in range(1, 9): 
    kmeans = KMeans(n_clusters = i, init = 'k-means++', random_state = 42)
    kmeans.fit(X) 
    wcss.append(kmeans.inertia_)
plt.plot(range(1, 9), wcss)
plt.xlabel('Number of clusters')
plt.ylabel('WCSS') 
plt.show()

kmeans = KMeans(n_clusters = 3, init = "k-means++", random_state = 42)
eight_kmeans = kmeans.fit_predict(X)

cluster_8['class'] = eight_kmeans

# %% [markdown]
# # 9

# %%
X = cluster_9.iloc[: , 1:9]
wcss = [] 
for i in range(1, 9): 
    kmeans = KMeans(n_clusters = i, init = 'k-means++', random_state = 42)
    kmeans.fit(X) 
    wcss.append(kmeans.inertia_)
plt.plot(range(1, 9), wcss)
plt.xlabel('Number of clusters')
plt.ylabel('WCSS') 
plt.show()


kmeans = KMeans(n_clusters = 3, init = "k-means++", random_state = 42)
nine_kmeans = kmeans.fit_predict(X)

cluster_9['class'] = nine_kmeans

# %% [markdown]
# # 10

# %%
cluster_10.isnull().sum()
np.where(cluster_10['reviews_from_critics'].isnull())
cluster_10= cluster_10.drop(122)

# %%
X = cluster_10.iloc[: , 1:9]
wcss = [] 
for i in range(1, 9): 
    kmeans = KMeans(n_clusters = i, init = 'k-means++', random_state = 42)
    kmeans.fit(X) 
    wcss.append(kmeans.inertia_)
plt.plot(range(1, 9), wcss)
plt.xlabel('Number of clusters')
plt.ylabel('WCSS') 
plt.show()

kmeans = KMeans(n_clusters = 3, init = "k-means++", random_state = 42)
ten_kmeans = kmeans.fit_predict(X)

cluster_10['class'] = ten_kmeans

# %% [markdown]
# # clust 11

# %%
cluster_11
# Out:
#           id  review_1st  review_2nd  description_1st  description_2nd  \
# 0  tt0403946    0.438067   11.663147        18.994333         -3.26644
#
#    overview_1st  overview_2nd  votes  reviews_from_critics  popularity  \
# 0     11.685879      3.003973    4.2                   6.0    2.266472
#
#    recommendation1  recommendation2  recommendation3  recommendation4  \
# 0              NaN              NaN              NaN              NaN
#
#    recommendation5  recommendation6
# 0              NaN              NaN

# %% [markdown]
# # Cluster 12

# %%
cluster_12
# Out:
#           id  review_1st  review_2nd  description_1st  description_2nd  \
# 0  tt0086998    4.052832    12.53694        19.587532        -3.268003
#
#    overview_1st  overview_2nd  votes  reviews_from_critics  popularity  \
# 0     13.527758      1.889188    5.8                  31.0    2.598283
#
#   recommendation1  recommendation2  recommendation3  recommendation4  \
# 0       tt0089444              NaN              NaN              NaN
#
#    recommendation5  recommendation6
# 0              NaN              NaN

# %% [markdown]
# # Cluster 13

# %%
cluster_13
# Out:
#           id  review_1st  review_2nd  description_1st  description_2nd  \
# 0  tt0038965    3.324017   12.474213        21.676123        -1.748538
# 1  tt0041487    0.726229   12.790117        21.064900        -2.086994
#
#    overview_1st  overview_2nd  votes  reviews_from_critics  popularity  \
# 0     11.242948      1.214908   6.55                  27.0    1.194854
# 1     10.730624      2.127908   6.45                  18.0    1.585850
#
#   recommendation1 recommendation2  recommendation3  recommendation4  \
# 0       tt0041487             NaN              NaN              NaN
# 1       tt0038965       tt0040087              NaN              NaN
#
#    recommendation5  recommendation6
# 0              NaN              NaN
# 1              NaN              NaN

# %% [markdown]
# # cluster 14

# %%
cluster_14.isnull().sum()
np.where(cluster_14['reviews_from_critics'].isnull())
cluster_14= cluster_14.drop([132, 227])

# %%
X = cluster_14.iloc[: , 1:9]
wcss = [] 
for i in range(1, 9): 
    kmeans = KMeans(n_clusters = i, init = 'k-means++', random_state = 42)
    kmeans.fit(X) 
    wcss.append(kmeans.inertia_)
plt.plot(range(1, 9), wcss)
plt.xlabel('Number of clusters')
plt.ylabel('WCSS') 
plt.show()

kmeans = KMeans(n_clusters = 3, init = "k-means++", random_state = 42)
fourteen_kmeans = kmeans.fit_predict(X)

cluster_14['class'] = fourteen_kmeans

# %% [markdown]
# # Clooster 15

# %%
#np.where(cluster_15['reviews_from_critics'].isnull())
cluster_15= cluster_15.drop([ 27, 102])

# %%
X = cluster_15.iloc[: , 1:9]
wcss = [] 
for i in range(1, 9): 
    kmeans = KMeans(n_clusters = i, init = 'k-means++', random_state = 42)
    kmeans.fit(X) 
    wcss.append(kmeans.inertia_)
plt.plot(range(1, 9), wcss)
plt.xlabel('Number of clusters')
plt.ylabel('WCSS') 
plt.show()

kmeans = KMeans(n_clusters = 4, init = "k-means++", random_state = 42)
fifteen = kmeans.fit_predict(X)

cluster_15['class'] = fifteen

# %% [markdown]
# # Cluster 16!

# %%
X = cluster_16.iloc[: , 1:9]
wcss = [] 
for i in range(1, 9): 
    kmeans = KMeans(n_clusters = i, init = 'k-means++', random_state = 42)
    kmeans.fit(X) 
    wcss.append(kmeans.inertia_)
plt.plot(range(1, 9), wcss)
plt.xlabel('Number of clusters')
plt.ylabel('WCSS') 
plt.show()

kmeans = KMeans(n_clusters = 4, init = "k-means++", random_state = 42)
sixteen = kmeans.fit_predict(X)

cluster_16['class'] = sixteen
