# %% [markdown]
# # 22-IMDB-web-grabbing

# %% [markdown]
# > This notebook is to build a web scraper for IMDB more like this section.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import re

import requests
from bs4 import BeautifulSoup
import timeit
import json

# %% [markdown]
# ## Import main data

# %%
main = pd.read_csv('Data/main_211110.csv', dtype=str)
main
# Out:
#       Unnamed: 0         id  \
# 0              0  tt0018515
# 1              1  tt0018515
# 2              2  tt0018515
# 3              3  tt0018515
# 4              4  tt0018515
# ...          ...        ...
# 28624      28624  tt0492486
# 28625      28625  tt0492486
# 28626      28626  tt0492486
# 28627      28627  tt0492486
# 28628      28628  tt0492486
#
#                                                   review  review_1st  \
# 0      I admit, the great majority of films released ...   1.6660906
# 1      This is a very strange film that was long thou...   2.6453724
# 2      William Boyd and Louis Wolheim are the "Two Ar...  -0.4441953
# 3      Not very many movies come to my mind that cove...   0.8150438
# 4      The third movie produced by Howard Hughes, thi...    2.477075
# ...                                                  ...         ...
# 28624  This was the surprise film at the Dublin Horro...   1.0869972
# 28625  I've seen hundreds of horror movies in my life...  0.17316706
# 28626  I cannot remember the last time a horror movie...   1.0682999
# 28627  I saw this movie tonight. Never have left comm...   1.0295599
# 28628  Shrooms basically is a Slasher Movie. 3 couple...   1.0787203
#
#       review_2nd       original_title  year date_published duration  \
# 0      1.7079178  Two Arabian Knights  1927     1927-09-23       92
# 1       5.547905  Two Arabian Knights  1927     1927-09-23       92
# 2      2.2827504  Two Arabian Knights  1927     1927-09-23       92
# 3      3.9238899  Two Arabian Knights  1927     1927-09-23       92
# 4       5.466526  Two Arabian Knights  1927     1927-09-23       92
# ...          ...                  ...   ...            ...      ...
# 28624   6.843044              Shrooms  2007     2008-08-22       84
# 28625    6.62107              Shrooms  2007     2008-08-22       84
# 28626   6.835441              Shrooms  2007     2008-08-22       84
# 28627  3.5069268              Shrooms  2007     2008-08-22       84
# 28628   6.848455              Shrooms  2007     2008-08-22       84
#
#                     country  ... popularity                       poster_path  \
# 0                       USA  ...    0.38981  /mGZ3EgmkDesKEA8FnJcUgX8TpXT.jpg
# 1                       USA  ...    0.38981  /mGZ3EgmkDesKEA8FnJcUgX8TpXT.jpg
# 2                       USA  ...    0.38981  /mGZ3EgmkDesKEA8FnJcUgX8TpXT.jpg
# 3                       USA  ...    0.38981  /mGZ3EgmkDesKEA8FnJcUgX8TpXT.jpg
# 4                       USA  ...    0.38981  /mGZ3EgmkDesKEA8FnJcUgX8TpXT.jpg
# ...                     ...  ...        ...                               ...
# 28624  Ireland, UK, Denmark  ...   9.128571  /hPzqg3NTDaW6y7L0QCBxMxhOQjK.jpg
# 28625  Ireland, UK, Denmark  ...   9.128571  /hPzqg3NTDaW6y7L0QCBxMxhOQjK.jpg
# 28626  Ireland, UK, Denmark  ...   9.128571  /hPzqg3NTDaW6y7L0QCBxMxhOQjK.jpg
# 28627  Ireland, UK, Denmark  ...   9.128571  /hPzqg3NTDaW6y7L0QCBxMxhOQjK.jpg
# 28628  Ireland, UK, Denmark  ...   9.128571  /hPzqg3NTDaW6y7L0QCBxMxhOQjK.jpg
#
#          revenue runtime    status  video vote_count    genre_1  genre_2  \
# 0            0.0    92.0  Released  False        0.0  Adventure   Comedy
# 1            0.0    92.0  Released  False        0.0  Adventure   Comedy
# 2            0.0    92.0  Released  False        0.0  Adventure   Comedy
# 3            0.0    92.0  Released  False        0.0  Adventure   Comedy
# 4            0.0    92.0  Released  False        0.0  Adventure   Comedy
# ...          ...     ...       ...    ...        ...        ...      ...
# 28624  4910682.0    84.0  Released  False       99.0     Comedy   Horror
# 28625  4910682.0    84.0  Released  False       99.0     Comedy   Horror
# 28626  4910682.0    84.0  Released  False       99.0     Comedy   Horror
# 28627  4910682.0    84.0  Released  False       99.0     Comedy   Horror
# 28628  4910682.0    84.0  Released  False       99.0     Comedy   Horror
#
#         genre_3
# 0       Romance
# 1       Romance
# 2       Romance
# 3       Romance
# 4       Romance
# ...         ...
# 28624   Mystery
# 28625   Mystery
# 28626   Mystery
# 28627   Mystery
# 28628   Mystery
#
# [28629 rows x 35 columns]

# %%
URL = "https://www.imdb.com/title/tt0118866/"
page = requests.get(URL)

soup = BeautifulSoup(page.content, "html.parser")

rels = soup.find_all("a", class_="ipc-poster-card__title ipc-poster-card__title--clamp-2 ipc-poster-card__title--clickable")

for rel in rels:
    link = rel.get("href")
    title = rel.find("span").text
    
    print(title, link)
# Out:
# The Daytrippers /title/tt0116041/?ref_=tt_sims_tt_t_1
# Party Girl /title/tt0114095/?ref_=tt_sims_tt_t_2
# The House of Yes /title/tt0119324/?ref_=tt_sims_tt_t_3
# Mala Mala /title/tt3314958/?ref_=tt_sims_tt_t_4
# Thin Ice /title/tt1512240/?ref_=tt_sims_tt_t_5
# Thirteen Conversations About One Thing /title/tt0268690/?ref_=tt_sims_tt_t_6
# William Eggleston in the Real World /title/tt0443698/?ref_=tt_sims_tt_t_7
# Little Murders /title/tt0067350/?ref_=tt_sims_tt_t_8
# Smooth Talk /title/tt0090037/?ref_=tt_sims_tt_t_9
# Flames /title/tt5791216/?ref_=tt_sims_tt_t_10
# Cutter's Way /title/tt0082220/?ref_=tt_sims_tt_t_11
# The Hot Rock /title/tt0068718/?ref_=tt_sims_tt_t_12

# %%
href = "/title/tt0116041/?ref_=tt_sims_tt_t_1"
href[6:]
re.search(r'\/(.*?)\/', href[6:]).group(1)
# Out:
# 'tt0116041'

# %%
unique_id = main['id'].unique()
len(unique_id)
# Out:
# 3037

# %%
start = timeit.default_timer()

tid_likes = {}
for i in range(len(unique_id)):
    tid = unique_id[i]
    URL = "https://www.imdb.com/title/" + tid + "/"
    page = requests.get(URL)

    soup = BeautifulSoup(page.content, "html.parser")

    rels = soup.find_all("a", class_="ipc-poster-card__title ipc-poster-card__title--clamp-2 ipc-poster-card__title--clickable")
    
    links = []
    for rel in rels:
        href = rel.get("href")
        links.append(re.search(r'\/(.*?)\/', href[6:]).group(1))
    
    tid_likes[tid] = links

stop = timeit.default_timer()

print('Time: ', stop - start)

# %%
start = timeit.default_timer()

tid_likes = {}
for i in range(len(unique_id)):
    tid = unique_id[i]
    URL = "https://www.imdb.com/title/" + tid + "/"
    page = requests.get(URL)

    soup = BeautifulSoup(page.content, "html.parser")

    rels = soup.find_all("a", class_="ipc-poster-card__title ipc-poster-card__title--clamp-2 ipc-poster-card__title--clickable")
    
    titles = []
    for rel in rels:
        titles.append(rel.find("span").text)
    
    tid_likes[tid] = titles

stop = timeit.default_timer()

print('Time: ', stop - start)
# Out:
# Time:  5515.419064625865

# %%
5515/3600
# Out:
# 1.5319444444444446

# %%
len(tid_likes)
# Out:
# 3037

# %%
with open('Data/imdb_truth.json', 'w') as fp:
    json.dump(tid_likes, fp)

# %%
with open('Data/imdb_truth.json', 'r') as fp:
    data = json.load(fp)

# %%
data
# Out:
# {'tt0018515': ['The Racket',
#   '7th Heaven',
#   'The Last Command',
#   'Street Angel',
#   'Sadie Thompson',
#   'Underworld',
#   'Tempest',
#   'The Way of All Flesh',
#   'The Front Page',
#   'The Divine Lady',
#   'The Patent Leather Kid',
#   'The Love Parade'],
#  'tt0118866': ['The Daytrippers',
#   'Party Girl',
#   'The House of Yes',
#   'Thirteen Conversations About One Thing',
#   'Thin Ice',
#   'Flames',
#   'William Eggleston in the Real World',
#   'Smooth Talk',
#   'What Happened Was...',
#   'Mala Mala',
#   'The Hot Rock',
#   "Cutter's Way"],
#  'tt0050652': ['The Hangman',
#   "Hangman's Knot",
#   "Tennessee's Partner",
#   'The Tall Stranger',
#   'Law of the Lawless',
#   'Cowboy',
#   'The Eagle and the Hawk',
#   'Along the Great Divide',
#   'The Law and Jake Wade',
#   'This Angry Age',
#   'Django Kill... If You Live, Shoot!',
#   'Three Violent People'],
#  'tt0051885': ['Homicidal',
#   'Phantom of the Rue Morgue',
#   'Mr. Sardonicus',
#   'The Tomb of Ligeia',
#   '13 Ghosts',
#   'The Tingler',
#   'I Died a Thousand Times',
#   'I Bury the Living',
#   'The Old Dark House',
#   'The Bat',
#   'The Night Walker',
#   'The Earth Dies Screaming'],
#  'tt0248123': ['Julieta',
#   'Allein',
#   'What We Wanted',
#   'Julietta',
#   'Freigesprochen',
#   'Only Mine',
#   'Toni Erdmann',
#   'All About My Mother',
#   'The Billion Dollar Code',
#   'Stowaway'],
#  'tt0065755': ['Gamera vs. Gyaos',
#   'Gamera vs. Guiron',
#   'Gamera vs. Viras',
#   'Gamera vs. Zigra',
#   'Gamera the Brave',
#   'Gamera: Super Monster',
#   'Rebirth of Mothra',
#   'All Monsters Attack',
#   'Gammera the Invincible',
#   'Godzilla vs. Gigan',
#   'Godzilla vs. Megalon',
#   'The Mysterians'],
#  'tt0100263': ['The Big Blue',
#   'Point of No Return',
#   'Subway',
#   'La Femme Nikita',
#   'The Messenger: The Story of Joan of Arc',
#   'The Fifth Element',
#   'Taxi',
#   'Wasabi',
#   'Angel-A',
#   'Nikita',
#   'Anna',
#   'Atlantis'],
#  'tt0045992': ['Gun Fury',
#   'The Man from the Alamo',
#   'Horizons West',
#   'The Cimarron Kid',
#   'Apache',
#   'Vengeance Valley',
#   'Only the Valiant',
#   'Rawhide',
#   'Cimarron',
#   'Seminole',
#   'Garden of Evil',
#   'Saskatchewan'],
#  'tt0112443': ['Off Limits',
#   'Desperate Hours',
#   'Sacrifice',
#   'No Way Back',
#   'Criminal Law',
#   'Red Sands',
#   'Bad Company',
#   'Broken',
#   'Perfect Creature',
#   'The Escapist',
#   'The Padre',
#   'The Hamiltons'],
#  'tt0235712': ['Ring 2',
#   'Spiral',
#   'Ringu',
#   'Ju-On: The Grudge 2',
#   'Ring',
#   'The Ring Virus',
#   'Sadako vs. Kayako',
#   'Sadako 3D',
#   'Ju-on: The Curse',
#   'Ju-on: The Curse 2',
#   'Ju-on: The Grudge',
#   'Sadako 2 3D'],
#  'tt0115685': ['To Wong Foo, Thanks for Everything! Julie Newmar',
#   'Good Morning, Vietnam',
#   'A League of Their Own',
#   'La Cage aux Folles',
#   'The First Wives Club',
#   'In & Out',
#   'A Fish Called Wanda',
#   '9 to 5',
#   'Steel Magnolias',
#   'Fried Green Tomatoes',
#   'Grumpy Old Men',
#   'My Big Fat Greek Wedding'],
#  'tt0029952': ["Bulldog Drummond's Bride",
#   "Bulldog Drummond's Secret Police",
#   "Bulldog Drummond's Revenge",
#   'Bulldog Drummond in Africa',
#   'Bulldog Drummond Comes Back',
#   'Bulldog Drummond Escapes',
#   'Arrest Bulldog Drummond',
#   'The Return of Bulldog Drummond',
#   'The Hound of the Baskervilles',
#   'Bulldog Drummond Strikes Back',
#   'Nancy Drew... Reporter',
#   'The Saint Strikes Back'],
#  'tt0114367': ['Screamers: The Hunting',
#   'Deep Rising',
#   'Impostor',
#   'Leviathan',
#   'Virus',
#   'Mimic',
#   'The Relic',
#   'Fortress',
#   'Split Second',
#   'Below',
#   'Phantoms',
#   'DeepStar Six'],
#  'tt0353489': ['Ginger Snaps Back: The Beginning',
#   'Ginger Snaps',
#   'Ginger Snaps: Blood, Teeth and Fur',
#   'American Mary',
#   'May',
#   'Dog Soldiers',
#   'Bad Moon',
#   'Cursed',
#   "Blood: A Butcher's Tale",
#   'The Howling',
#   'Pumpkinhead',
#   'Silver Bullet'],
#  'tt0044811': ['A Lesson in Love',
#   'Dreams',
#   'Thirst',
#   'Summer Interlude',
#   'Port of Call',
#   'To Joy',
#   'Brink of Life',
#   "The Devil's Eye",
#   'Sawdust and Tinsel',
#   'A Ship to India',
#   'It Rains on Our Love',
#   'Crisis'],
#  'tt0443584': ['Madrid, 1987',
#   'The Weakness of the Bolshevik',
#   'Appassionata',
#   'Thieves',
#   'The Protagonists',
#   'Make It Happen',
#   "Il paradiso all'improvviso",
#   'Mundo civilizado',
#   'Water Lilies',
#   'Inconscio italiano',
#   'Jamón, Jamón',
#   'Desire'],
#  'tt0115006': ['Xtro II: The Second Encounter',
#   'Xtro',
#   'Cannibals in the Streets',
#   'Martial Law',
#   'Hell of the Living Dead',
#   "Class of Nuke 'Em High",
#   'Eaten Alive!',
#   'Edge of the Axe',
#   'Spookies',
#   'Anthropophagus: The Grim Reaper',
#   'Hollywood Horror House',
#   'Savage Dawn'],
#  'tt0094375': ['Royal Warriors',
#   'Yes, Madam!',
#   'Tai Chi Master',
#   'The Heroic Trio',
#   'Wing Chun',
#   'Ai qing lai le',
#   'Easy Money',
#   'The Legend of Fong Sai-Yuk 2',
#   'In the Line of Duty IV',
#   'Cosa Nostra Asia',
#   'Black Mask',
#   'True Legend'],
#  'tt0118747': ['The Blues Brothers',
#   'The Best of the Blues Brothers',
#   'The Blues Brothers Animated Series',
#   "National Lampoon's Animal House",
#   "Susan's Plan",
#   'Schlock',
#   'Beverly Hills Cop III',
#   'Trading Places',
#   'Spies Like Us',
#   'Tennessee Goblin',
#   'Slasher',
#   'Burke and Hare'],
#  'tt0242527': ['11:14',
#   'The Hole',
#   'Wrong Turn',
#   'The Jacket',
#   'Fear of Rain',
#   'Joy Ride',
#   'Hard Candy',
#   'The Village',
#   'Jeepers Creepers',
#   'Domino',
#   'Retreat',
#   'Wrong Turn'],
#  'tt0466766': ['Stitches',
#   'Tamara',
#   'Laid to Rest',
#   'The Paper Store',
#   'Inside',
#   'Periods.',
#   'Forever Strong',
#   'Slaughter High',
#   'Greetings from Tim Buckley',
#   'Maniac Cop 2',
#   'The Bedford Diaries',
#   'Parts Per Billion'],
#  'tt0374180': ['Warlock: The Armageddon',
#   'The Company of Wolves',
#   'The Pit and the Pendulum',
#   'Creep',
#   'Dead Birds',
#   'Second Name',
#   'Bad Moon',
#   "Cirque du Freak: The Vampire's Assistant",
#   'Kibakichi: Bakko-yokaiden',
#   'Cursed',
#   'Night of the Wolf',
#   'Wolves'],
#  'tt0100369': ['Castle Freak',
#   'Dolls',
#   'Dagon',
#   'Robot Jox',
#   'From Beyond',
#   'The Pit and the Pendulum',
#   'Edmond',
#   'King of the Ants',
#   'Fortress',
#   'Daughter of Darkness',
#   'Stuck',
#   'Bride of Re-Animator'],
#  'tt0122933': ['Analyze That',
#   'Ronin',
#   'Meet the Parents',
#   'Men of Honor',
#   'The Score',
#   'Meet the Fockers',
#   'A Bronx Tale',
#   'Meet the Parents: Deleted Scenes',
#   'The Whole Nine Yards',
#   'Showtime',
#   'Cop Land',
#   'Along Came Polly'],
#  'tt0089087': ['Beyond Rangoon',
#   'Hell in the Pacific',
#   'Excalibur',
#   'Hope and Glory',
#   'Leo the Last',
#   'Zardoz',
#   'Deliverance',
#   'Where the Heart Is',
#   "The Tiger's Tail",
#   'B.T.K.',
#   'Southern Comfort',
#   'In My Country'],
#  'tt0442781': ['Villain',
#   'Billa',
#   'Yennai Arindhaal',
#   'Mankatha',
#   'Arrambam',
#   'Citizen',
#   'Amarkalam',
#   'Vedalam',
#   'Veeram',
#   'Vaalee',
#   'Dheena',
#   'Attagasam'],
#  'tt0428856': ['Lemming',
#   'The Adversary',
#   'Nénette et Boni',
#   'The Measure of a Man',
#   'The Last Mistress',
#   'Merci pour le Chocolat',
#   'A Few Hours of Spring',
#   'All Our Desires',
#   'Retour à Kotelnitch',
#   'The Moon Child',
#   'Between Two Worlds',
#   'La crise'],
#  'tt0914797': ['SOMM',
#   'Nobel Son',
#   'SOMM: Into the Bottle',
#   'Blow Dry',
#   'Dark Harbor',
#   'Dust',
#   'Red Obsession',
#   'Snow Cake',
#   'Truly Madly Deeply',
#   'Sideways',
#   'The Search for John Gissing',
#   'Judas Kiss'],
#  'tt0099316': ['Arthur 2: On the Rocks',
#   'Grievous Bodily Harm',
#   'Crazy People',
#   'Mystery Date',
#   'Arthur',
#   'Leap of Faith',
#   'Flashback',
#   'Like Father Like Son',
#   'Mr. Destiny',
#   'Article 99',
#   'Romantic Comedy',
#   'The Dream Team'],
#  'tt0229480': ['Cemetery of Terror',
#   'Silent Madness',
#   'Grave Robbers',
#   'Rest in Pieces',
#   'Necromancer',
#   "Don't Panic",
#   "Satan's Blood",
#   'Whodunit?',
#   'My Dear Killer',
#   'La mansión de los Cthulhu',
#   'Fade to Black',
#   'The French Sex Murders'],
#  'tt0082677': ['Coma',
#   'Runaway',
#   'Wolfen',
#   'Pursuit',
#   'Physical Evidence',
#   'The Terminal Man',
#   'Extreme Close-Up',
#   'The Hidden',
#   'Brainstorm',
#   'The Great Train Robbery',
#   'The Andromeda Strain',
#   'The Sentinel'],
#  'tt0067345': ['The Ultimate Warrior',
#   'March or Die',
#   'Conduct Unbecoming',
#   'Town Without Pity',
#   'Morituri',
#   'Sky Riders',
#   'Romance of a Horsethief',
#   'Wolf Lake',
#   'The 25th Hour',
#   'Bitter Victory',
#   'The Assassination Bureau',
#   'Figures in a Landscape'],
#  'tt0037386': ['Night Train to Munich',
#   '711 Ocean Drive',
#   'Tonight and Every Night',
#   'The Keys of the Kingdom',
#   'Between Midnight and Dawn',
#   'The Southerner',
#   'The Window',
#   'Autumn Leaves',
#   'The Adventures of Tartu',
#   'Sunday Dinner for a Soldier',
#   'Patterns',
#   'One of Our Aircraft Is Missing'],
#  'tt0073233': ['Wat zien ik',
#   'Soldier of Orange',
#   'Spetters',
#   'Turkish Delight',
#   'The 4th Man',
#   'Flesh+Blood',
#   'Tricked',
#   'Voorbij, voorbij',
#   'Black Book',
#   'Voor koningin en vaderland',
#   'De worstelaar',
#   'Showgirls'],
#  'tt0111003': ['Body Snatchers',
#   'Virus',
#   'Phantoms',
#   'Puppet Master',
#   'Deep Rising',
#   'DeepStar Six',
#   "Puppet Master III: Toulon's Revenge",
#   'Leviathan',
#   'The Relic',
#   'Puppet Master II',
#   'Puppet Master 4',
#   "Hunter's Blood"],
#  'tt0105399': ['City Hunter',
#   'Crime Story',
#   'Thunderbolt',
#   'Operation Condor',
#   'Heart of Dragon',
#   'Project A 2',
#   'First Strike',
#   'Mr. Nice Guy',
#   'Dragons Forever',
#   'Armour of God',
#   'Supercop',
#   'Miracles: The Canton Godfather'],
#  'tt0399327': ['Lakeview Terrace',
#   'Code Name: The Cleaner',
#   'Man of the House',
#   'Resurrecting the Champ',
#   'Changing Lanes',
#   'Cop Out',
#   'Formula 51',
#   'Snakes on a Plane',
#   'No Good Deed',
#   "Partners 'n Love",
#   'National Security',
#   'The Comeback'],
#  'tt0168043': ['Expect the Unexpected',
#   'Running Out of Time',
#   'A Hero Never Dies',
#   'The Mission',
#   'Mad Detective',
#   'PTU',
#   'Election 2',
#   'Life Without Principle',
#   'Exiled',
#   'Running on Karma',
#   'Election',
#   'Breaking News'],
#  'tt0384177': ['Fresh Bait',
#   'Safe Conduct',
#   'It All Starts Today',
#   'Life and Nothing But',
#   'Une semaine de vacances',
#   'Revenge of the Musketeers',
#   'Daddy Nostalgia',
#   'The Clockmaker of St. Paul',
#   'Death Watch',
#   'Coup de Torchon',
#   'Shepherds and Butchers',
#   'Beatrice'],
#  'tt0084732': ['Plenty',
#   'Last Embrace',
#   'Eyewitness',
#   '52 Pick-Up',
#   'Ironweed',
#   'Twilight',
#   'Best Seller',
#   'Heartburn',
#   'Music of the Heart',
#   'A Cry in the Dark',
#   "The French Lieutenant's Woman",
#   'The Seduction of Joe Tynan'],
#  'tt0034182': ['The Spoilers',
#   'In Old California',
#   'Tall in the Saddle',
#   'Angel and the Badman',
#   'Pittsburgh',
#   'Reap the Wild Wind',
#   'Dark Command',
#   'Seven Sinners',
#   'The Fighting Kentuckian',
#   'Dakota',
#   'Night Passage',
#   'Wake of the Red Witch'],
#  'tt0113278': ['Hong Kong 97',
#   'Journey to the Center of the Earth',
#   'Spitfire',
#   'Knights',
#   'Nemesis 2: Nebula',
#   'Omega Doom',
#   'Nemesis 3: Time Lapse',
#   'Deceit',
#   'Bloodmatch',
#   'Sorcerers',
#   'Kickboxer 2: The Road Back',
#   'Nemesis'],
#  'tt0831888': ['Mind Game',
#   'Memories',
#   'Metropolis',
#   'Cat Soup',
#   'Tokyo Godfathers',
#   'Redline',
#   'Millennium Actress',
#   'Jin-Roh: The Wolf Brigade',
#   'Dead Leaves',
#   'Sword of the Stranger',
#   'Paprika',
#   'Steamboy'],
#  'tt0211718': ['Gadjo dilo',
#   'Freedom',
#   'Transylvania',
#   'Exils',
#   'Journey from Greece',
#   'Latcho Drom',
#   'Geronimo',
#   'Swing',
#   'Tom Medina',
#   'Children of the Stork',
#   'Mondo',
#   'Indignados'],
#  'tt0119086': ['The Babysitter',
#   'The Crush',
#   'Blast from the Past',
#   'Rock My World',
#   'Scorched',
#   'Silence Becomes You',
#   'Scattered Dreams',
#   'True Crime',
#   'Girl',
#   'Joyride',
#   'Things We Lost in the Fire',
#   'The Four Temperaments'],
#  'tt0120408': ['The Ballad of Narayama',
#   'Warm Water Under a Red Bridge',
#   'Black Rain',
#   'Vengeance Is Mine',
#   'Intentions of Murder',
#   'Profound Desires of the Gods',
#   'The Pornographers',
#   'The Insect Woman',
#   'Dr. Akagi',
#   'Pigs and Battleships',
#   'Zegen',
#   'The Ballad of Narayama'],
#  'tt0029120': ['Love on the Run',
#   'The Bride Wore Red',
#   'Queen Bee',
#   'Mannequin',
#   'Strange Cargo',
#   'Possessed',
#   'Sadie McKee',
#   'Forsaking All Others',
#   "The Damned Don't Cry",
#   'The Last of Mrs. Cheyney',
#   'Dancing Lady',
#   'Autumn Leaves'],
#  'tt0024894': ['The Raven',
#   'Murders in the Rue Morgue',
#   'Island of Lost Souls',
#   'The Old Dark House',
#   'The Mummy',
#   'Black Friday',
#   'The Wolf Man',
#   'The Invisible Man',
#   'Dracula',
#   'The Bride of Frankenstein',
#   'The Invisible Ray',
#   'The Black Cat'],
#  'tt0119434': ['Christmas She Wrote',
#   'A Summer Romance',
#   'Love is a Piece of Cake',
#   'Three of Hearts',
#   'Darkness Falls',
#   'Lovelife',
#   'The Shadow Men',
#   'Cement',
#   'True Blood',
#   'Outside Ozona',
#   'Desire and Hell at Sunset Motel',
#   'Christmas Perfection'],
#  'tt0072933': ['Emmanuelle',
#   'Emmanuelle 3',
#   'Emmanuelle IV',
#   'Emmanuelle 7',
#   'Emmanuelle 6',
#   'Emmanuelle 5',
#   'Emanuelle, Queen of Sados',
#   'Black Emanuelle',
#   "Lady Chatterley's Lover",
#   'The Story of O',
#   'Emanuelle in Bangkok',
#   'Emmanuelle à Venise'],
#  'tt0221218': ['Glass House: The Good Mother',
#   'Joy Ride',
#   'Enough',
#   'The Stepfather',
#   'Hush',
#   'Untraceable',
#   'Fear',
#   'Disturbia',
#   'The Roommate',
#   'Amerikali Kiz',
#   'Cold Creek Manor',
#   'Case 39'],
#  'tt0083798': ['The Man with Two Brains',
#   'All of Me',
#   'The Jerk',
#   'The Lonely Guy',
#   'Roxanne',
#   'L.A. Story',
#   'Pennies from Heaven',
#   'Dirty Rotten Scoundrels',
#   'My Blue Heaven',
#   'Movers & Shakers',
#   'Three Amigos!',
#   'The Absent-Minded Waiter'],
#  'tt0369295': ['Boys Life 3',
#   'Boys Life: Three Stories of Love, Lust, and Liberation',
#   'Boys Life 5',
#   'Boys Life 2',
#   'Boys Life 6',
#   'D.E.B.S.',
#   'Boys Life 7',
#   'Private Valentine: Blonde & Dangerous',
#   'B-Girl',
#   'The 10 Year Plan',
#   'O Beautiful',
#   'Saint Judy'],
#  'tt0035244': ['Wake of the Red Witch',
#   'Flame of Barbary Coast',
#   'Pittsburgh',
#   'Dark Command',
#   'The Spoilers',
#   'Dakota',
#   'In Old Oklahoma',
#   'North West Mounted Police',
#   'A Lady Takes a Chance',
#   'Seven Sinners',
#   'In Old California',
#   'Jet Pilot'],
#  'tt0091818': ['Nemesis',
#   'Whiskey Mountain',
#   'The Sword and the Sorcerer',
#   'Siege',
#   'Vicious Lips',
#   'Dangerously Close',
#   'Savage Dawn',
#   'Action U.S.A.',
#   'Murder-Rock: Dancing Death',
#   'Petey Wheatstraw',
#   'Knights',
#   'Spookies'],
#  'tt0030287': ['The Letter',
#   'Dark Victory',
#   'The Little Foxes',
#   'Now, Voyager',
#   'Dangerous',
#   'Mr. Skeffington',
#   'Dodsworth',
#   'All This, and Heaven Too',
#   'Of Human Bondage',
#   'The Heiress',
#   'Wuthering Heights',
#   'The Old Maid'],
#  'tt0046878': ['Ride the Pink Horse',
#   'The Narrow Margin',
#   'I Wake Up Screaming',
#   'Address Unknown',
#   'Pitfall',
#   'The Underworld Story',
#   '99 River Street',
#   'Murder by Contract',
#   'Born to Kill',
#   'Cry of the City',
#   'Where the Sidewalk Ends',
#   'Act of Violence'],
#  'tt0161292': ['Fear X',
#   'Pusher III',
#   'Pusher II',
#   'Pusher',
#   'Danny. Legend. God.',
#   'Valhalla Rising',
#   'Daddy Longlegs',
#   "L'héritage",
#   'Twelve Canoes',
#   'Angst',
#   'Dance Me to My Song',
#   'Borgman'],
#  'tt0002461': ['The Musketeers of Pig Alley',
#   'The Mystery of the Rocks of Kador',
#   'Richard III',
#   'Richard III',
#   'Richard III',
#   'Richard III',
#   "The Avenging Conscience: or 'Thou Shalt Not Kill'",
#   "Hell's Hinges",
#   'Richard III'],
#  'tt0026942': ['Flying Down to Rio',
#   'Carefree',
#   'Follow the Fleet',
#   'The Gay Divorcee',
#   'The Story of Vernon and Irene Castle',
#   'Shall We Dance',
#   'Top Hat',
#   'Swing Time',
#   'The Barkleys of Broadway',
#   'A Damsel in Distress',
#   "The Sky's the Limit",
#   'Vivacious Lady'],
#  'tt0435286': ['Pokémon: Jirachi - Wish Maker',
#   'Pokémon Heroes',
#   'Pokémon: Lucario and the Mystery of Mew',
#   'Pokémon: Giratina and the Sky Warrior',
#   'Pokémon: The Rise of Darkrai',
#   'Pokémon Ranger and the Temple of the Sea',
#   'Pokemon 4Ever: Celebi - Voice of the Forest',
#   'Pokémon: Arceus and the Jewel of Life',
#   'Pokémon: Zoroark: Master of Illusions',
#   'Pokémon 3 the Movie: Spell of the Unown',
#   'Pokémon the Movie 2000',
#   'Pokémon the Movie: Kyurem vs. the Sword of Justice'],
#  'tt0337876': ['Sexy Beast',
#   'Under the Skin',
#   'Fur: An Imaginary Portrait of Diane Arbus',
#   'Birthday Girl',
#   'To Die For',
#   'Rabbit Hole',
#   'The Zone of Interest',
#   'Jamiroquai: Virtual Insanity',
#   'Margot at the Wedding',
#   'Red Sands',
#   'The Fall',
#   'The Human Stain'],
#  'tt0092644': ['Beverly Hills Cop',
#   'Beverly Hills Cop III',
#   '48 Hrs.',
#   'Trading Places',
#   'Lethal Weapon 2',
#   'Lethal Weapon 3',
#   'Another 48 Hrs.',
#   'The Golden Child',
#   'Coming to America',
#   'Lethal Weapon',
#   'Lethal Weapon 4',
#   'Crocodile Dundee'],
#  'tt0052600': ['The Cranes Are Flying',
#   'The Destiny of a Man',
#   'Letter Never Sent',
#   'The Forty-First',
#   'The Ascent',
#   'They Fought for Their Country',
#   'Only Old Men Are Going to Battle',
#   'The Dawns Here Are Quiet',
#   'True Friends',
#   'Clear Skies',
#   'Officers',
#   'Moscow Does Not Believe in Tears'],
#  'tt0158714': ['Lady Snowblood 2: Love Song of Vengeance',
#   'Female Prisoner #701: Scorpion',
#   'Lone Wolf and Cub: Sword of Vengeance',
#   'Lone Wolf and Cub: Baby Cart at the River Styx',
#   'Lone Wolf and Cub: Baby Cart to Hades',
#   'Lone Wolf and Cub: Baby Cart in the Land of Demons',
#   'Lone Wolf and Cub: Baby Cart in Peril',
#   'Lone Wolf and Cub: White Heaven in Hell',
#   'Female Prisoner Scorpion: Jailhouse 41',
#   'The Sword of Doom',
#   'Female Prisoner Scorpion: Beast Stable',
#   'Shogun Assassin'],
#  'tt0097498': ['Return to Horror High',
#   'White Fire',
#   'Hell Comes to Frogtown',
#   'Hellgate',
#   'Scanner Cop',
#   'Blind Date',
#   'Necromancer',
#   'DNA',
#   'Hellgate',
#   'The Amusement Park',
#   'Chopping Mall',
#   'The Stuff'],
#  'tt0089715': ['Thieves Like Us',
#   'A Wedding',
#   'Come Back to the 5 & Dime Jimmy Dean, Jimmy Dean',
#   'Kansas City',
#   'Vincent & Theo',
#   'A Perfect Couple',
#   'Images',
#   'Streamers',
#   'HealtH',
#   'Beyond Therapy',
#   'Fool for Love',
#   'The Laundromat'],
#  'tt0085750': ['Jaws: The Revenge',
#   'Jaws 2',
#   'Tubarão: O Regresso',
#   'Jaws',
#   'The Artifact',
#   'Hellbox 3: Alastor Revenge',
#   'Angels World',
#   'P.O.V',
#   'Cruel Jaws',
#   'The Thing Returns',
#   'The Call 2',
#   'Hellbox 2: The Dark Dimension'],
#  'tt0227277': ['Infanzia, vocazione e prime esperienze di Giacomo Casanova, veneziano',
#   'A Leap in the Dark',
#   'Traffic Jam',
#   'Till Marriage Do Us Part',
#   "Mourir d'aimer...",
#   'Rasputin',
#   'The Wanting Mare',
#   'Hothead',
#   'Adua e le compagne',
#   'Ashes of Paradise',
#   'Merci pour le Chocolat',
#   'Wild Horses'],
#  'tt0043469': ['Garden of Evil',
#   'Springfield Rifle',
#   'Unconquered',
#   'Saskatchewan',
#   'Apache',
#   'The Last Hunt',
#   'The Last Wagon',
#   'The Far Country',
#   'Pursued',
#   'The Charge at Feather River',
#   'Alvarez Kelly',
#   'Gun Fury'],
#  'tt0036376': ["Dracula's Daughter",
#   'House of Dracula',
#   'The Ghost of Frankenstein',
#   'House of Frankenstein',
#   'Frankenstein Meets the Wolf Man',
#   "The Invisible Man's Revenge",
#   'Invisible Agent',
#   'The Invisible Woman',
#   "The Mummy's Tomb",
#   "The Mummy's Ghost",
#   "The Mummy's Curse",
#   "The Mummy's Hand"],
#  'tt0082892': ['Peter-No-Tail in America',
#   'Pelle Svanslös',
#   'Emil i Lönneberga',
#   'Alfons Åberg',
#   'The Snowman',
#   'Bamse - världens starkaste björn!',
#   'Bamse och den lilla åsnan',
#   'Pelle Svanslös',
#   'Rasmus på luffen',
#   'New Mischief by Emil',
#   'Ronja Rövardotter',
#   'Sunes sommar'],
#  'tt0031742': ['Goodbye, Mr. Chips',
#   'Pygmalion',
#   'A Tale of Two Cities',
#   'The Big House',
#   'The Long Voyage Home',
#   'The Front Page',
#   'Love Affair',
#   'Of Mice and Men',
#   'Stage Door',
#   'Of Mice and Men',
#   'Boys Town',
#   'The More the Merrier'],
#  'tt0120794': ['The Road to El Dorado',
#   'Joseph: King of Dreams',
#   'Anastasia',
#   'The Hunchback of Notre Dame',
#   'Treasure Planet',
#   'Spirit: Stallion of the Cimarron',
#   'Sinbad: Legend of the Seven Seas',
#   'Atlantis: The Lost Empire',
#   'Brother Bear',
#   'Mulan',
#   'Hercules',
#   "The Emperor's New Groove"],
#  'tt0072342': ['Violette',
#   'Dirty Hands',
#   'The Cousins',
#   'Les noces rouges',
#   'Les liens de sang',
#   'Le Boucher',
#   'The Breach',
#   'This Man Must Die',
#   'La femme infidèle',
#   'Nada',
#   'The Color of Lies',
#   'Just Before Nightfall'],
#  'tt0048682': ["The Brain That Wouldn't Die",
#   'It Conquered the World',
#   'Attack of the Giant Leeches',
#   'Naked Paradise',
#   'The Killer Shrews',
#   'Gunslinger',
#   'The Giant Claw',
#   'Creature from the Haunted Sea',
#   'Five Guns West',
#   'Last Woman on Earth',
#   'Matango',
#   'Not of This Earth'],
#  'tt0098157': ["Class of Nuke 'Em High",
#   'Nightmare City',
#   'Redneck Zombies',
#   'Evil Dead Trap',
#   'Sgt. Kabukiman N.Y.P.D.',
#   'The Deadly Spawn',
#   'Contamination',
#   'The Curse',
#   'Rabid Grannies 2: Ravenshore',
#   'Hell of the Living Dead',
#   'Zombie Strippers!',
#   'Bloodsucking Freaks'],
#  'tt0104418': ['The Video Dead',
#   'Razorback',
#   'Night of the Demons 2',
#   'Necronomicon: Book of Dead',
#   'Evilspeak',
#   'The Brain',
#   'Motel Hell',
#   'Night of the Demons',
#   'The Resurrected',
#   'Lord of Illusions',
#   'The Rift',
#   'Highway to Hell'],
#  'tt0047542': ['The Man with the Golden Arm',
#   'He Walked by Night',
#   'The Hitch-Hiker',
#   'D.O.A.',
#   'Quicksand',
#   'Too Late for Tears',
#   'The Man Who Cheated Himself',
#   'Down Three Dark Streets',
#   'Suddenly',
#   'Crime Wave',
#   'Johnny Concho',
#   'The Big Combo'],
#  'tt0101879': ['Midnight Man',
#   'Illegally Yours',
#   'Frank & Jesse',
#   'First Degree',
#   'On Dangerous Ground',
#   'Hostile Intent',
#   'One Hell of a Guy',
#   'Outrage',
#   'Square Dance',
#   'The Dark Backward',
#   'Oxford Blues',
#   'For Hire'],
#  'tt0254455': ['Lovers of the Arctic Circle',
#   'Room in Rome',
#   'Tierra',
#   'The Red Squirrel',
#   'The Other Side of the Bed',
#   'Cows',
#   'Chaotic Ana',
#   'Open Your Eyes',
#   'Carmen',
#   'Intimacy',
#   'Desire',
#   'Y tu mamá también'],
#  'tt0073496': ['The Other Side of the Mountain: Part II',
#   'Ice Castles',
#   'Shampoo',
#   'The Bell Jar',
#   'Love Child',
#   'The Other Side of the Mountain',
#   'A Separate Peace',
#   'Two-Minute Warning',
#   'Ash Wednesday',
#   'The Sporting Club',
#   'Cold Feet',
#   'The Stranger Who Looks Like Me'],
#  'tt0076725': ['Smash Palace',
#   'The Chant of Jimmie Blacksmith',
#   'Ceddo',
#   'My Brilliant Career',
#   'Landfall',
#   'Loulou',
#   'Three Lives and Only One Death',
#   'The Journalist',
#   'Just Out of Reach',
#   'Utu',
#   'Before the Revolution',
#   'The Hired Hand'],
#  'tt0138703': ['Phantasm III: Lord of the Dead',
#   'Phantasm: Ravager',
#   'Phantasm II',
#   'Phantasm',
#   'Phantasmagoria',
#   "Jim, the World's Greatest",
#   'Survival Quest',
#   'Kenny & Company',
#   "Wikked Lil' Girrrls",
#   'Killer Waves 2',
#   'Women Of Phantasm: The Documentary With Balls!',
#   'Bubba Ho-Tep'],
#  'tt0072006': ['The Beastmaster',
#   'Goodbye Pork Pie',
#   'Street Law',
#   'Chain Gang Women',
#   'Puzzle',
#   'Bucktown',
#   "Mama's Dirty Girls",
#   "Hell's Belles",
#   'Chrome and Hot Leather',
#   "Class of '74",
#   "Jessi's Girls",
#   'Teenage Seductress'],
#  'tt0450232': ['Hostage',
#   'The Jackal',
#   'Last Man Standing',
#   'Tears of the Sun',
#   'Conspiracy Theory',
#   'Mercury Rising',
#   'The Last Boy Scout',
#   'Assault on Precinct 13',
#   'Inside Moves',
#   'Lucky Number Slevin',
#   'Assassins',
#   'Swordfish'],
#  'tt0438488': ['Terminator 3: Rise of the Machines',
#   'Terminator Genisys',
#   'Terminator: Dark Fate',
#   'The Terminator',
#   'Terminator 2: Judgment Day',
#   'Predators',
#   'Predator',
#   'Predator 2',
#   'Alien: Resurrection',
#   'Alien 3',
#   'Terminator: The Sarah Connor Chronicles',
#   'Alien: Covenant'],
#  'tt0067367': ['The Vampire Lovers',
#   'Twins of Evil',
#   'Countess Dracula',
#   'The Kiss of the Vampire',
#   'Hands of the Ripper',
#   'Dr Jekyll & Sister Hyde',
#   "Blood from the Mummy's Tomb",
#   'Vampire Circus',
#   'The Horror of Frankenstein',
#   'Scars of Dracula',
#   'Taste the Blood of Dracula',
#   'Dracula A.D. 1972'],
#  'tt0029606': ['A Star Is Born',
#   'A Star Is Born',
#   'A Star Is Born',
#   'Stage Door',
#   'Jezebel',
#   'Lost Horizon',
#   'Pygmalion',
#   'Dodsworth',
#   'Mr. Deeds Goes to Town',
#   'A Tale of Two Cities',
#   'A Star Is Born',
#   'A star is born'],
#  'tt0419677': ['A Room for Romeo Brass',
#   'This Is England',
#   'Tyrannosaur',
#   'TwentyFourSeven',
#   "This Is England '88",
#   "This Is England '90",
#   'Somers Town',
#   "This Is England '86",
#   'Danny. Legend. God.',
#   'Daddy Longlegs',
#   "L'héritage",
#   'Fear X'],
#  'tt0442933': ['Lara Croft: Tomb Raider',
#   'Solomon Kane',
#   'Sky Captain and the World of Tomorrow',
#   'Reign of Fire',
#   'The Legend of Zorro',
#   'Lara Croft Tomb Raider: The Cradle of Life',
#   'The Mask of Zorro',
#   'The 13th Warrior',
#   'Van Helsing',
#   'Alexander',
#   'Beowulf',
#   'The Chronicles of Riddick'],
#  'tt0075824': ['The Phantom of Liberty',
#   'The Discreet Charm of the Bourgeoisie',
#   'Tristana',
#   'Belle de Jour',
#   'The Milky Way',
#   'The Exterminating Angel',
#   'Viridiana',
#   'Diary of a Chambermaid',
#   "La mort d'un bûcheron",
#   'La vie heureuse de Léopold Z',
#   'Honor Among Lovers',
#   'La vraie nature de Bernadette'],
#  'tt0090037': ['Girlfriends',
#   'What Happened Was...',
#   'Joyce at 34',
#   'Working Girls',
#   'The Lemon Sisters',
#   'A New Leaf',
#   'Clockwatchers',
#   'Man Push Cart',
#   'The Hot Rock',
#   'Deep Cover',
#   'Landscape Suicide',
#   'Man on a Swing'],
#  'tt0097373': ['The Mighty Quinn',
#   'Heart Condition',
#   "A Soldier's Story",
#   'Cry Freedom',
#   'Mississippi Masala',
#   'Power',
#   'The George McKenna Story',
#   'Carbon Copy',
#   'Ricochet',
#   "Mo' Better Blues",
#   'Virtuosity',
#   'Out of Time'],
#  'tt0382295': ['Wickie und die starken Männer',
#   'Die Wilden Kerle: Alles ist gut, solange du wild bist!',
#   'Das Sams',
#   'Hui Buh: Das Schlossgespenst',
#   'Bibi Blocksberg',
#   'Vicky and the Treasure of the Gods',
#   'Vorstadtkrokodile',
#   'The Seventh Dwarf',
#   'Die Wilden Kerle 2',
#   'The Crocodiles Strike Back',
#   'Head Full of Honey',
#   'Bibi Blocksberg and the Secret of Blue Owls'],
#  'tt0114369': ['Fight Club',
#   'Pulp Fiction',
#   'The Silence of the Lambs',
#   'Forrest Gump',
#   'Inception',
#   'Django Unchained',
#   'The Green Mile',
#   'Shutter Island',
#   'Inglourious Basterds',
#   'The Dark Knight',
#   'The Departed',
#   'The Shawshank Redemption'],
#  'tt0116729': ['Waiter',
#   'Voyeur',
#   'De noorderlingen',
#   'Schneider vs. Bax',
#   'The Last Days of Emma Blank',
#   'Kleine Teun',
#   'Grimm',
#   "L'héritage",
#   'Borgman',
#   'Twelve Canoes',
#   'Danny. Legend. God.',
#   'De Stedeling'],
#  'tt0071746': ['All That Jazz',
#   'Chez Maupassant',
#   'Cabaret',
#   'Nasty Baby',
#   'Les camisards',
#   'Liza with a Z',
#   'Star 80',
#   'Happy New Year',
#   'Mazeppa',
#   'Paul à Québec',
#   'Marie-Octobre',
#   'The Sniper'],
#  'tt0044030': ["Please Don't Eat the Daisies",
#   'By the Light of the Silvery Moon',
#   'On Moonlight Bay',
#   "That's Entertainment!",
#   'Meet Me in St. Louis',
#   'The Music Man',
#   'Listen, Darling',
#   'Curly Top',
#   'Doctor Dolittle',
#   'Hans Christian Andersen',
#   'Stowaway',
#   "That's Entertainment! III"],
#  'tt0362270': ['The Royal Tenenbaums',
#   'The Darjeeling Limited',
#   'Rushmore',
#   'Moonrise Kingdom',
#   'Bottle Rocket',
#   'Isle of Dogs',
#   'The Grand Budapest Hotel',
#   'Hotel Chevalier',
#   'Moonrise Kingdom: Animated Book Short',
#   'Castello Cavalcanti',
#   'Bottle Rocket',
#   'Come Together: A Fashion Picture in Motion'],
#  'tt0028676': ['Love Is News',
#   'Second Honeymoon',
#   'Day-Time Wife',
#   'A Night to Remember',
#   'In Old Chicago',
#   "I'll Never Forget You",
#   "The Razor's Edge",
#   'This Above All',
#   'Johnny Apollo',
#   'Suez',
#   'Adventure in Manhattan',
#   'Ladies in Love'],
#  'tt0104573': ['Menace II Society',
#   'Above the Rim',
#   'Poetic Justice',
#   'New Jack City',
#   'Baby Boy',
#   'Boyz n the Hood',
#   'South Central',
#   'Dead Presidents',
#   'Paid in Full',
#   'Friday',
#   'Gang Related',
#   'Set It Off'],
#  'tt0435696': ['Command Performance',
#   'Icarus',
#   'Missionary Man',
#   'Silent Trigger',
#   'Men of War',
#   'Skin Trade',
#   'Direct Contact',
#   'Red Scorpion',
#   'Direct Action',
#   'The Defender',
#   'Storm Catcher',
#   'Bridge of Dragons'],
#  'tt0087363': ['Gremlins 2: The New Batch',
#   'Ghostbusters',
#   'Ghostbusters II',
#   'Beetlejuice',
#   'Gremlins 3',
#   'Gremlins 3: Dawn of Desmond',
#   'Batman Returns',
#   'Poltergeist',
#   'Batman',
#   'The Lost Boys',
#   'Edward Scissorhands',
#   'The Fly'],
#  'tt0090357': ['Without a Clue',
#   'Innerspace',
#   'The Private Life of Sherlock Holmes',
#   'Twilight Zone: The Movie',
#   'Tin Men',
#   'Romancing the Stone',
#   'Avalon',
#   'An Everlasting Piece',
#   'Young Sherlock',
#   'Liberty Heights',
#   'Jimmy Hollywood',
#   'Always'],
#  'tt0126651': ['Fuera del cielo',
#   "Sonora, the Devil's Highway",
#   'Cilantro y perejil',
#   '101 Reykjavík',
#   'Santitos',
#   'De la calle',
#   'Capadocia',
#   'Workforce',
#   'La lengua del sol',
#   'Captain Pantoja and the Special Services',
#   'La sorpresa',
#   'Sexo, pudor y lágrimas'],
#  'tt0970462': ['Attack on Darfur',
#   'Stoic',
#   'Max Schmeling',
#   'Assault on Wall Street',
#   'Rampage: Capital Punishment',
#   'Rampage: President Down',
#   'Postal',
#   'Auschwitz',
#   'The Final Storm',
#   'Heart of America',
#   'Blubberella',
#   'Rampage'],
#  'tt0768212': ["Nim's Island",
#   'The Water Horse',
#   "Mr. Magorium's Wonder Emporium",
#   'The Secret of Moonacre',
#   'City of Ember',
#   'The Seeker: The Dark Is Rising',
#   'The Spiderwick Chronicles',
#   'The Tale of Despereaux',
#   'The Golden Compass',
#   'Zathura: A Space Adventure',
#   'Nanny McPhee',
#   'Inkheart'],
#  'tt0783532': ['Kalushi: The Story of Solomon Mahlangu',
#   'Tsotsi',
#   'Gangster Paradise',
#   'Imperial Dreams',
#   'All Day and a Night',
#   'The Ruthless',
#   'Beasts of No Nation',
#   'Legendary Weapons of China',
#   'Hell',
#   'Proud Mary',
#   'Sand Storm',
#   'Time to Hunt'],
#  'tt0120723': ['The Clearing',
#   'I.Q.',
#   'Down to Earth',
#   'Phoenix',
#   '10',
#   'The Woman in Red',
#   'A Guy Thing',
#   'Almost an Angel',
#   'My Best Friend Is a Vampire',
#   'Phat Beach',
#   'Head of State',
#   'Switch'],
#  'tt0253556': ['Equilibrium',
#   'The 13th Warrior',
#   'The Chronicles of Riddick',
#   'Sahara',
#   'Pitch Black',
#   'Scorpion Spring',
#   'Riddick',
#   'Waterworld',
#   'Stargate',
#   'Swordfish',
#   'The Time Machine',
#   'Laurel Canyon'],
#  'tt0069404': ['Rex Harrison Presents Stories of Love',
#   'Mazeppa',
#   'Les camisards',
#   'Mrs. Parkington',
#   'Chronicle of Poor Lovers',
#   'Hoa Binh',
#   'Peace Over the Fields',
#   'First Love',
#   'Le pressentiment',
#   'Tales of Manhattan',
#   'Wajma, an Afghan Love Story',
#   'The Birds, the Bees and the Italians'],
#  'tt0168501': ['The Best Man Holiday',
#   'The Wood',
#   'Brown Sugar',
#   'The Brothers',
#   'Soul Food',
#   'Love Jones',
#   'Love & Basketball',
#   'Deliver Us from Eva',
#   'Two Can Play That Game',
#   "Jason's Lyric",
#   'Set It Off',
#   'Waiting to Exhale'],
#  'tt0101578': ['Noble House',
#   'Ji',
#   'Sacrifice',
#   'Glitch!',
#   'Bei mei',
#   'One Kine Day',
#   'Sidekicks',
#   '10,000 Days',
#   'Bonhoeffer: Agent of Grace',
#   'Eat a Bowl of Tea',
#   'Tian guan ci fu',
#   'The Second Chance'],
#  'tt0048535': ['Ten Wanted Men',
#   'Man in the Saddle',
#   'The Cariboo Trail',
#   'Abilene Town',
#   'A Lawless Street',
#   'Coroner Creek',
#   'Tall Man Riding',
#   'Westbound',
#   'Gunfighters',
#   'Decision at Sundown',
#   'Buchanan Rides Alone',
#   'Trail Street'],
#  'tt0453467': ['The Taking of Pelham 123',
#   'The Book of Eli',
#   'Unstoppable',
#   'Man on Fire',
#   'Flight',
#   'Inside Man',
#   'John Q',
#   'The Equalizer',
#   'Training Day',
#   '2 Guns',
#   'The Equalizer 2',
#   'The Bone Collector'],
#  'tt0093502': ['The Funeral',
#   "A Taxing Woman's Return",
#   'Supermarket Woman',
#   'Minbo',
#   'Ageman',
#   'Tampopo',
#   'Marutai no onna',
#   'The Last Dance',
#   'A Quiet Life',
#   'Welcome Back, Mr. McDonald',
#   'The Man Who Stole the Sun',
#   "The Emperor's Naked Army Marches On"],
#  'tt0474642': ['The Life of Fish',
#   'Sábado',
#   "Don't Look Down",
#   '9 Songs',
#   'Sex and Lucía',
#   'Lie with Me',
#   'Secret Things',
#   'Romance',
#   'The Maid',
#   'Room in Rome',
#   'House of Tolerance',
#   'Hotel Desire'],
#  'tt0072271': ['The Texas Chainsaw Massacre',
#   'A Nightmare on Elm Street',
#   'The Evil Dead',
#   'The Texas Chainsaw Massacre 2',
#   'Friday the 13th',
#   'The Exorcist',
#   'Carrie',
#   'Halloween',
#   "Child's Play",
#   'Hellraiser',
#   'Night of the Living Dead',
#   'Evil Dead II'],
#  'tt0053183': ['MacArthur',
#   "Twelve O'Clock High",
#   'The Desert Rats',
#   'The Bridges at Toko-Ri',
#   'A Walk in the Sun',
#   'The Purple Plain',
#   'Halls of Montezuma',
#   'Tobruk',
#   'Captain Newman, M.D.',
#   'Beloved Infidel',
#   "The Devil's Brigade",
#   'Night People'],
#  'tt0018066': ['Mother',
#   'Storm Over Asia',
#   'Arsenal',
#   'Old and New',
#   'October (Ten Days that Shook the World)',
#   'Earth',
#   'Stachka',
#   'By the Law',
#   'Shakhmatnaya goryachka',
#   'Bed and Sofa',
#   'Zvenigora',
#   'Three Songs About Lenin'],
#  'tt0096163': ['The Vanishing',
#   'Cure',
#   "Don't Look Now",
#   'Angst',
#   'Possession',
#   'Les yeux sans visage',
#   'Audition',
#   'Saint Maud',
#   'Blow Out',
#   'Woman in the Dunes',
#   'The Tenant',
#   'The Wicker Man'],
#  'tt0035749': ['Mother Wore Tights',
#   'My Gal Sal',
#   'Moon Over Miami',
#   'Sun Valley Serenade',
#   'Calamity Jane',
#   'The Blue Dahlia',
#   'Rhapsody in Blue',
#   'Wabash Avenue',
#   'Pillow Talk',
#   'Father of the Bride',
#   'Look for the Silver Lining',
#   'Springtime in the Rockies'],
#  'tt0068327': ['All That Jazz',
#   'Liza with a Z',
#   'Lenny',
#   'Sweet Charity',
#   'West Side Story',
#   'Cabaret',
#   'Chicago',
#   'Cabaret',
#   'An American in Paris',
#   'MASH',
#   'Klute',
#   'Victor Victoria'],
#  'tt0095145': ['Troop Beverly Hills',
#   'Quicksilver',
#   'He Said, She Said',
#   'Outrageous Fortune',
#   'Dealers',
#   'Satisfaction',
#   'And God Created Woman',
#   'The Hand that Rocks the Cradle',
#   'The Con',
#   'Blind Side',
#   'A Table for One',
#   'Send Me No Flowers'],
#  'tt0098165': ["Salome's Last Dance",
#   'Gothic',
#   'The Boy Friend',
#   'The Music Lovers',
#   'Valentino',
#   'The Lair of the White Worm',
#   'Mahler',
#   'Women in Love',
#   'The Devils',
#   'Lisztomania',
#   'Savage Messiah',
#   'Crimes of Passion'],
#  'tt0119809': ['The Doom Generation',
#   'Totally F***ed Up',
#   'The Living End',
#   'Splendor',
#   'This Is How the World Ends',
#   'Mysterious Skin',
#   'Kaboom',
#   'Smiley Face',
#   'Three Bewildered People in the Night',
#   'Here Now',
#   "The Long Weekend (O'Despair)",
#   'White Bird in a Blizzard'],
#  'tt0095662': ['Critical Condition',
#   "Bustin' Loose",
#   'The Toy',
#   'Another You',
#   'Silver Streak',
#   "Brewster's Millions",
#   'See No Evil, Hear No Evil',
#   'Greased Lightning',
#   'Stir Crazy',
#   'Some Kind of Hero',
#   'Which Way Is Up?',
#   'The Three Muscatels'],
#  'tt0423176': ['Unknown Pleasures',
#   'Platform',
#   'Er shi si cheng ji',
#   'Pickpocket',
#   'Mountains May Depart',
#   'Still Life',
#   'A Touch of Sin',
#   'I Wish I Knew',
#   'Ash Is Purest White',
#   'Dong',
#   'Xiaoshan Going Home',
#   'The Hole'],
#  'tt0330843': ['Laaga Chunari Mein Daag: Journey of a Woman',
#   'Bhoothnath',
#   'Baabul',
#   "Let's Be Friends!",
#   'Virasat',
#   'Ta Ra Rum Pum',
#   'Veer-Zaara',
#   'Chaalbaaz',
#   'Aaja Nachle',
#   'Waqt: The Race Against Time',
#   'Chachi 420',
#   'Viruddh... Family Comes First'],
#  'tt0089565': ["Lady Chatterley's Lover",
#   'Mata Hari',
#   'Emmanuelle',
#   'An Affair',
#   'Mata Hari: The Naked Spy',
#   'Sliver',
#   'Delta of Venus',
#   'Mata Hari',
#   'A Serbian Film',
#   'Mata Hari',
#   'Mata Hari',
#   'Six Minutes to Midnight'],
#  'tt0095016': ['Die Hard 2',
#   'Die Hard with a Vengeance',
#   'Indiana Jones and the Last Crusade',
#   'Terminator 2: Judgment Day',
#   'Jurassic Park',
#   'Indiana Jones and the Raiders of the Lost Ark',
#   'Live Free or Die Hard',
#   'Aliens',
#   'The Sixth Sense',
#   'Back to the Future',
#   'Alien',
#   'Star Wars: Episode VI - Return of the Jedi'],
#  'tt0210302': ['Bullet Ballet',
#   'Vital',
#   'Haze',
#   'A Snake of June',
#   'Tokyo Fist',
#   'Kotoko',
#   'Tetsuo II: Body Hammer',
#   'Akumu tantei',
#   'Killing',
#   'Fires on the Plain',
#   'Yôkai hantâ: Hiruko',
#   'The Adventure of Denchu-Kozo'],
#  'tt0079822': ['Kansas City Bomber',
#   'Skatetown U.S.A.',
#   'The Big Show',
#   "Breakin' 2: Electric Boogaloo",
#   'Savage Streets',
#   'Burnt Offerings',
#   'The Long, Long Trailer',
#   'The Left Handed Gun',
#   'Ninja III: The Domination',
#   'Save the Tiger',
#   'Corvette Summer',
#   'The Bridges at Toko-Ri'],
#  'tt0048954': ['Kiss Me Kate',
#   'Kid Galahad',
#   'An American in Paris',
#   'One, Two, Three',
#   'Young at Heart',
#   'The Sea Hawk',
#   'Call Me Madam',
#   'French Cancan',
#   'Leave Her to Heaven',
#   'A Star Is Born',
#   "Gentleman's Agreement",
#   'Anything Goes'],
#  'tt0411117': ['Tous les matins du monde',
#   "À l'est de moi",
#   'American Masters and Champions of the Martial Arts',
#   'Where Eagles Dare',
#   'Land of Oblivion',
#   'The Last Mistress',
#   'La fille de Monaco',
#   'Suspectes',
#   'The Assassin Next Door',
#   'Tyranny',
#   'Enter the World of Bond',
#   "Everything You Didn't Say"],
#  'tt0031235': ['The Charge of the Light Brigade',
#   'Virginia City',
#   'The Private Lives of Elizabeth and Essex',
#   'They Died with Their Boots on',
#   'The Sea Hawk',
#   'San Antonio',
#   'Santa Fe Trail',
#   'Captain Blood',
#   'Arizona Legion',
#   "Four's a Crowd",
#   'Edge of Darkness',
#   'Holiday for Sinners'],
#  'tt0772200': ['Tiger Orange',
#   'Were the World Mine',
#   'Adam & Steve',
#   'Plan B',
#   'Boy Culture',
#   'From Beginning to End',
#   'Ice Blues',
#   'Kiss Me, Guido',
#   'Dream Boy',
#   'Third Man Out',
#   'On the Other Hand, Death',
#   'Mambo Italiano'],
#  'tt0325596': ['Antitrust',
#   'Little Boy Blue',
#   'Catch Hell',
#   'Five Fingers',
#   'Followers',
#   'Murder in Mind',
#   'Flowers',
#   'Crazy Kind of Love',
#   'Franklyn',
#   'Sweet Home Alabama',
#   'The Bang Bang Club',
#   'Perception'],
#  'tt0292490': ['Rang De Basanti',
#   'Zindagi Na Milegi Dobara',
#   'Lagaan: Once Upon a Time in India',
#   'Jab We Met',
#   'Munna Bhai M.B.B.S.',
#   'Barfi!',
#   'Kal Ho Naa Ho',
#   'Carry On, Munna Bhai',
#   'Swades',
#   'Bhaag Milkha Bhaag',
#   'OMG: Oh My God!',
#   'Sarfarosh'],
#  'tt0104431': ['Home Alone',
#   'Home Alone 3',
#   'Jumanji',
#   'Home Alone: The Holiday Heist',
#   'Night at the Museum',
#   'Home Alone 4',
#   'Charlie and the Chocolate Factory',
#   'Mrs. Doubtfire',
#   'Ice Age',
#   'How the Grinch Stole Christmas',
#   'Harry Potter and the Chamber of Secrets',
#   'Elf'],
#  'tt0209368': ['Persons Unknown',
#   'Ellie Parker',
#   'The Custodian',
#   'For Love Alone',
#   'Under the Lighthouse Dancing',
#   'The Hunt for the Unicorn Killer',
#   'The Wyvern Mystery',
#   'Gross Misconduct',
#   'Peaches',
#   'Love and Other Catastrophes',
#   'Russian Doll',
#   'Undertaking Betty'],
#  'tt0079714': ['Phantasm II',
#   'Phantasm III: Lord of the Dead',
#   'Phantasm IV: Oblivion',
#   'Phantasm: Ravager',
#   'Pumpkinhead',
#   'House',
#   'Re-Animator',
#   'The Howling',
#   'Maniac Cop',
#   'Creepshow',
#   'The Fog',
#   'Basket Case'],
#  'tt0090186': ['The Majorettes',
#   "Don't Answer the Phone!",
#   'Beyond the Door III',
#   'Unhinged',
#   'Eyes of a Stranger',
#   'I, Madman',
#   'Deadly Friend',
#   'The Final Terror',
#   'Girls School Screamers',
#   'House of Horrors',
#   'The Fifth Cord',
#   'Love Me Deadly'],
#  'tt0205461': ['Thomas & Friends: The Great Discovery - The Movie',
#   'Thomas & Friends',
#   'Thomas & Friends: The Adventure Begins',
#   'Thomas & Friends: Hero of the Rails',
#   'Thomas & Friends: Calling All Engines!',
#   'Thomas & Friends: Blue Mountain Mystery',
#   'Thomas the Tank Engine',
#   "Thomas & Friends: Sodor's Legend of the Lost Treasure",
#   'Thomas & Friends: Tale of the Brave',
#   'Thomas & Friends: King of the Railway',
#   'Thomas & Friends: Misty Island Rescue',
#   'Thomas & Friends: The Great Race'],
#  'tt0039204': ['Force of Evil',
#   'He Ran All the Way',
#   'The Breaking Point',
#   'Kiss of Death',
#   'Out of the Fog',
#   'The Sea Wolf',
#   'Born to Kill',
#   'The Set-Up',
#   'Crossfire',
#   'Act of Violence',
#   'We Were Strangers',
#   'Champion'],
#  'tt0244094': ['Just a Kiss',
#   'An Unmarried Woman',
#   'Surviving Eden',
#   'Letters from the Big Man',
#   'Wirey Spindell',
#   'Jail Bait',
#   'Taxi',
#   'The Limbo Room',
#   'Star Spangled Girl',
#   'Where Are the Children?',
#   'Safe Men',
#   'A Crime'],
#  'tt0044209': ['Repeat Performance',
#   'Address Unknown',
#   'His Kind of Woman',
#   'Red Light',
#   'Unmasked',
#   'Scandal: The Trial of Mary Astor',
#   'Al Capone',
#   'Outlaw Women',
#   'Prince of Pirates',
#   'Sealed Cargo',
#   'Four Sided Triangle',
#   'A Man Alone'],
#  'tt0053106': ['The Cranes Are Flying',
#   'Soy Cuba',
#   'True Friends',
#   'The Ascent',
#   'Ballad of a Soldier',
#   'Zagovor obrechyonnykh',
#   'Pervyy eshelon',
#   'Nail in the Boot',
#   'Diamonds of the Night',
#   'Vikhri vrazhdebnye',
#   'Marketa Lazarová',
#   'The Destiny of a Man'],
#  'tt0190798': ['Barrio',
#   'Lucky Star',
#   'El viaje a ninguna parte',
#   'The Enchanted Forest',
#   'El Bola',
#   'Numbered Days',
#   'La caja 507',
#   'La Niña De Tus Ojos',
#   'Lovers: A True Story',
#   'The Sleeping Voice',
#   'Te doy mis ojos',
#   'El pico'],
#  'tt0380066': ['All Cheerleaders Die',
#   'The Tripper',
#   'The Abandoned',
#   'Cellar Dweller',
#   'Dead Birds',
#   'All Cheerleaders Die',
#   'May',
#   'Toolbox Murders',
#   'The Gravedancers',
#   'Kindred Spirits',
#   'Wicked Little Things',
#   'The Woods'],
#  'tt0063050': ['I Never Sang for My Father',
#   'Rachel, Rachel',
#   'The Search',
#   'Lilies of the Field',
#   'Man on a Swing',
#   'The Russians Are Coming the Russians Are Coming',
#   'The Entertainer',
#   'Sweet Bird of Youth',
#   'Cover Me Babe',
#   'Possessed',
#   "Hell's Angels",
#   'In This Our Life'],
#  'tt0032477': ['Seven Sweethearts',
#   'Rendezvous',
#   'Hotel',
#   'Rhapsody in Blue',
#   'Night Song',
#   'Above and Beyond',
#   'Moon Over Miami',
#   'Jewel Robbery',
#   'Night Must Fall',
#   'Back from Eternity',
#   'East Side, West Side',
#   'The Shanghai Story'],
#  'tt0089853': ['Radio Days',
#   'Broadway Danny Rose',
#   'Zelig',
#   'Hannah and Her Sisters',
#   'Crimes and Misdemeanors',
#   'Stardust Memories',
#   'Love and Death',
#   'Husbands and Wives',
#   "A Midsummer Night's Sex Comedy",
#   'Interiors',
#   'Alice',
#   'Manhattan'],
#  'tt0084412': ['Gung Ho',
#   'Johnny Dangerously',
#   'Mr. Mom',
#   'The Dream Team',
#   'Clean and Sober',
#   'The Paper',
#   'Touch and Go',
#   'Grand Theft Auto',
#   'The Squeeze',
#   'Multiplicity',
#   'Malibu Hot Summer',
#   'Working Stiffs'],
#  'tt0103105': ['The Eighth Day',
#   'The Brand New Testament',
#   'Kiss & Cry',
#   'Thérèse',
#   'Cold Blood',
#   'Voyages',
#   'Bovary',
#   'Will It Snow for Christmas?',
#   'The Castle of Purity',
#   'The Shape',
#   'Isolation',
#   'Guinea Pig 4: Devil Woman Doctor'],
#  'tt0022792': ['He Was Her Man',
#   'Blonde Crazy',
#   'Union Depot',
#   'Blondie Johnson',
#   'Lawyer Man',
#   'Tiger Shark',
#   'Ceiling Zero',
#   'Dames',
#   'Today We Live',
#   'The Dawn Patrol',
#   'La foule hurle',
#   'The Criminal Code'],
#  'tt0210065': ['The Krays',
#   'Essex Boys',
#   'Nil by Mouth',
#   'Sexy Beast',
#   'I.D.',
#   'The Business',
#   '44 Inch Chest',
#   'Scum',
#   'Chopper',
#   'Gangster No 1 - The Freddie Foreman Story',
#   'Face',
#   'Scum'],
#  'tt0037179': ['The Wicked Lady',
#   'Bedelia',
#   'They Were Sisters',
#   'The Man in Grey',
#   'Desert Fury',
#   'The House of the Seven Gables',
#   'Account Rendered',
#   'Penthouse',
#   'Sleeping Car to Trieste',
#   'Larceny',
#   "The Madonna's Secret",
#   'Take One False Step'],
#  'tt0064100': ['Cactus Flower',
#   'An Unmarried Woman',
#   'Harry and Tonto',
#   'Enemies, A Love Story',
#   'Model Shop',
#   'Bob & Carol & Ted & Alice',
#   'Shampoo',
#   'Getting Straight',
#   'Next Stop, Greenwich Village',
#   'This Property Is Condemned',
#   'Love with the Proper Stranger',
#   'Carnal Knowledge'],
#  'tt0118819': ['The Flower of My Secret',
#   'High Heels',
#   'Bad Education',
#   'Broken Embraces',
#   'Tie Me Up! Tie Me Down!',
#   'Kika',
#   'Women on the Verge of a Nervous Breakdown',
#   'All About My Mother',
#   'Talk to Her',
#   'Law of Desire',
#   'Volver',
#   'Dark Habits'],
#  'tt0052847': ['Gidget Goes Hawaiian',
#   'Gidget',
#   'Gidget Goes to Rome',
#   'The Reluctant Debutante',
#   'Beauty and the Boss',
#   "Take Her, She's Mine",
#   'Come September',
#   "Kissin' Cousins",
#   'A Summer Place',
#   'Will Success Spoil Rock Hunter?',
#   'Where the Boys Are',
#   'Tammy Tell Me True'],
#  'tt0075669': ['Don',
#   'Muqaddar Ka Sikandar',
#   'Deewaar',
#   'Zanjeer',
#   'Namak Halaal',
#   'Laawaris',
#   'Trishul',
#   'Shahenshah',
#   'Satte Pe Satta',
#   'Naseeb',
#   'Coolie',
#   'Yaarana'],
#  'tt0045631': ['Convicted',
#   'Private Hell 36',
#   'Naked Alibi',
#   'The Web',
#   'Shield for Murder',
#   'The Mob',
#   'The Street with No Name',
#   'Two of a Kind',
#   'Cry Danger',
#   "Hell's Half Acre",
#   'Black Angel',
#   "Johnny O'Clock"],
#  'tt0246134': ['In a Better World',
#   'Everyone Says I Love You',
#   'Lawless Heart',
#   'Galveston',
#   'Lucky Break',
#   'Still Crazy',
#   'AKA',
#   'Princess of the Row',
#   'True Blue',
#   'Byzantium',
#   'Mysterious Creatures',
#   'Diana and I'],
#  'tt0391728': ['100 Girls',
#   'Adam and Eve',
#   'Adam and Eve',
#   'Adam and Eve',
#   "It's Complicated",
#   'The Sin of Adam and Eve',
#   'Taking Chances',
#   'Hospitality',
#   'Tom Cool',
#   'Waltzing Anna',
#   'Elektra Luxx',
#   'Adam and Evalyn'],
#  'tt0142242': ['Dragon Ball Z: Broly - Second Coming',
#   'Dragon Ball Z: The Return of Cooler',
#   "Dragon Ball Z: Cooler's Revenge",
#   'Dragon Ball Z: Revival Fusion',
#   'Dragon Ball Z: Super Android 13',
#   'Dragon Ball Z: Bojack Unbound',
#   'Dragon Ball Z: Wrath of the Dragon',
#   'Dragon Ball Z: Bio-Broly',
#   'Dragon Ball Z: Tree of Might',
#   'Dragon Ball Z: Lord Slug',
#   'Dragon Ball Z: Dead Zone',
#   "Dragon Ball Z: The World's Strongest"],
#  'tt0101694': ['Consenting Adults',
#   'Guilty as Sin',
#   'Shattered',
#   'Black Widow',
#   'Unlawful Entry',
#   'CrissCross',
#   'Betrayed',
#   'Protocol',
#   'The Hand that Rocks the Cradle',
#   'Before and After',
#   'Jagged Edge',
#   'Lovers and Liars'],
#  'tt0106827': ['Ernest Goes to Jail',
#   'Ernest Goes to School',
#   'Ernest Goes to Camp',
#   'Ernest Saves Christmas',
#   'Ernest in the Army',
#   'Ernest Goes to Africa',
#   'Slam Dunk Ernest',
#   'Ernest Scared Stupid',
#   'Ernest Goes to Splash Mountain',
#   "Hey, Vern, It's Ernest!",
#   "Ernest's Greatest Hits Volume 2",
#   'The Beverly Hillbillies'],
#  'tt0167132': ['Manta, Manta',
#   'Maybe... Maybe Not',
#   "Knockin' on Heaven's Door",
#   'Bang Boom Bang - Ein todsicheres Ding',
#   'Barefoot',
#   'Keinohrhasen',
#   'Kokowääh',
#   'Wo ist Fred?',
#   'Schutzengel',
#   'Türkisch für Anfänger',
#   'Männerhort',
#   'Die Hochzeit'],
#  'tt0131646': ['Space Truckers',
#   'Immortal',
#   'Starship Troopers 3: Marauder',
#   'Fortress 2: Re-Entry',
#   'A Sound of Thunder',
#   'Masterminds',
#   'Battlefield Earth',
#   'Slipstream',
#   'Red Planet',
#   'Without a Paddle',
#   'Sky Captain and the World of Tomorrow',
#   'Sparkler'],
#  'tt0044170': ['Murderers Among Us',
#   'It Happened in Broad Daylight',
#   'The 317th Platoon',
#   'I Was Nineteen',
#   'Kanal',
#   'Der Tiger von Eschnapur',
#   'Naked Among Wolves',
#   'The Captain from Köpenick',
#   'Black Rain',
#   'Stars',
#   'The Harmonists',
#   'Atlas'],
#  'tt0093201': ['Moon 44',
#   'Dead End Drive-In',
#   'Silver Bullet',
#   "The Noah's Ark Principle",
#   'Night of the Creeps',
#   'Memoirs of an Invisible Man',
#   'Franzmann',
#   'Stonewall',
#   'Dark Horse',
#   'The Italian Job',
#   'Anonymous',
#   'Universal Soldier'],
#  'tt0049843': ['All I Desire',
#   'The Tarnished Angels',
#   'A Time to Love and a Time to Die',
#   'Magnificent Obsession',
#   'Written on the Wind',
#   'All That Heaven Allows',
#   'Imitation of Life',
#   'Captain Lightfoot',
#   'Thunder on the Hill',
#   'The Breaking Point',
#   'The Moonlighter',
#   'The Mortal Storm'],
#  'tt0461769': ['Helpless',
#   'Eureka',
#   'Sad Vacation',
#   'Electric Dragon 80.000 V',
#   'Small Roads',
#   'Vital',
#   'The Untamed',
#   'Heli',
#   'Ohikkoshi',
#   'Hana',
#   'Gemini',
#   'Journey to the Shore'],
#  'tt0044110': ["His Majesty O'Keefe",
#   'Mister 880',
#   'Vengeance Valley',
#   'Jim Thorpe -- All-American',
#   'South Sea Woman',
#   'Kansas Raiders',
#   'Gunsmoke',
#   'The Young Savages',
#   'Where Love Has Gone',
#   "The Devil's Disciple",
#   'The Kentuckian',
#   'The Cimarron Kid'],
#  'tt0286261': ['Vera Drake',
#   'Career Girls',
#   'Life Is Sweet',
#   'Another Year',
#   'High Hopes',
#   'Happy-Go-Lucky',
#   'Secrets & Lies',
#   'Topsy-Turvy',
#   'Bleak Moments',
#   'Meantime',
#   'Mr. Turner',
#   'Naked'],
#  'tt0119586': ['L.627',
#   "Mama, There's a Man in Your Bed",
# ...
#   'The World in His Arms',
#   'The Way Ahead',
#   'Firecreek',
#   'Captain Horatio Hornblower',
#   '633 Squadron',
#   'The One That Got Away',
#   'The Bravados',
#   'Malta Story',
#   "Twelve O'Clock High",
#   'Night People',
#   'The Bridges at Toko-Ri'],
#  'tt0096316': ['Gardens of Stone',
#   'The Cotton Club',
#   'Peggy Sue Got Married',
#   'One from the Heart',
#   'Tetro',
#   'Rumble Fish',
#   'The Rain People',
#   'Youth Without Youth',
#   'The Fabulous Baker Boys',
#   'The Outsiders',
#   'The Rainmaker',
#   'Distant Vision'],
#  'tt0093855': ["Salem's Lot",
#   "Salem's Lot",
#   'It Lives Again',
#   "It's Alive III: Island of the Alive",
#   'Sphinx',
#   'Spookies',
#   'Demon Wind',
#   'The Dead Pit',
#   'Amityville 3-D',
#   'Innocent Blood',
#   'Alone in the Dark',
#   'Body Count'],
#  'tt0107711': ['Death Warrant',
#   'Sudden Death',
#   'Double Impact',
#   'Lionheart',
#   'Hard Target',
#   'Maximum Risk',
#   'The Quest',
#   'Legionnaire',
#   'Kickboxer',
#   'Timecop',
#   'Cyborg',
#   'Replicant'],
#  'tt0072239': ['Whirlpool',
#   'The Perfume of the Lady in Black',
#   'The Grapes of Death',
#   'Vampyres',
#   'Fascination',
#   'Night of the Eagle',
#   'The Blood Spattered Bride',
#   'Deviation',
#   'It Happened at Nightmare Inn',
#   'To the Devil a Daughter',
#   'Images',
#   'House of Whipcord'],
#  'tt0495040': ['Uncle',
#   'Bænken',
#   'Dreaming About You',
#   'Gamle mænd i nye biler',
#   'Chinaman',
#   'Sprængfarlig bombe',
#   'Italiensk for begyndere',
#   'Kongekabale',
#   'Terribly Happy',
#   'The Boys from St. Petri',
#   'Flame & Citron',
#   'Klown'],
#  'tt0437857': ['Hell House LLC',
#   'Hatchet',
#   'The House of the Devil',
#   "Trick 'r Treat",
#   'Sleepaway Camp',
#   'Ginger Snaps',
#   'Black Christmas',
#   'B4TM',
#   'The Loved Ones',
#   'Hatchet II',
#   'The Truth Below',
#   'Lake Mungo'],
#  'tt0168794': ['Mammoth',
#   'Suspicious River',
#   'Reckless',
#   'Let the Devil Wear Black',
#   'The Maker',
#   'The Robber Bride',
#   'Pipe Dream',
#   'The Best Thief in the World',
#   'Kissed',
#   'Murder in Mind',
#   'Goodbye Lover',
#   'Naked in New York'],
#  'tt0031397': ['Mr. Bug Goes to Town',
#   "Gulliver's Travels",
#   "Gulliver's Travels",
#   'The Story of the Fox',
#   'The Snow Queen',
#   "Gulliver's Travels",
#   "Mickey's Amateurs",
#   'The 3 Worlds of Gulliver',
#   '1001 Arabian Nights',
#   'Moose Hunters',
#   "Orphan's Benefit",
#   'Superman'],
#  'tt0084357': ['The Grapes of Death',
#   'Lips of Blood',
#   'The Night of the Hunted',
#   'The Iron Rose',
#   'The Shiver of the Vampires',
#   'Requiem for a Vampire',
#   'Fascination',
#   'The Nude Vampire',
#   'Bloody Moon',
#   'The Demoniacs',
#   'Helga, la louve de Stilberg',
#   'The Escapees'],
#  'tt0079826': ['For the Boys',
#   'Stella',
#   'Beaches',
#   'Down and Out in Beverly Hills',
#   'Outrageous Fortune',
#   'Ruthless People',
#   'Big Business',
#   'The Thorn',
#   'That Old Feeling',
#   'Divine Madness',
#   "Isn't She Great",
#   'Gypsy'],
#  'tt0042509': ['Come Back, Little Sheba',
#   'Strangers When We Meet',
#   'Reflections in a Golden Eye',
#   'The File on Thelma Jordon',
#   "The Farmer's Daughter",
#   'The Glass Menagerie',
#   'Tiger Bay',
#   'The Glass Menagerie',
#   'Good Neighbor Sam',
#   'Butterflies Are Free',
#   'The Dark Mirror',
#   'Seven Days... Seven Nights'],
#  'tt0072362': ['Were the World Mine',
#   'The Hanging Garden',
#   'Plan B',
#   'You & I',
#   'Come Undone',
#   'Totally F***ed Up',
#   'The 10 Year Plan',
#   'Longtime Companion',
#   'Beautiful Thing',
#   '4 Moons',
#   'Love or Whatever',
#   "Fortune and Men's Eyes"],
#  'tt0231402': ['Crocodile Dundee II',
#   'Crocodile Dundee',
#   'The Very Excellent Mr. Dundee',
#   'Almost an Angel',
#   'Lightning Jack',
#   'Strange Bedfellows',
#   'Charlie & Boots',
#   'Tourism Australia: Dundee - The Son of a Legend Returns Home',
#   "That's Not My Dog!",
#   'Floating Away',
#   'The Paul Hogan Show',
#   'The Jewel of the Nile'],
#  'tt0081562': ['See No Evil, Hear No Evil',
#   'Silver Streak',
#   'Another You',
#   "Brewster's Millions",
#   'Stir Crazy',
#   "Bustin' Loose",
#   'Hanky Panky',
#   'The Woman in Red',
#   'The Toy',
#   'Moving',
#   'The Frisco Kid',
#   'Critical Condition'],
#  'tt0068615': ['Night of the Lepus',
#   'Squirm',
#   'Empire of the Ants',
#   'Bug',
#   'Day of the Animals',
#   'Frogs!',
#   'Kingdom of the Spiders',
#   'Grave of the Vampire',
#   'The Food of the Gods',
#   'Ants!',
#   'Tormented',
#   'Prophecy'],
#  'tt0104142': ['Think Big',
#   'Wishful Thinking',
#   'Reel Talent',
#   'Going Bananas',
#   'Instinct',
#   'Slipping Into Darkness',
#   'Hot Stuff',
#   'The Good Bad Guy',
#   'Die Einsteiger',
#   "It's All About You",
#   'Genuine Risk',
#   'Last Vegas 2'],
#  'tt0101523': ['Passion of Mind',
#   'Mortal Thoughts',
#   'Half Light',
#   'Striptease',
#   'Once Around',
#   'I.Q.',
#   'Choices',
#   'Love Hurts',
#   'The Scarlet Letter',
#   'There Goes the Neighborhood',
#   'Flawless',
#   'In & Out'],
#  'tt0052611': ['Gorgo',
#   'The Beast from 20,000 Fathoms',
#   'The Monster That Challenged the World',
#   'The Deadly Mantis',
#   'It Came from Beneath the Sea',
#   'The Black Scorpion',
#   '20 Million Miles to Earth',
#   'Kronos',
#   'Not of This Earth',
#   'Earth vs. the Flying Saucers',
#   'It! the Terror from Beyond Space',
#   'The Valley of Gwangi'],
#  'tt0072195': ['Born in Flames',
#   'Welcome II the Terrordome',
#   'An Oversimplification of Her Beauty',
#   'Ornette: Made in America',
#   'The Last Angel of History',
#   'The Brother from Another Planet',
#   'Crumbs',
#   'Oh, Sun',
#   'Sun Ra: A Joyful Noise',
#   'Black Panthers',
#   'Supa Modo',
#   'Afronauts'],
#  'tt0034965': ['The Little Giant',
#   'Brother Orchid',
#   'A Slight Case of Murder',
#   "The Whole Town's Talking",
#   'The Amazing Dr. Clitterhouse',
#   'Crime by Night',
#   'A Kiss in the Dark',
#   'The Sea Wolf',
#   'Smart Money',
#   'Brother Rat',
#   'Blackmail',
#   'The Unfaithful'],
#  'tt0082340': ['Escape from L.A.',
#   'Big Trouble in Little China',
#   'They Live',
#   'The Fog',
#   'Assault on Precinct 13',
#   'Prince of Darkness',
#   'Christine',
#   'The Thing',
#   'Starman',
#   'In the Mouth of Madness',
#   'Vampires',
#   'Ghosts of Mars'],
#  'tt0120394': ['Human Traffic',
#   'La Cha Cha',
#   'The Acid House',
#   'Small Faces',
#   'Scum',
#   'The Krays',
#   'Kevin & Perry Go Large',
#   'Scum',
#   'The Football Factory',
#   'I.D.',
#   'Nil by Mouth',
#   'The Business'],
#  'tt0167137': ['En kort en lang',
#   'Kærlighed ved første hik',
#   'Stolen Spring',
#   'Take the Trash',
#   'Midt om natten',
#   'Solkongen',
#   'Dirch',
#   'The Julekalender',
#   'The Boys from St. Petri',
#   'What Goes Around',
#   'Jul på Vesterbro',
#   'Italiensk for begyndere'],
#  'tt0116483': ['Billy Madison',
#   'The Waterboy',
#   'Big Daddy',
#   'Mr. Deeds',
#   'The Wedding Singer',
#   'The Longest Yard',
#   '50 First Dates',
#   'Click',
#   'Tommy Boy',
#   'Dodgeball: A True Underdog Story',
#   'Step Brothers',
#   'Little Nicky'],
#  'tt0349333': ['Darna Zaroori Hai',
#   'Bhoot',
#   'Raaz',
#   'Raat',
#   '1920',
#   '13B: Fear Has a New Address',
#   'Kaun?',
#   'Masti',
#   'Krishna Cottage',
#   'Ek Thi Daayan',
#   'Ek Hasina Thi',
#   'Kaal'],
#  'tt0112619': ['Red Dawn',
#   'Violet Perfume: No One Is Listening',
#   'Sexo, pudor y lágrimas',
#   'Los caifanes',
#   'Midaq Alley',
#   'Canoa: A Shameful Memory',
#   'Macario',
#   'Amar te duele',
#   'Un mundo maravilloso',
#   'The Place Without Limits',
#   "Herod's Law",
#   'The Perfect Dictatorship'],
#  'tt0329767': ['Torremolinos 73',
#   'En kort en lang',
#   'Le Fantôme',
#   'Open Hearts',
#   'I Am Dina',
#   'Prag',
#   'The Green Butchers',
#   'Dykkerdrengen',
#   'Monas verden',
#   'Wildside',
#   'Men & Chicken',
#   'Italiensk for begyndere'],
#  'tt0000574': ["The '?' Motorist",
#   "Dante's Inferno",
#   'Bluebeard',
#   'Pauvre Pierrot',
#   'Life of an American Fireman',
#   'The Waterer Watered',
#   "Mary Jane's Mishap",
#   'Blacksmith Scene',
#   'Frankenstein',
#   'The Execution of Mary, Queen of Scots',
#   'Cabiria',
#   'Dream of a Rarebit Fiend'],
#  'tt0133197': ['Shiner',
#   'The Debtors',
#   'Blue Ice',
#   'The Whistle Blower',
#   'It All Came True',
#   'A Shock to the System',
#   'Bullet to Beijing',
#   'Quicksand',
#   'The Statement',
#   'Is Anybody There?',
#   'Silver Bears',
#   'Half Moon Street'],
#  'tt0092783': ['Best Seller',
#   'True Believer',
#   'Fast-Walking',
#   'Off Limits',
#   'The Boost',
#   'In Love and War',
#   'Dead Bang',
#   'The Escapist',
#   'White Sands',
#   'Johnny Handsome',
#   'The Mean Season',
#   'Killer: A Journal of Murder'],
#  'tt0830558': ['An American Crime',
#   'The Seasoning House',
#   'Chained',
#   'The Loved Ones',
#   'I Spit on Your Grave',
#   'The Girl Next Door',
#   'The Woman',
#   "Mother's Day",
#   'The Girl Next Door',
#   'Eden Lake',
#   'The Collector',
#   'Martyrs'],
#  'tt0158983': ['Team America: World Police',
#   'The Simpsons Movie',
#   'South Park: Imaginationland',
#   'South Park',
#   'BASEketball',
#   'The Spirit of Christmas',
#   'Beavis and Butt-Head Do America',
#   'The Spirit of Christmas',
#   'Austin Powers: The Spy Who Shagged Me',
#   'Austin Powers: International Man of Mystery',
#   'Austin Powers in Goldmember',
#   "Wayne's World"],
#  'tt0064074': ['The Knack... and How to Get It',
#   'Slither',
#   'Girl with Green Eyes',
#   'Petulia',
#   'A Taste of Honey',
#   'Plucked',
#   'Tell Me That You Love Me, Junie Moon',
#   'A Place to Go',
#   'Fear in the Night',
#   'How I Won the War',
#   'Derek and Clive Get the Horn',
#   'Harpya'],
#  'tt0375568': ['Planet 51',
#   'G-Force',
#   'The Tale of Despereaux',
#   'The Ant Bully',
#   'Astro Boy',
#   'Arthur and the Invisibles',
#   'Hoodwinked',
#   "Surf's Up",
#   'Meet the Robinsons',
#   'Open Season',
#   'Barnyard',
#   'Astroboy'],
#  'tt0807054': ['The Navigators',
#   "Jimmy's Hall",
#   'Bread and Roses',
#   'Land and Freedom',
#   'Looking for Eric',
#   'Route Irish',
#   'Ae Fond Kiss...',
#   "The Angels' Share",
#   'My Name Is Joe',
#   'Sweet Sixteen',
#   'The Wind that Shakes the Barley',
#   "Carla's Song"],
#  'tt0365262': ['GhostWatcher 2',
#   'Ghostwatch',
#   'The House of Screaming Death',
#   'Children of the Night',
#   "The Devil's Hand",
#   'The Deeper You Dig',
#   'The Eye',
#   'Demonic',
#   'Pulse',
#   'Ginger Snaps',
#   '13 Minutes',
#   'Slasher'],
#  'tt0451038': ['Me and Orson Welles',
#   'Charlie St. Cloud',
#   'Vanessa Hudgens: Say Ok',
#   'At Any Price',
#   "High School Musical Cast: I Can't Take My Eyes Off of You",
#   "Melinda's World",
#   "New Year's Eve",
#   'The Lucky One',
#   'Dirty Grandpa',
#   'Mike and Dave Need Wedding Dates',
#   'Neighbors 2: Sorority Rising',
#   'Miracle Run'],
#  'tt0101998': ['Just Another Girl on the I.R.T.',
#   'Where I Live',
#   'The Bronx War',
#   'South Central',
#   'Hollywood Shuffle',
#   'Massacre at Central High',
#   'To Sleep with Anger',
#   'The Game',
#   'Caught Up',
#   'The Super',
#   'Jungle Fever',
#   'Empire'],
#  'tt0029322': ['Hands Across the Table',
#   'Twentieth Century',
#   'True Confession',
#   'My Man Godfrey',
#   'No Man of Her Own',
#   'Libeled Lady',
#   'Easy Living',
#   'In Name Only',
#   'Midnight',
#   'Made for Each Other',
#   'Virtue',
#   'Vigil in the Night'],
#  'tt0073705': ['Rabid',
#   'The Brood',
#   'Scanners',
#   'Videodrome',
#   'Dead Ringers',
#   'Fast Company',
#   'Naked Lunch',
#   'Shivers',
#   'Spider',
#   'The Dead Zone',
#   'Crash',
#   'Crimes of the Future'],
#  'tt0041983': ['He Walked by Night',
#   'Follow Me Quietly',
#   'The Man Who Cheated Himself',
#   'Moss Rose',
#   'Quicksand',
#   'Please Murder Me!',
#   'Bodyguard',
#   'The Amazing Mr. X',
#   'Fallen Angel',
#   '711 Ocean Drive',
#   'One Jump Ahead',
#   'I Believe in You'],
#  'tt0041699': ['Drunken Angel',
#   'The Bad Sleep Well',
#   'Scandal',
#   'The Quiet Duel',
#   'I Live in Fear',
#   'Red Beard',
#   'One Wonderful Sunday',
#   'The Hidden Fortress',
#   'Sanjuro',
#   'The Lower Depths',
#   'Throne of Blood',
#   'No Regrets for Our Youth'],
#  'tt0100633': ['Beyond Bedlam',
#   'The Long Winter',
#   'Mad Dogs and Englishmen',
#   'Twenty-One',
#   'Rowing with the Wind',
#   'Bad Boy',
#   'Beltenebros',
#   'Viktor',
#   'Dangerous Ground',
#   'Bitter Harvest',
#   'Chicago Joe and the Showgirl',
#   'Double Whammy'],
#  'tt0076584': ['Inglourious Basterds',
#   'The Dirty Dozen: The Fatal Mission',
#   'Django',
#   'Street Law',
#   'Code Name: Emerald',
#   'Keoma',
#   'Kill Them All and Come Back Alone',
#   'Inglorious Basterds: Stolz der Nation',
#   'From Corleone to Brooklyn',
#   'The Heroin Busters',
#   'The Great Silence',
#   'Cabo Blanco'],
#  'tt0102489': ['Sweet Murder',
#   'Up from the Depths',
#   'Chopper Chicks in Zombietown',
#   'Black Circle',
#   'Till Death Us Do Part',
#   'The Nail Gun Massacre',
#   'The Dark',
#   'Cyberjack',
#   'Feast of July',
#   'Pale Blood',
#   'High Desert Kill',
#   'Deadly Intruder'],
#  'tt0021931': ['The Front Page',
#   'The Star Witness',
#   'Carefree',
#   'The Killer That Stalked New York',
#   'Black Legion',
#   'He Ran All the Way',
#   'Red Dust',
#   'The Brothers Rico',
#   'The Secret 6',
#   'Manhattan Melodrama',
#   'The Big House',
#   'The Smiling Lieutenant'],
#  'tt0038107': ['Swamp Water',
#   'The Bigamist',
#   'This Land Is Mine',
#   'The River',
#   'Kansas City Confidential',
#   'Salt of the Earth',
#   'The Strange Love of Martha Ivers',
#   'Of Human Bondage',
#   'He Walked by Night',
#   'The Woman on the Beach',
#   'And Then There Were None',
#   'The Man with the Golden Arm'],
#  'tt0048512': ['The Detective',
#   'Ministry of Fear',
#   'Something to Live for',
#   "Yesterday's Enemy",
#   'Lady in Distress',
#   'The Promoter',
#   'The Mudlark',
#   'The Scapegoat',
#   'Last Holiday',
#   'Manon',
#   'All at Sea',
#   "The Horse's Mouth"],
#  'tt0361399': ['Enemies Closer',
#   'Consequence',
#   'Knife Edge',
#   'Infamous Six',
#   'Last Run',
#   'Jill Rips',
#   'Exodus to Shanghai',
#   'Submerged',
#   'Contaminated Man',
#   'Blast',
#   'Federal Protection',
#   'Prince Valiant'],
#  'tt0443526': [],
#  'tt0119822': ["Something's Gotta Give",
#   'The Bucket List',
#   'A Few Good Men',
#   'About Schmidt',
#   'Jerry Maguire',
#   'Terms of Endearment',
#   'Rain Man',
#   'What Women Want',
#   'Ghost',
#   'Awakenings',
#   'How Do You Know',
#   'Erin Brockovich'],
#  'tt0363771': ['The Chronicles of Narnia: Prince Caspian',
#   'The Chronicles of Narnia: The Voyage of the Dawn Treader',
#   'Charlie and the Chocolate Factory',
#   'Night at the Museum',
#   'Alice in Wonderland',
#   'Fantastic Beasts and Where to Find Them',
#   'Harry Potter and the Chamber of Secrets',
#   'Harry Potter and the Half-Blood Prince',
#   'Harry Potter and the Order of the Phoenix',
#   'Harry Potter and the Prisoner of Azkaban',
#   'Harry Potter and the Goblet of Fire',
#   'Home Alone'],
#  'tt0084945': ['Zapped Again!',
#   'Screwballs',
#   'My Tutor',
#   "Porky's",
#   'Private School',
#   'Spring Break',
#   'Gas Pump Girls',
#   'Massacre River',
#   "Porky's II: The Next Day",
#   'Hardbodies',
#   "Porky's Revenge",
#   'They Call Me Bruce'],
#  'tt0117373': ['Arctic Blue',
#   'Omega Doom',
#   'Blood of the Innocent',
#   'Crossworlds',
#   'Beyond Justice',
#   'A Breed Apart',
#   'Past Midnight',
#   'The Beans of Egypt, Maine',
#   'Wedlock',
#   'Art Deco Detective',
#   'Blast',
#   'Redline'],
#  'tt0039169': ['Mr. Blandings Builds His Dream House',
#   'My Favorite Wife',
#   'The Talk of the Town',
#   'I Was a Male War Bride',
#   'Every Girl Should Be Married',
#   "The Bishop's Wife",
#   'People Will Talk',
#   'Father Goose',
#   'Monkey Business',
#   'The Awful Truth',
#   'Holiday',
#   'Mr. Lucky'],
#  'tt0043045': ['Until They Sail',
#   'Tribute to a Bad Man',
#   'Tomorrow Is Another Day',
#   "The Damned Don't Cry",
#   'Sleep, My Love',
#   'Woman in Hiding',
#   'Since You Went Away',
#   'Julie',
#   'Something for the Birds',
#   '711 Ocean Drive',
#   'Two Flags West',
#   'Cloudburst'],
#  'tt0411270': ['Read My Lips',
#   'A Self-Made Hero',
#   'A Prophet',
#   'Dheepan',
#   'Rust and Bone',
#   'See How They Fall',
#   'Heartbreaker',
#   'Russian Dolls',
#   'The Spanish Apartment',
#   'Paris',
#   'Le péril jeune',
#   'Paris, 13th District'],
#  'tt0034012': ['My Favorite Wife',
#   'The Talk of the Town',
#   'The Bachelor and the Bobby-Soxer',
#   'The Awful Truth',
#   'None But the Lonely Heart',
#   'I Was a Male War Bride',
#   'Monkey Business',
#   'Mr. Lucky',
#   'People Will Talk',
#   'Topper',
#   'Mr. Blandings Builds His Dream House',
#   'Indiscreet'],
#  'tt0086197': ['The Killing Fields',
#   'The Right Stuff',
#   'JFK',
#   'Patton',
#   'Witness',
#   'Breaking Away',
#   "All the President's Men",
#   'The Real Right Stuff',
#   'Apollo 13',
#   'Reds',
#   'Cocoon',
#   'Chariots of Fire'],
#  ...}

# %%
len_item = []
for key, item in data.items():
    len_item.append(len(item))

# %%
(unique, counts) = np.unique(len_item, return_counts=True)
frequencies = np.asarray((unique, counts)).T
frequenciesquenciesquencies
# Out:
# array([[   0,    5],
#        [   1,    4],
#        [   2,    6],
#        [   3,    6],
#        [   4,    5],
#        [   5,    3],
#        [   6,    6],
#        [   7,    6],
#        [   8,    5],
#        [   9,    1],
#        [  10,    4],
#        [  11,    2],
#        [  12, 2984]])

# %%
name = ["recommendation" + str(i) for i in range(1,13)]
df = pd.DataFrame.from_dict(data, orient='index', columns= name)
df.reset_index(level=0, inplace=True)
df.rename(columns={'index':'id'}, inplace=True)
df.to_csv('Data/imdb_recommendations.csv', index=False)
df
# Out:
#              id       recommendation1            recommendation2  \
# 0     tt0018515            The Racket                 7th Heaven
# 1     tt0118866       The Daytrippers                 Party Girl
# 2     tt0050652           The Hangman             Hangman's Knot
# 3     tt0051885             Homicidal  Phantom of the Rue Morgue
# 4     tt0248123               Julieta                     Allein
# ...         ...                   ...                        ...
# 3032  tt0238948               Foolish            Meet the Blacks
# 3033  tt0406375  Bridge to Terabithia                    Jumanji
# 3034  tt0063591   How to Frame a Figg              The Love God?
# 3035  tt0119791           Nattevagten       A Life Less Ordinary
# 3036  tt0492486        Penny Dreadful                 Dead Birds
#
#                 recommendation3                         recommendation4  \
# 0              The Last Command                            Street Angel
# 1              The House of Yes  Thirteen Conversations About One Thing
# 2           Tennessee's Partner                       The Tall Stranger
# 3                Mr. Sardonicus                      The Tomb of Ligeia
# 4                What We Wanted                                Julietta
# ...                         ...                                     ...
# 3032                  3 Strikes                                   Metro
# 3033  The Spiderwick Chronicles                          The Karate Kid
# 3034           The Private Eyes                   No Time for Sergeants
# 3035        Eye of the Beholder                              Nightwatch
# 3036            YellowBrickRoad                              Shrooms 3D
#
#          recommendation5                     recommendation6  \
# 0         Sadie Thompson                          Underworld
# 1               Thin Ice                              Flames
# 2     Law of the Lawless                              Cowboy
# 3              13 Ghosts                         The Tingler
# 4         Freigesprochen                           Only Mine
# ...                  ...                                 ...
# 3032         Local Color                         The New Guy
# 3033            Sky High  Journey to the Center of the Earth
# 3034   The Prize Fighter                           The Caddy
# 3035            Stigmata                       The Vanishing
# 3036               Creep                Wicked Little Things
#
#                                      recommendation7  \
# 0                                            Tempest
# 1                William Eggleston in the Real World
# 2                             The Eagle and the Hawk
# 3                            I Died a Thousand Times
# 4                                       Toni Erdmann
# ...                                              ...
# 3032                                     29th Street
# 3033  Night at the Museum: Battle of the Smithsonian
# 3034                        Ma and Pa Kettle at Home
# 3035                                     Night Watch
# 3036                                       Catacombs
#
#                         recommendation8                recommendation9  \
# 0                  The Way of All Flesh                 The Front Page
# 1                           Smooth Talk           What Happened Was...
# 2                Along the Great Divide          The Law and Jake Wade
# 3                     I Bury the Living             The Old Dark House
# 4                   All About My Mother        The Billion Dollar Code
# ...                                 ...                            ...
# 3032                          Class Act                          I Spy
# 3033          The Sorcerer's Apprentice              The Polar Express
# 3034  Ma and Pa Kettle Back on the Farm  Support Your Local Gunfighter
# 3035                      Shallow Grave                          Mimic
# 3036                          Dark Ride                       100 Feet
#
#                      recommendation10  \
# 0                     The Divine Lady
# 1                           Mala Mala
# 2                      This Angry Age
# 3                             The Bat
# 4                            Stowaway
# ...                               ...
# 3032  Bickford Shmeckler's Cool Ideas
# 3033              Night at the Museum
# 3034               Return to Mayberry
# 3035                      Brassed Off
# 3036                La bête à l'affût
#
#                              recommendation11          recommendation12
# 0                      The Patent Leather Kid           The Love Parade
# 1                                The Hot Rock              Cutter's Way
# 2          Django Kill... If You Live, Shoot!      Three Violent People
# 3                            The Night Walker  The Earth Dies Screaming
# 4                                        None                      None
# ...                                       ...                       ...
# 3032                          Nothing to Lose    A Low Down Dirty Shame
# 3033  Night at the Museum: Secret of the Tomb              Nanny McPhee
# 3034              Support Your Local Sheriff!                 Fitzwilly
# 3035                              Night Watch       Fri os fra det onde
# 3036                          Finders Keepers          Shin Tange Sazen
#
# [3037 rows x 13 columns]

# %%
main.drop(columns=['Unnamed: 0'], inplace = True)
main
# Out:
#               id                                             review  \
# 1      tt0018515  This is a very strange film that was long thou...
# 2      tt0018515  William Boyd and Louis Wolheim are the "Two Ar...
# 3      tt0018515  Not very many movies come to my mind that cove...
# 4      tt0018515  The third movie produced by Howard Hughes, thi...
# 5      tt0018515  Turner Classic Movies showed this silent, B&W ...
# ...          ...                                                ...
# 28624  tt0492486  This was the surprise film at the Dublin Horro...
# 28625  tt0492486  I've seen hundreds of horror movies in my life...
# 28626  tt0492486  I cannot remember the last time a horror movie...
# 28627  tt0492486  I saw this movie tonight. Never have left comm...
# 28628  tt0492486  Shrooms basically is a Slasher Movie. 3 couple...
#
#        review_1st review_2nd       original_title  year date_published  \
# 1       2.6453724   5.547905  Two Arabian Knights  1927     1927-09-23
# 2      -0.4441953  2.2827504  Two Arabian Knights  1927     1927-09-23
# 3       0.8150438  3.9238899  Two Arabian Knights  1927     1927-09-23
# 4        2.477075   5.466526  Two Arabian Knights  1927     1927-09-23
# 5       1.1922804  2.5448508  Two Arabian Knights  1927     1927-09-23
# ...           ...        ...                  ...   ...            ...
# 28624   1.0869972   6.843044              Shrooms  2007     2008-08-22
# 28625  0.17316706    6.62107              Shrooms  2007     2008-08-22
# 28626   1.0682999   6.835441              Shrooms  2007     2008-08-22
# 28627   1.0295599  3.5069268              Shrooms  2007     2008-08-22
# 28628   1.0787203   6.848455              Shrooms  2007     2008-08-22
#
#       duration               country language  ... popularity  \
# 1           92                   USA  English  ...    0.38981
# 2           92                   USA  English  ...    0.38981
# 3           92                   USA  English  ...    0.38981
# 4           92                   USA  English  ...    0.38981
# 5           92                   USA  English  ...    0.38981
# ...        ...                   ...      ...  ...        ...
# 28624       84  Ireland, UK, Denmark  English  ...   9.128571
# 28625       84  Ireland, UK, Denmark  English  ...   9.128571
# 28626       84  Ireland, UK, Denmark  English  ...   9.128571
# 28627       84  Ireland, UK, Denmark  English  ...   9.128571
# 28628       84  Ireland, UK, Denmark  English  ...   9.128571
#
#                             poster_path    revenue runtime    status  video  \
# 1      /mGZ3EgmkDesKEA8FnJcUgX8TpXT.jpg        0.0    92.0  Released  False
# 2      /mGZ3EgmkDesKEA8FnJcUgX8TpXT.jpg        0.0    92.0  Released  False
# 3      /mGZ3EgmkDesKEA8FnJcUgX8TpXT.jpg        0.0    92.0  Released  False
# 4      /mGZ3EgmkDesKEA8FnJcUgX8TpXT.jpg        0.0    92.0  Released  False
# 5      /mGZ3EgmkDesKEA8FnJcUgX8TpXT.jpg        0.0    92.0  Released  False
# ...                                 ...        ...     ...       ...    ...
# 28624  /hPzqg3NTDaW6y7L0QCBxMxhOQjK.jpg  4910682.0    84.0  Released  False
# 28625  /hPzqg3NTDaW6y7L0QCBxMxhOQjK.jpg  4910682.0    84.0  Released  False
# 28626  /hPzqg3NTDaW6y7L0QCBxMxhOQjK.jpg  4910682.0    84.0  Released  False
# 28627  /hPzqg3NTDaW6y7L0QCBxMxhOQjK.jpg  4910682.0    84.0  Released  False
# 28628  /hPzqg3NTDaW6y7L0QCBxMxhOQjK.jpg  4910682.0    84.0  Released  False
#
#       vote_count    genre_1  genre_2   genre_3
# 1            0.0  Adventure   Comedy   Romance
# 2            0.0  Adventure   Comedy   Romance
# 3            0.0  Adventure   Comedy   Romance
# 4            0.0  Adventure   Comedy   Romance
# 5            0.0  Adventure   Comedy   Romance
# ...          ...        ...      ...       ...
# 28624       99.0     Comedy   Horror   Mystery
# 28625       99.0     Comedy   Horror   Mystery
# 28626       99.0     Comedy   Horror   Mystery
# 28627       99.0     Comedy   Horror   Mystery
# 28628       99.0     Comedy   Horror   Mystery
#
# [28628 rows x 34 columns]

# %%
df['id']=df['id'].astype(str)
main['id']=main['id'].astype(str)

# %%
main_211112 = main.merge(df, on="id", how="left")

# %%
main_211112.to_csv('Data/main_211112.csv', index=False)

# %%
main_211112 = pd.read_csv('Data/main_211112.csv', dtype=str)
main_211112
# Out:
#               id                                             review  \
# 0      tt0018515  This is a very strange film that was long thou...
# 1      tt0018515  William Boyd and Louis Wolheim are the "Two Ar...
# 2      tt0018515  Not very many movies come to my mind that cove...
# 3      tt0018515  The third movie produced by Howard Hughes, thi...
# 4      tt0018515  Turner Classic Movies showed this silent, B&W ...
# ...          ...                                                ...
# 28623  tt0492486  This was the surprise film at the Dublin Horro...
# 28624  tt0492486  I've seen hundreds of horror movies in my life...
# 28625  tt0492486  I cannot remember the last time a horror movie...
# 28626  tt0492486  I saw this movie tonight. Never have left comm...
# 28627  tt0492486  Shrooms basically is a Slasher Movie. 3 couple...
#
#        review_1st review_2nd       original_title  year date_published  \
# 0       2.6453724   5.547905  Two Arabian Knights  1927     1927-09-23
# 1      -0.4441953  2.2827504  Two Arabian Knights  1927     1927-09-23
# 2       0.8150438  3.9238899  Two Arabian Knights  1927     1927-09-23
# 3        2.477075   5.466526  Two Arabian Knights  1927     1927-09-23
# 4       1.1922804  2.5448508  Two Arabian Knights  1927     1927-09-23
# ...           ...        ...                  ...   ...            ...
# 28623   1.0869972   6.843044              Shrooms  2007     2008-08-22
# 28624  0.17316706    6.62107              Shrooms  2007     2008-08-22
# 28625   1.0682999   6.835441              Shrooms  2007     2008-08-22
# 28626   1.0295599  3.5069268              Shrooms  2007     2008-08-22
# 28627   1.0787203   6.848455              Shrooms  2007     2008-08-22
#
#       duration               country language  ...   recommendation3  \
# 0           92                   USA  English  ...  The Last Command
# 1           92                   USA  English  ...  The Last Command
# 2           92                   USA  English  ...  The Last Command
# 3           92                   USA  English  ...  The Last Command
# 4           92                   USA  English  ...  The Last Command
# ...        ...                   ...      ...  ...               ...
# 28623       84  Ireland, UK, Denmark  English  ...   YellowBrickRoad
# 28624       84  Ireland, UK, Denmark  English  ...   YellowBrickRoad
# 28625       84  Ireland, UK, Denmark  English  ...   YellowBrickRoad
# 28626       84  Ireland, UK, Denmark  English  ...   YellowBrickRoad
# 28627       84  Ireland, UK, Denmark  English  ...   YellowBrickRoad
#
#       recommendation4 recommendation5       recommendation6 recommendation7  \
# 0        Street Angel  Sadie Thompson            Underworld         Tempest
# 1        Street Angel  Sadie Thompson            Underworld         Tempest
# 2        Street Angel  Sadie Thompson            Underworld         Tempest
# 3        Street Angel  Sadie Thompson            Underworld         Tempest
# 4        Street Angel  Sadie Thompson            Underworld         Tempest
# ...               ...             ...                   ...             ...
# 28623      Shrooms 3D           Creep  Wicked Little Things       Catacombs
# 28624      Shrooms 3D           Creep  Wicked Little Things       Catacombs
# 28625      Shrooms 3D           Creep  Wicked Little Things       Catacombs
# 28626      Shrooms 3D           Creep  Wicked Little Things       Catacombs
# 28627      Shrooms 3D           Creep  Wicked Little Things       Catacombs
#
#             recommendation8 recommendation9   recommendation10  \
# 0      The Way of All Flesh  The Front Page    The Divine Lady
# 1      The Way of All Flesh  The Front Page    The Divine Lady
# 2      The Way of All Flesh  The Front Page    The Divine Lady
# 3      The Way of All Flesh  The Front Page    The Divine Lady
# 4      The Way of All Flesh  The Front Page    The Divine Lady
# ...                     ...             ...                ...
# 28623             Dark Ride        100 Feet  La bête à l'affût
# 28624             Dark Ride        100 Feet  La bête à l'affût
# 28625             Dark Ride        100 Feet  La bête à l'affût
# 28626             Dark Ride        100 Feet  La bête à l'affût
# 28627             Dark Ride        100 Feet  La bête à l'affût
#
#              recommendation11  recommendation12
# 0      The Patent Leather Kid   The Love Parade
# 1      The Patent Leather Kid   The Love Parade
# 2      The Patent Leather Kid   The Love Parade
# 3      The Patent Leather Kid   The Love Parade
# 4      The Patent Leather Kid   The Love Parade
# ...                       ...               ...
# 28623         Finders Keepers  Shin Tange Sazen
# 28624         Finders Keepers  Shin Tange Sazen
# 28625         Finders Keepers  Shin Tange Sazen
# 28626         Finders Keepers  Shin Tange Sazen
# 28627         Finders Keepers  Shin Tange Sazen
#
# [28628 rows x 46 columns]
